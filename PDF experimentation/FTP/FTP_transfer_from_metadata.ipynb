# %% [markdown]
# ## What if we worked from the Metadata CSV?
#
# There's way more information here is the intriguing part. So for example I could filter based on completion, multiple folders at a time, filter on everything that is not at the metadata level etc.
#
# The downside: we cannot edit document sets via the metadata upload.
#
# The upside: everything in New Content right now has been transcribed and checked for "Needs Review". We could clear out all of New Content in one go, if we wanted to.
#
# Obviously, bulk uploads would take time, but for the most part the New Content stuff has associated box/folder info. I'm going to investigate exactly what does and doesn't have box/folder info today.

# %%
# useful code blocks from the old process

# hiding the API key
import os
import dotenv

# change to the directory where the dotenv file is (unique for each person)
os.chdir("/Users/charl/JBPP")

# load in stuff hidden in the .env file
dotenv.load_dotenv()
JBPP_key = os.getenv('JBPP_key')

# %%
# import required packages
import requests
import pandas as pd
import json
import re

# code to create post request
apikey = JBPP_key

root = "http://fromthepage.com/iiif"
endpoint = "/collection/2025-summer-program" # this endpoint is the only thing that needs editing 
# use IIIF slug found at bottom of "export" tab in FTP document set you want to export from
headers = {"Authorization": f"Token token={apikey}"}

# %%
# helper function

def html_export_from_id(id):
    new_url = f'https://fromthepage.com/iiif/{id}/export/html' # url that hosts the html export
    final = requests.get(new_url) # get request on html export url
    html = final.text
    return html

# %%
# let's take a look at this metadata file

# API key already loaded, let's navigate back to our folder

# os.chdir('PDF experimentation/FTP')
print(os.getcwd())
messy_df = pd.read_csv('fromthepage_metadata_20250709.csv')
# Out:
# C:\Users\charl\JBPP\PDF experimentation\FTP

# %%
messy_df.columns
# Out:
# Index(['FromThePage Title', '*Collection*', '*Document Sets*',
#        '*Uploaded Filename*', '*FromThePage ID*', '*FromThePage Slug*',
#        '*FromThePage URL*', 'FromThePage Description', 'Identifier',
#        '*Originating Manifest ID*', '*Creation Date*', '*Total Pages*',
#        '*Pages Transcribed*', '*Pages Corrected*', '*Pages Indexed*',
#        '*Pages Translated*', '*Pages Needing Review*', '*Pages Marked Blank*',
#        '*Contributors*', '*Contributors Name*', 'document set',
#        '*Description Status*', '*Described By*', 'PJB ID'],
#       dtype='object')

# %%
drop_cols = [
    '*Collection*', '*Uploaded Filename*', '*FromThePage Slug*',
    'FromThePage Description',
    '*Originating Manifest ID*', '*Creation Date*', 
    '*Pages Corrected*', '*Pages Indexed*',
    '*Pages Translated*',
    '*Contributors*', '*Description Status*', '*Described By*'
]
messy_df.drop(drop_cols, axis = 1, inplace = True)

# %%
messy_df
# Out:
#                                       FromThePage Title  \
# 0      (Online Participant) Speech from the Alabama ...
# 1      (Online Participant) Speech made before the H...
# 2     (Scholars’ Lab) "Meet the Press" NBC interview...
# 3     (Scholars’ Lab) Article - "Activism of the Lat...
# 4     (Scholars’ Lab) Article - "The Story of Lewis ...
# ...                                                 ...
# 9047  From Julian Bond to Julian Price, 2 Jan 1974 [...
# 9048                       Test Partial Box 17 Folder 3
# 9049                                    Box 17 Folder 3
# 9050                                        Box 17 Test
# 9051                                    Box 17 Folder 6
#
#                        *Document Sets*  *FromThePage ID*  \
# 0                       X_Current List             11081
# 1                       X_Current List             11082
# 2     X_OLD 2022 Transferred to Drupal             11084
# 3                       X_Current List             11085
# 4                       X_Current List             11200
# ...                                ...               ...
# 9047                          Zip Test          32200846
# 9048                          Zip Test          32202359
# 9049               2025 Summer Program          32213452
# 9050                          Zip Test          32213880
# 9051               2025 Summer Program          32214941
#
#                                       *FromThePage URL*         Identifier  \
# 0     https://fromthepage.com/julian-bond-papers-pro...     mss13347_b4_f3
# 1     https://fromthepage.com/julian-bond-papers-pro...     mss13347_b4_f2
# 2     https://fromthepage.com/julian-bond-papers-pro...  mss13337-b1-f3_sl
# 3     https://fromthepage.com/julian-bond-papers-pro...  mss13337_b1_f1_sl
# 4     https://fromthepage.com/julian-bond-papers-pro...  mss13347_b1_f5_sl
# ...                                                 ...                ...
# 9047  https://fromthepage.com/julian-bond-papers-pro...                NaN
# 9048  https://fromthepage.com/julian-bond-papers-pro...                NaN
# 9049  https://fromthepage.com/julian-bond-papers-pro...                NaN
# 9050  https://fromthepage.com/julian-bond-papers-pro...                NaN
# 9051  https://fromthepage.com/julian-bond-papers-pro...                NaN
#
#       *Total Pages*  *Pages Transcribed*  *Pages Needing Review*  \
# 0                11                   11                       0
# 1                11                   11                       0
# 2                13                   13                       0
# 3                 3                    3                       0
# 4                 2                    2                       0
# ...             ...                  ...                     ...
# 9047              2                    2                       0
# 9048             12                    1                       0
# 9049            147                  104                      13
# 9050             12                    0                       0
# 9051             75                   62                       1
#
#       *Pages Marked Blank*                                *Contributors Name*  \
# 0                        0                   | The Julian Bond Papers Project
# 1                        0  Stephanie Requena |  | Heather | abreen17 | Th...
# 2                        0  Jan Pilkington | tsherman | Heather | abreen17...
# 3                        0  Jan Pilkington |  | Stephanie Requena | The Ju...
# 4                        0  Jan Pilkington |  | The Julian Bond Papers Pro...
# ...                    ...                                                ...
# 9047                     0                                                NaN
# 9048                     0                                                NaN
# 9049                     0  Nakole Allen | Amira Dennis | Sophia Melo-Maln...
# 9050                     0                                                NaN
# 9051                     0  Nakole Allen | Amira Dennis | Sophia Melo-Maln...
#
#      document set  PJB ID
# 0             NaN     NaN
# 1             NaN     NaN
# 2             NaN     NaN
# 3             NaN     NaN
# 4             NaN     NaN
# ...           ...     ...
# 9047          NaN     NaN
# 9048          NaN     NaN
# 9049          NaN     NaN
# 9050          NaN     NaN
# 9051          NaN     NaN
#
# [9052 rows x 12 columns]

# %%
messy_df['*Document Sets*'].unique()
# Out:
# array(['X_Current List', 'X_OLD 2022 Transferred to Drupal',
#        'X_OLD 2022 Transferred to Drupal|X_Protected URLs',
#        'X_Protected URLs', 'X_OLD: 2023-2024 Transferred to Drupal',
#        'X_Protected URLs|X_Current List',
#        'X_Protected URLs|X_OLD: 2023-2024 Transferred to Drupal',
#        'X_OLD 2022 Transferred to Drupal|X_NHPRC Sample',
#        'X_OLD 2022 Transferred to Drupal|X_Protected URLs|New Content',
#        'X_OLD: 2023-2024 Transferred to Drupal|2024-2025_Charlie: Transfer to Drupal',
#        '2024-2025 Transferred to Drupal', 'New Content',
#        'Ready to Transfer to Drupal',
#        'Via CSV 2024-25 Transferred to Drupal',
#        'X_Protected URLs|X_NHPRC Sample|X_OLD: 2023-2024 Transferred to Drupal',
#        nan, 'CWP-test-document-set|Via CSV 2024-25 Transferred to Drupal',
#        'X_Protected URLs|X_NHPRC Sample|2024-2025 Transferred to Drupal',
#        '2024-2025 Transferred to Drupal|Docs Not for Public',
#        'X_NHPRC Sample|2024-2025 Transferred to Drupal',
#        'CONFIRMED Dups to Delete', 'Zip Test', '2025 Summer Program'],
#       dtype=object)

# %%
# let's stick to exclusively New Content

filtered = messy_df[messy_df['*Document Sets*'] ==  'New Content']
filtered
# Out:
#                                       FromThePage Title *Document Sets*  \
# 793          Speech concerning affirmative action, 2002     New Content
# 2292                         Brown v Board of Education     New Content
# 2293                        Missouri v Jenkins (70-176)     New Content
# 2294                        Missouri v Jenkins 2 (NOTE)     New Content
# 2296                                       Carter NAACP     New Content
# ...                                                 ...             ...
# 9042  To Julian Bond from Panke Bradley, Mrs. L. Fit...     New Content
# 9043  [Fragment] From Julian Bond to Cary Internatio...     New Content
# 9044  To Julian Bond from Dr. Richard Allen Williams...     New Content
# 9045  From Julian Bond Memo Concerning the Westbrook...     New Content
# 9046  From Julian Bond Memo Concerning the Westbrook...     New Content
#
#       *FromThePage ID*                                  *FromThePage URL*  \
# 793           32033742  https://fromthepage.com/julian-bond-papers-pro...
# 2292          32099898  https://fromthepage.com/julian-bond-papers-pro...
# 2293          32099900  https://fromthepage.com/julian-bond-papers-pro...
# 2294          32099901  https://fromthepage.com/julian-bond-papers-pro...
# 2296          32099903  https://fromthepage.com/julian-bond-papers-pro...
# ...                ...                                                ...
# 9042          32198891  https://fromthepage.com/julian-bond-papers-pro...
# 9043          32198892  https://fromthepage.com/julian-bond-papers-pro...
# 9044          32198893  https://fromthepage.com/julian-bond-papers-pro...
# 9045          32198894  https://fromthepage.com/julian-bond-papers-pro...
# 9046          32198895  https://fromthepage.com/julian-bond-papers-pro...
#
#      Identifier  *Total Pages*  *Pages Transcribed*  *Pages Needing Review*  \
# 793     PJB 526             23                   23                       0
# 2292   PJB498 a             10                   10                       0
# 2293   PJB498 b            107                  107                       0
# 2294   PJB498 c            117                  117                       0
# 2296   PJB498 e             14                   14                       0
# ...         ...            ...                  ...                     ...
# 9042   PJB 8273              2                    2                       0
# 9043   PJB 8274              1                    1                       0
# 9044   PJB 8275              1                    1                       0
# 9045   PJB 8276              1                    1                       0
# 9046   PJB 8277              1                    1                       0
#
#       *Pages Marked Blank*                                *Contributors Name*  \
# 793                      0  Shelagh Mackey | Markeeta Rosenow |  | Christa...
# 2292                     0  Debra Haraldson |  | Jan Pilkington | Karen J ...
# 2293                     0  Emily Hemlinger | Debra Haraldson |  | Judi  |...
# 2294                     0  Emily Hemlinger | Shelagh Mackey |  | Emily Ni...
# 2296                     0                                Markeeta Rosenow |
# ...                    ...                                                ...
# 9042                     0                        Privacylover | Carlos Perez
# 9043                     0                 Richie James Gorman | Carlos Perez
# 9044                     0                        Privacylover | Carlos Perez
# 9045                     0                 Richie James Gorman | Carlos Perez
# 9046                     0               Zachary Fortson Busch | Carlos Perez
#
#      document set  PJB ID
# 793           NaN     NaN
# 2292          NaN     NaN
# 2293          NaN     NaN
# 2294          NaN     NaN
# 2296          NaN     NaN
# ...           ...     ...
# 9042        b17f2     NaN
# 9043        b17f2     NaN
# 9044        b17f2     NaN
# 9045        b17f2     NaN
# 9046        b17f2     NaN
#
# [5885 rows x 12 columns]

# %%
# this looks about right
filtered['PJB ID'].unique()
filtered.drop('PJB ID', axis = 1, inplace = True)

# %%
# above warning is not a real issue for me because I no longer care about edits being made to the original dataframe (aka messy_df)
pd.options.mode.chained_assignment = None

# %%
filtered['document set'].unique()
# Out:
# array([nan, 'New Content', 'b14f3', 'b14f4', 'b14f5', 'b14f6', 'b14f7',
#        'b14f8', 'b14f9', 'b15f2', 'b15f1', 'b15f3', 'b15f4', 'b15f5',
#        'b15f6', 'b15f7', 'b16f1', 'b16f2', 'b16f3', 'b16f5', 'b16f6',
#        'b16f7', 'b16f4', 'b17f1', 'b17f2'], dtype=object)

# %%
# so we began this with 'New Content' (presumably b14f2, if I had to guess, and I will)
filtered[filtered['*Total Pages*'] != filtered['*Pages Transcribed*']]
# Out:
#                                       FromThePage Title *Document Sets*  \
# 2328  To Julian Bond from Leon Quat, Telegram, 7 Oct...     New Content
# 2595      To Julian Bond from Joann Taggart, 5 Apr 1969     New Content
# 8311  To Julian Bond from Wendell and Ellice Givan, ...     New Content
# 8325  To Julian Bond from Ralph Gaskins, 1 Dec 1973,...     New Content
# 8328  To Julian Bond from Henrietta Eberheart, 27 De...     New Content
#
#       *FromThePage ID*                                  *FromThePage URL*  \
# 2328          32101234  https://fromthepage.com/julian-bond-papers-pro...
# 2595          32108582  https://fromthepage.com/julian-bond-papers-pro...
# 8311          32196518  https://fromthepage.com/julian-bond-papers-pro...
# 8325          32196532  https://fromthepage.com/julian-bond-papers-pro...
# 8328          32196535  https://fromthepage.com/julian-bond-papers-pro...
#
#      Identifier  *Total Pages*  *Pages Transcribed*  *Pages Needing Review*  \
# 2328   PJB 2079              2                    1                       0
# 2595   PJB 2354              5                    4                       0
# 8311   PJB 7815              6                    4                       0
# 8325   PJB 7829              4                    2                       0
# 8328   PJB 7832              4                    3                       0
#
#       *Pages Marked Blank*                                *Contributors Name*  \
# 2328                     1                                     | Carlos Perez
# 2595                     1    Shelagh Mackey | Debra Haraldson | Carlos Perez
# 8311                     2  Privacylover | Emily Hemlinger |  | Delanee En...
# 8325                     2                    Patricia M Capps | Carlos Perez
# 8328                     1                        Privacylover | Carlos Perez
#
#      document set
# 2328          NaN
# 2595          NaN
# 8311        b16f7
# 8325        b16f7
# 8328        b16f7

# %%
# decent way to make checks.
filtered[filtered['*Pages Needing Review*'] != 0]
# Out:
# Empty DataFrame
# Columns: [FromThePage Title, *Document Sets*, *FromThePage ID*, *FromThePage URL*, Identifier, *Total Pages*, *Pages Transcribed*, *Pages Needing Review*, *Pages Marked Blank*, *Contributors Name*, document set]
# Index: []

# %%
# so now I know that everything in this filtered subset is ready for export.
# obviously, at the folder level, it is very easy to subset

# %%
filtered['document set'].unique()
# Out:
# array([nan, 'New Content', 'b14f3', 'b14f4', 'b14f5', 'b14f6', 'b14f7',
#        'b14f8', 'b14f9', 'b15f2', 'b15f1', 'b15f3', 'b15f4', 'b15f5',
#        'b15f6', 'b15f7', 'b16f1', 'b16f2', 'b16f3', 'b16f5', 'b16f6',
#        'b16f7', 'b16f4', 'b17f1', 'b17f2'], dtype=object)

# %%
list(filtered['document set'].unique())
# Out:
# [nan,
#  'New Content',
#  'b14f3',
#  'b14f4',
#  'b14f5',
#  'b14f6',
#  'b14f7',
#  'b14f8',
#  'b14f9',
#  'b15f2',
#  'b15f1',
#  'b15f3',
#  'b15f4',
#  'b15f5',
#  'b15f6',
#  'b15f7',
#  'b16f1',
#  'b16f2',
#  'b16f3',
#  'b16f5',
#  'b16f6',
#  'b16f7',
#  'b16f4',
#  'b17f1',
#  'b17f2']

# %%
unlabeled = filtered[filtered['document set'].isna()].drop([793, 2292, 2293, 2294, 2296, 2297])
unlabeled
# Out:
#                                       FromThePage Title *Document Sets*  \
# 2323  To Julian Bond from Hugh Gloster, 18 Sept 1968...     New Content
# 2325    To Julian Bond from Charles Everitt, 2 Oct 1968     New Content
# 2326  Memo to Julian Bond from Noe Baldwin, 2 Oct 19...     New Content
# 2327       To Julian Bond from Jerry Godard, 7 Oct 1968     New Content
# 2328  To Julian Bond from Leon Quat, Telegram, 7 Oct...     New Content
# ...                                                 ...             ...
# 2590  To Julian Bond from Carl Braden, 31 Dec 1968, ...     New Content
# 2591  To Julian Bond from Paul Anthony, 31 Dec 1968,...     New Content
# 2592  To Julian Bond from Charles Vogt, 18 Dec 1968,...     New Content
# 2593  To Julian Bond from Miss P. A. Stoney, 5 June ...     New Content
# 2595      To Julian Bond from Joann Taggart, 5 Apr 1969     New Content
#
#       *FromThePage ID*                                  *FromThePage URL*  \
# 2323          32101228  https://fromthepage.com/julian-bond-papers-pro...
# 2325          32101230  https://fromthepage.com/julian-bond-papers-pro...
# 2326          32101231  https://fromthepage.com/julian-bond-papers-pro...
# 2327          32101233  https://fromthepage.com/julian-bond-papers-pro...
# 2328          32101234  https://fromthepage.com/julian-bond-papers-pro...
# ...                ...                                                ...
# 2590          32105732  https://fromthepage.com/julian-bond-papers-pro...
# 2591          32105733  https://fromthepage.com/julian-bond-papers-pro...
# 2592          32105734  https://fromthepage.com/julian-bond-papers-pro...
# 2593          32108569  https://fromthepage.com/julian-bond-papers-pro...
# 2595          32108582  https://fromthepage.com/julian-bond-papers-pro...
#
#      Identifier  *Total Pages*  *Pages Transcribed*  *Pages Needing Review*  \
# 2323   PJB 2074              2                    2                       0
# 2325   PJB 2076              1                    1                       0
# 2326   PJB 2077              1                    1                       0
# 2327   PJB 2078              1                    1                       0
# 2328   PJB 2079              2                    1                       0
# ...         ...            ...                  ...                     ...
# 2590   PJB 2349              3                    3                       0
# 2591   PJB 2350              1                    1                       0
# 2592   PJB 2351              1                    1                       0
# 2593   PJB 2352              2                    2                       0
# 2595   PJB 2354              5                    4                       0
#
#       *Pages Marked Blank*                              *Contributors Name*  \
# 2323                     0      | Grace Janssen | Lucy Blase | Carlos Perez
# 2325                     0                   Debra Haraldson | Carlos Perez
# 2326                     0                      Janet Cannon | Carlos Perez
# 2327                     0                     Aaron VanHove | Carlos Perez
# 2328                     1                                   | Carlos Perez
# ...                    ...                                              ...
# 2590                     0  Debra Haraldson | Shelagh Mackey | Carlos Perez
# 2591                     0                   Debra Haraldson | Carlos Perez
# 2592                     0                   Debra Haraldson | Carlos Perez
# 2593                     0                   Debra Haraldson | Carlos Perez
# 2595                     1  Shelagh Mackey | Debra Haraldson | Carlos Perez
#
#      document set
# 2323          NaN
# 2325          NaN
# 2326          NaN
# 2327          NaN
# 2328          NaN
# ...           ...
# 2590          NaN
# 2591          NaN
# 2592          NaN
# 2593          NaN
# 2595          NaN
#
# [104 rows x 11 columns]

# %%
from bs4 import BeautifulSoup

# %%
def sort_exports(df):

    contents_list = []
    
    for idx, row in df.iterrows():
        pjb_id = row['Identifier']
        id = row['*FromThePage ID*']
        title = row['FromThePage Title']
        contributors = row['*Contributors Name*'].strip(' |').replace(' |',',')
        html = html_export_from_id(id)

        soup = BeautifulSoup(html, "lxml")
        content_tags = soup.find_all("div", class_="page-content")
        content = [tag.decode_contents() for tag in content_tags]
        content = ' '.join(content) + "<p> Thanks to FromThePage transcription contributors: " + contributors + "</p>"

        info = {'ID': pjb_id, 'Title': title, 'Document Body': content}
        
        contents_list.append(info)

    return contents_list

# %%
contents_list = sort_exports(unlabeled)

# %%
unlabeled_docs = pd.DataFrame(contents_list)
unlabeled_docs.to_csv('unlabeled_docs_export.csv')

# %%
os.mkdir('FTP exports')

# %%
unique_sets = list(filtered['document set'].unique())

# %%
unique_sets = unique_sets[1:] # to lose the nan

# %%
# %%time
for i in unique_sets:
    label = i
    slice_df = filtered[filtered['document set'] == i]
    contents_list = sort_exports(slice_df)
    df_temp = pd.DataFrame(contents_list)
    df_temp.to_csv(f'FTP exports/{label}_export_07092025.csv')
# Out:
# CPU times: total: 43.8 s
# Wall time: 16min 46s

# %%
filtered.sort_values(by = '*Total Pages*', ascending = False).head(30)
# Out:
#                                       FromThePage Title *Document Sets*  \
# 2297  Research Material for Speech- "The Broken Prom...     New Content
# 2294                        Missouri v Jenkins 2 (NOTE)     New Content
# 2293                        Missouri v Jenkins (70-176)     New Content
# 793          Speech concerning affirmative action, 2002     New Content
# 2296                                       Carter NAACP     New Content
# 8951  Funding Proposal for Operation New Prichard [S...     New Content
# 2292                         Brown v Board of Education     New Content
# 5206  Proposal for a Journal of Black Politics, [Jul...     New Content
# 2598      To Julian Bond from Ardena Shanks, 2 May 1969     New Content
# 5256  Speech concerning Black Voters and Officials d...     New Content
# 4642        From Julian Bond to John Neary, 21 Sep 1970     New Content
# 8311  To Julian Bond from Wendell and Ellice Givan, ...     New Content
# 2439  Speech concerning the structure and operation ...     New Content
# 2497  To Julian Bond from Kathleen Johnson, 30 Sept ...     New Content
# 2595      To Julian Bond from Joann Taggart, 5 Apr 1969     New Content
# 2603  To Julian Bond from Gilbert John Forlor, 10 Ma...     New Content
# 8325  To Julian Bond from Ralph Gaskins, 1 Dec 1973,...     New Content
# 2581  To Julian Bond from Judy Marks, 19 Dec 1968, w...     New Content
# 8328  To Julian Bond from Henrietta Eberheart, 27 De...     New Content
# 8331  To Julian Bond from Pat Lewis, 11 Dec 1973, wi...     New Content
# 4502  Memorandum from Julian Bond to Vincent Harding...     New Content
# 5488  Press Release by Political Associates Concerni...     New Content
# 5331  Press Release: Atlanta's Southern Elections Fu...     New Content
# 2587  To Julian Bond from Jack Conway, 18 Dec 1968, ...     New Content
# 6778       From Julian Bond to Earl Graves, 14 Sep 1971     New Content
# 7259         From Julian Bond to Jim Gibson, 9 Feb 1972     New Content
# 7710               From Julian Bond to Bebe, 1 Aug 1972     New Content
# 7789       From Julian Bond to J. Max Bond, 25 Aug 1972     New Content
# 7829      From Julian Bond to Wallace Green, 6 Sep 1972     New Content
# 8151  From Julian Bond to Mrs. Ronald Brown, 31 Oct ...     New Content
#
#       *FromThePage ID*                                  *FromThePage URL*  \
# 2297          32099923  https://fromthepage.com/julian-bond-papers-pro...
# 2294          32099901  https://fromthepage.com/julian-bond-papers-pro...
# 2293          32099900  https://fromthepage.com/julian-bond-papers-pro...
# 793           32033742  https://fromthepage.com/julian-bond-papers-pro...
# 2296          32099903  https://fromthepage.com/julian-bond-papers-pro...
# 8951          32198800  https://fromthepage.com/julian-bond-papers-pro...
# 2292          32099898  https://fromthepage.com/julian-bond-papers-pro...
# 5206          32124915  https://fromthepage.com/julian-bond-papers-pro...
# 2598          32108739  https://fromthepage.com/julian-bond-papers-pro...
# 5256          32124965  https://fromthepage.com/julian-bond-papers-pro...
# 4642          32124229  https://fromthepage.com/julian-bond-papers-pro...
# 8311          32196518  https://fromthepage.com/julian-bond-papers-pro...
# 2439          32102525  https://fromthepage.com/julian-bond-papers-pro...
# 2497          32104593  https://fromthepage.com/julian-bond-papers-pro...
# 2595          32108582  https://fromthepage.com/julian-bond-papers-pro...
# 2603          32108744  https://fromthepage.com/julian-bond-papers-pro...
# 8325          32196532  https://fromthepage.com/julian-bond-papers-pro...
# 2581          32105720  https://fromthepage.com/julian-bond-papers-pro...
# 8328          32196535  https://fromthepage.com/julian-bond-papers-pro...
# 8331          32196538  https://fromthepage.com/julian-bond-papers-pro...
# 4502          32124089  https://fromthepage.com/julian-bond-papers-pro...
# 5488          32126160  https://fromthepage.com/julian-bond-papers-pro...
# 5331          32126002  https://fromthepage.com/julian-bond-papers-pro...
# 2587          32105728  https://fromthepage.com/julian-bond-papers-pro...
# 6778          32135609  https://fromthepage.com/julian-bond-papers-pro...
# 7259          32148259  https://fromthepage.com/julian-bond-papers-pro...
# 7710          32191937  https://fromthepage.com/julian-bond-papers-pro...
# 7789          32192016  https://fromthepage.com/julian-bond-papers-pro...
# 7829          32192056  https://fromthepage.com/julian-bond-papers-pro...
# 8151          32193477  https://fromthepage.com/julian-bond-papers-pro...
#
#      Identifier  *Total Pages*  *Pages Transcribed*  *Pages Needing Review*  \
# 2297     PJB539            118                  118                       0
# 2294   PJB498 c            117                  117                       0
# 2293   PJB498 b            107                  107                       0
# 793     PJB 526             23                   23                       0
# 2296   PJB498 e             14                   14                       0
# 8951   PJB 8182             10                   10                       0
# 2292   PJB498 a             10                   10                       0
# 5206   PJB 4325             10                   10                       0
# 2598   PJB 2357              6                    6                       0
# 5256   PJB 4375              6                    6                       0
# 4642   PJB 4643              6                    6                       0
# 8311   PJB 7815              6                    4                       0
# 2439     PJB495              5                    5                       0
# 2497   PJB 2248              5                    5                       0
# 2595   PJB 2354              5                    4                       0
# 2603   PJB 2362              4                    4                       0
# 8325   PJB 7829              4                    2                       0
# 2581   PJB 2340              4                    4                       0
# 8328   PJB 7832              4                    3                       0
# 8331   PJB 7835              4                    4                       0
# 4502   PJB 4503              3                    3                       0
# 5488   PJB 4932              3                    3                       0
# 5331   PJB 4774              3                    3                       0
# 2587   PJB 2346              3                    3                       0
# 6778   PJB 6006              3                    3                       0
# 7259   PJB 6489              3                    3                       0
# 7710   PJB 7214              3                    3                       0
# 7789   PJB 7293              3                    3                       0
# 7829   PJB 7333              3                    3                       0
# 8151   PJB 7655              3                    3                       0
#
#       *Pages Marked Blank*                                *Contributors Name*  \
# 2297                     0  Sarah Ahmad  | Princess1 | Matyas Niedermeier ...
# 2294                     0  Emily Hemlinger | Shelagh Mackey |  | Emily Ni...
# 2293                     0  Emily Hemlinger | Debra Haraldson |  | Judi  |...
# 793                      0  Shelagh Mackey | Markeeta Rosenow |  | Christa...
# 2296                     0                                Markeeta Rosenow |
# 8951                     0  Richie James Gorman |  | Privacylover | Prince...
# 2292                     0  Debra Haraldson |  | Jan Pilkington | Karen J ...
# 5206                     0  Carlos Perez | Debra Haraldson | kristen allen...
# 2598                     0  Debra Haraldson | Emily Niepraschk | Carlos Perez
# 5256                     0                          Carlos Perez | T. Bradley
# 4642                     0   Debra Haraldson | Privacylover | Emily Hemlinger
# 8311                     2  Privacylover | Emily Hemlinger |  | Delanee En...
# 2439                     0                                 Debra Haraldson |
# 2497                     0     Debra Haraldson | Jacob Schmidt | Carlos Perez
# 2595                     1    Shelagh Mackey | Debra Haraldson | Carlos Perez
# 2603                     0  Shelagh Mackey | Debra Haraldson |  | Carlos P...
# 8325                     2                    Patricia M Capps | Carlos Perez
# 2581                     0                     Debra Haraldson | Carlos Perez
# 8328                     1                        Privacylover | Carlos Perez
# 8331                     0                      | Privacylover | Carlos Perez
# 4502                     0  Debra Haraldson | Sophia Melo-Malnowski | Emil...
# 5488                     0     T. Bradley | Debra Haraldson | Emily Hemlinger
# 5331                     0                     Privacylover | Emily Hemlinger
# 2587                     0  Shelagh Mackey | Debra Haraldson | Jacob Schmi...
# 6778                     0                             Greg S. | Carlos Perez
# 7259                     0                     Debra Haraldson | Carlos Perez
# 7710                     0               Sophia Melo-Malnowski | Carlos Perez
# 7789                     0                          T. Bradley | Carlos Perez
# 7829                     0  Sophia Melo-Malnowski | T. Bradley | Carlos Perez
# 8151                     0   Patricia M Capps | Delanee Ensley | Carlos Perez
#
#      document set
# 2297          NaN
# 2294          NaN
# 2293          NaN
# 793           NaN
# 2296          NaN
# 8951        b17f2
# 2292          NaN
# 5206        b15f1
# 2598  New Content
# 5256        b15f1
# 4642        b15f2
# 8311        b16f7
# 2439          NaN
# 2497          NaN
# 2595          NaN
# 2603  New Content
# 8325        b16f7
# 2581          NaN
# 8328        b16f7
# 8331        b16f7
# 4502        b15f2
# 5488        b15f3
# 5331        b15f3
# 2587          NaN
# 6778        b15f7
# 7259        b16f2
# 7710        b16f5
# 7789        b16f5
# 7829        b16f5
# 8151        b16f6
