# %% [markdown]
# ### FTP API data grab
#
# This file contains the code for downloading a FTP transcription export from their API
#
# Still a work in progress
#
# I am using Python's requests library because I have more facility in Python and Windows PowerShell is a curse that I prefer not to suffer under when I can avoid it. If on a MacOS or Linux/Unix system, the documentation on the FTP website explains how to accomplish this from the command line: https://content.fromthepage.com/project-owner-documentation/api-keys/

# %%
# hiding the API key
import os
import dotenv

# change to the directory where the dotenv file is (unique for each person)
os.chdir("/Users/charl/JBPP")

# load in stuff hidden in the .env file
dotenv.load_dotenv()
JBPP_key = os.getenv('JBPP_key')

# %%
# import required packages
import requests
import pandas as pd
import json
import re

# code to create post request
apikey = JBPP_key

root = "http://fromthepage.com/iiif"
endpoint = "/collection/2025-summer-program" # this endpoint is the only thing that needs editing 
# use IIIF slug found at bottom of "export" tab in FTP document set you want to export from
headers = {"Authorization": f"Token token={apikey}"}

# %%
# submit post request using requests library (operates same as cURL, just in Python)
response = requests.post(root+endpoint, headers=headers)

# %%
# to run if you wanna look at the raw text or check status

# print(response.status_code)
# should be 200
# print(response.text)

# %%
# convert to dataframe using json_normalize
# record_path=['manifests'] is to ignore metadata associated with the API call that's returned in the response
# but is not connected to the actual doc set content
response_df = pd.json_normalize(json.loads(response.text), record_path=['manifests'])

# %%
# if interested in taking a look at the dataframe:

response_df.head().T
# I'm curious if anything else will become metadata because there's more metadata in the bulk uploaded documents
# If it breaks later, refer to that column to see how to fix it
# Out:
#                                                                                    0  \
# @id                                   https://fromthepage.com/iiif/32213452/manifest
# @type                                                                    sc:Manifest
# label                                                                Box 17 Folder 3
# metadata                           [{'label': 'dc:source', 'value': ['', 'https:/...
# service.@context                    http://www.fromthepage.org/jsonld/1/context.json
# service.@id                             https://fromthepage.com/iiif/32213452/status
# service.label                                                            Work Status
# service.profile                    https://github.com/benwbrum/fromthepage/wiki/F...
# service.pctComplete                                                            66.67
# service.pctTranscribed                                                         66.67
# service.pctOcrCorrected                                                          0.0
# service.pctIndexed                                                                 0
# service.pctMarkedBlank                                                             0
# service.pctNeedsReview                                                         11.56
# service.pctTranslationComplete                                                     0
# service.pctTranslated                                                              0
# service.pctTranslationNeedsReview                                                  0
# service.pctTranslationIndexed                                                      0
# service.pctTranslationMarkedBlank                                                  0
# service.metadataStatus                                                   undescribed
# service.lastUpdated                                          2025-07-08 00:52:48 UTC
#
#                                                                                    1
# @id                                   https://fromthepage.com/iiif/32214941/manifest
# @type                                                                    sc:Manifest
# label                                                                Box 17 Folder 6
# metadata                           [{'label': 'dc:source', 'value': ['', 'https:/...
# service.@context                    http://www.fromthepage.org/jsonld/1/context.json
# service.@id                             https://fromthepage.com/iiif/32214941/status
# service.label                                                            Work Status
# service.profile                    https://github.com/benwbrum/fromthepage/wiki/F...
# service.pctComplete                                                            78.67
# service.pctTranscribed                                                         78.67
# service.pctOcrCorrected                                                          0.0
# service.pctIndexed                                                                 0
# service.pctMarkedBlank                                                             0
# service.pctNeedsReview                                                          1.33
# service.pctTranslationComplete                                                     0
# service.pctTranslated                                                              0
# service.pctTranslationNeedsReview                                                  0
# service.pctTranslationIndexed                                                      0
# service.pctTranslationMarkedBlank                                                  0
# service.metadataStatus                                                   undescribed
# service.lastUpdated                                          2025-07-08 15:08:41 UTC

# %%
# don't run this cell (you can, you just don't need to)

#bunch_of_tuples = [] # this is where we'll store all the key (PJB ID) - value (Document Body) pairs to convert to a dataframe

#for i in range(len(response_df)): # iterates over each row of the dataframe - 
#    # there are other ways to do this but it's not prohibitively inefficient
#    url = response_df['@id'][i] # indexes into the value in the first column of the dataframe (the IIIF url)
#    cut = url.split('/')[4] # slices out the unique work_id - to be used to locate plaintext export
#    try:
#        pjb_id = response_df['metadata'][i][0]['value'] # tries to make key based on identifier aka PJB ID
#    except TypeError:
#       pjb_id = cut # if it fails, it instead makes key on the basis of the work_id (guaranteed to be unique)
#    new_url = f'https://fromthepage.com/iiif/{cut}/export/plaintext/verbatim' # url that hosts the plaintext export
#    final = requests.get(new_url) # get request on plaintext export url
#    bunch_of_tuples.append((pjb_id, final.text)) # appends key-value pair to dictionary

# %%
label = response_df['label'][1]
url = response_df['@id'][1]
cut = url.split('/')[4]
iiif_ref = response_df['metadata'][1][0]['value'][1]
label, url, cut, iiif_ref
# Out:
# ('Box 17 Folder 6',
#  'https://fromthepage.com/iiif/32214941/manifest',
#  '32214941',
#  'https://iiifman.lib.virginia.edu/pid/tsb:109207?unit=60420')

# %%
new_url = f'https://fromthepage.com/iiif/{cut}/export/html' # url that hosts the html export
final = requests.get(new_url) # get request on html export url
html = final.text

# %%
from bs4 import BeautifulSoup
import re

def extract_pages(string):
    soup = BeautifulSoup(string, "lxml")

    # Find all <div> tags where id starts with "page-"
    page_divs = soup.find_all("div", id=re.compile(r"^page-\d+"))

    pages = []

    for page_div in page_divs:
        # Extract title from the <a name="..."> tag inside the page
        title_tag = page_div.find("a", attrs={"name": True})
        title = title_tag.get_text(strip=True) if title_tag else None

        # Extract page content
        content_tag = page_div.find("div", class_="page-content")
        content = content_tag.decode_contents() if content_tag else None

        # Extract all usernames from <small class="page-version-username">
        user_tags = page_div.find_all("small", class_="page-version-username")
        users = [tag.get_text(strip=True) for tag in user_tags]

        pages.append({
            "FTP_page_id": page_div.get("id"),
            "title": title,
            "content": content,
            "users": users
        })

    return pages

# %%
pages = extract_pages(html)

# %%
for page in pages:
    page['title'] = page['title'].strip(' cont.').strip(',')
    page['PJB'] = page['title'].split(',')[-1].strip(' ')
    print(page['PJB'])
# Out:
# PJB 8601
# PJB 8602
# PJB 8603
# PJB 8604
# PJB 8605
# PJB 8606
# PJB 8607
# PJB 8607
# PJB 8608
# PJB 8608
# PJB 8608
# PJB 8609
# PJB 8610
# PJB 8611
# PJB 8612
# PJB 8613
# PJB 8613
# PJB 8614
# PJB 8615
# PJB 8616
# PJB 8617
# PJB 8618
# PJB 8619
# PJB 8620
# PJB 8621
# PJB 8622
# PJB 8623
# PJB 8624
# PJB 8625
# PJB 8626
# PJB 8627
# PJB 8627
# PJB 8627
# PJB 8627
# PJB 8628
# PJB 8628
# PJB 8628
# PJB 8629
# PJB 8630
# PJB 8631
# PJB 8632
# PJB 8633
# PJB 8633
# PJB 8634
# PJB 8634
# PJB 8635
# PJB 8636
# PJB 8637
# PJB 8638
# PJB 8638
# PJB 8639
# PJB 8640
# PJB 8641
# PJB 8641
# PJB 8642
# PJB 8643
# PJB 8644
# PJB 8645
# PJB 8645
# PJB 8646
# PJB 8647
# PJB 8648
# PJB 8649
# PJB 8649
# PJB 8650
# PJB 8650
# PJB 8651
# PJB 8652
# PJB 8653
# PJB 8653
# PJB 8654
# PJB 8654
# PJB 8654
# PJB 8655
# PJB 8655

# %%
from collections import defaultdict

grouped = defaultdict(list)
for page in pages:
    grouped[page['PJB']].append(page)

merged_pages = [
    {
        'PJB': PJB,
        'content': ' '.join(p['content'] for p in group if p['content']),
        'users': sorted(set(u for p in group for u in p['users'])),
        'FTP_page_ids': [p['FTP_page_id'] for p in group]
    }
    for PJB, group in grouped.items()
]

# %%
for page in merged_pages:
    contributors = page.pop('users')
    contributors = ', '.join(contributors)
    page['content'] = page['content'] + "<p>Thanks to FromThePage transcription contributors: " + contributors + "</p>"

# %%
merged_pages
# Out:
# [{'PJB': 'PJB 8601',
#   'content': '\n<p>March 1, 1974</p>\n<p>Dear Ms. Henzie,</p>\n<p>Thank you for your kind letter of February 16th. As requested, enclosed is information about me that should be helpful in doing your term paper.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Ms. Sandy Henzie <br/>\n212 Hill Church Road<br/>\nSpring City, Pa. 19475</p>\n<p>JB/jj<br/>\ncc. <br/>\nencl.</p>\n<p>Thanks to FromThePage transcription contributors: Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113595']},
#  {'PJB': 'PJB 8602',
#   'content': '\n<p><sup>big other matter</sup></p>\n<p>212 Hill Church Road<br/>\nSpring City, PA 19475<br/>\nFebruary 16, 1974</p>\n<p>The Honorable Mr. Julian Bond<br/>\nHouse of Representatives<br/>\nAtlanta, Georgia</p>\n<p>Sir:</p>\n<p>I am doing a term paper for my American Government class at school and have chosen you as my subject. Could you send me any background information on yourself and your views on important matters in the government? Any opinions you have on Watergate and the Energy Crisis would be greatly appreciated.</p>\n<p>I am thanking you in advance for any information you could send me.</p>\n<p>Sincerely yours, <br/>\n[Sandy Henzie signature]<br/>\nSandy Henzie</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113596']},
#  {'PJB': 'PJB 8603',
#   'content': '\n<p>March 1, 1974</p>\n<p>Dear Mr. Hamburger,</p>\n<p>Please forgive me for taking so long to respond to your very fine book. I have read it and was more than impressed by it. It created a great deal of nostalgia in me. Not for the so called good old days your book represented, but for a period in American life when ordinary hard working men and women like those in Fayette County were willing to go to every extreme to secure their constitutional rights. It strikes me that such people are increasingly difficult to find in most parts of the United States today . and for all I know, their number may be deminishing even in Fayette County.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Robert Hamburger<br/>\nDepartment of English<br/>\nThe City College<br/>\nThe City University of New York<br/>\nNew York, N.Y. 10031</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113597']},
#  {'PJB': 'PJB 8604',
#   'content': '\n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113598']},
#  {'PJB': 'PJB 8605',
#   'content': '\n<p>March 1, 1974</p>\n<p>Dear Mr. Williams:</p>\n<p>I do remember you and I am glad to hear that you are out in the free world.</p>\n<p>I do not know how to contact Mr. Pace, but I might suggest that you contact Mr. William Laite, Jr., Department of Offender Rehabilitation, 815 Trinity-Washington Bldg., Atlanta, Georgia.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Marvin Williams, Jr. <br/>\n300 Avenue F, Apt x-l<br/>\nThomaston, Georgia 30285</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113599']},
#  {'PJB': 'PJB 8606',
#   'content': '\n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113600']},
#  {'PJB': 'PJB 8607',
#   'content': '\n<p>March 1, 1974</p>\n<p>Dear Abe:</p>\n<p>Of course you have my permission to quote the answers to your questionnaire.</p>\n<p>Question one is difficult to answer, because of the difference between potential and actual power. Blacks have the actual power to influence many public policy decisions made affecting the residents of the City of Atlanta.</p>\n<p>Blacks in Atlanta who have real political power include Senator Leroy Johnson and Mr. Jesse Hill. There are some others, but these two stand above the c[illegible]. Sen. Johnson, only one of two Blacks in a fifty-six member Senate, is able to pass legislation by employing the standard political technique of "back scratching".</p>\n<p>A major problem facing Black political leadership in Atlanta is a serious lack of technical and staff support, as well as, the standard class and political differences which seperate them and prevent them from presenting a united front.</p>\n<p>We can increase our political power in Atlanta by increasing the Black electorate through year round registration and voter education drives and by insuring that those Blacks and whites who get elected to office through the power of the Black vote are intelligent and responsible people and not simply articulate rabble <u>-</u> rousers.</p>\n<p>Blacks in Atlanta have more political power than those in other large southern cities, because of a combination of reasons, but primarily because of the history</p>\n \n<p><sup>Abraham Davis<br/>\nProfessor of Political Science<br/>\nMarch 1, 1974<br/>\nPage Two</sup></p>\n<p>of an aggressive Black middle class and a benevolent dictatorship imposed by the white business circles of this city, which has allowed Black political power to flourish.</p>\n<p>I hesitate to make up a list of important B<strike>a</strike>l<strike>l</strike>acks since I am sure to exclude someone who should be included.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Dr. Abraham Davis<br/>\nProfessor of Political Science<br/>\nMorehouse College<br/>\nAtlanta, Georgia 30314</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113601', 'page-35113602']},
#  {'PJB': 'PJB 8608',
#   'content': '\n<p><sup>24</sup></p>\n<p>Dear <u>[Rep. Julian Bond signature]</u>;</p>\n<p>I am doing a study of black politics in Atlanta and will be interviewing a number of citizens and politicians. These interviews are an integral part of my research</p>\n<p>I would appreciated it very much if you would answer the following ten questions. ALL answers will be completely confidential unless I have your permission to quote you in my study.</p>\n<p>I will appreciate very much your cooperation in this matter. Please return your answers to the following address:</p>\n<p>Dr. Abraham L. Davis<br/>\nDepartment of Political Science<br/>\nMorehouse College<br/>\nAtlanta, Georgia 30314</p>\n<p>Would you please check the appropriate box. <br/>\nPlease detach and return</p>\n<p>Dr. Abraham Davis has my permission to quote me in his study on Black Politics in Atlanta</p>\n<p>I want my answers to remain confidential and prefer not to be quoted in your study.</p>\n<p>Thank you very much for your time</p>\n<p>Sincerely, <br/>\n[Abraham L. Davis signature]<br/>\nAbraham Davis<br/>\nProfessor of Political Science</p>\n \n<p>QUESTIONNAIRE</p>\n<p>1. How much political power do blacks have in Atlanta?</p>\n<p>2. Do you perceive a difference between influence and power? If so, what are the differences?</p>\n<p>3. Name some blacks who in your estimation have real political power. Explain.</p>\n<p>4. Cite some examples of blacks exercising real political power in Atlanta.</p>\n<p>5. What problems do black leaders face in Atlanta in exercising their power in a maximum way?</p>\n<p>6. What steps can blacks take to increase their political power in Atlanta?</p>\n<p>Use the reverse side of each sheet of paper if you need more space for your answers. </p>\n \n<p><sup>-2-</sup></p>\n<p>7. What goals have blacks achieved thru political power in Atlanta?</p>\n<p>8. What goals should blacks achieve with political power?</p>\n<p>9. Do blacks in Atlanta have more political power than blacks in other large Southern cities? If the answer is "yes," explain. If the answer is "no," explain.</p>\n<p>10. Name the blacks in Atlanta who in your estimation have the most political power. List them in decreasing order of from the most to the least power.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113603', 'page-35113604', 'page-35113605']},
#  {'PJB': 'PJB 8609',
#   'content': "\n<p>March 2, 1974</p>\n<p>Dear Yancey:</p>\n<p>Enclosed is my Atlanta - San Juan - Atlanta ticket receipt. Now that S.E.F. is affluent, I hope you will reimburse me for this and other out of pocket expenses I've incurred.</p>\n<p>Also, enclosed is a membership form for Eastern's Ionosphere Club for your Chairman - that's me..... This will ease my travel and better enable me to raise money.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Yancey Martin, Executive Director<br/>\nSouthern Elections Fund<br/>\n87 Walton Street<br/>\nAtlanta, Georgia 30303</p>\n<p>JB/jj<br/>\ncc.<br/>\nencls: ticket receipt<br/>\nmembership form &amp; envelope</p>\n<p>Thanks to FromThePage transcription contributors: Nakole Allen, lbaker</p>",
#   'FTP_page_ids': ['page-35113606']},
#  {'PJB': 'PJB 8610',
#   'content': "\n<p>Yancey Martin<br/>\nS.E.F. <br/>\n87 Walton St<br/>\nAtlanta, Ga.</p>\n<p>Dear Yancey:</p>\n<p>Enclosed is my Atlanta -- San Juan -- Atlanta ticket receipt.</p>\n<p>Now that S.E.F. is affluent, I hope you'll reimburse me for this and other out of pocket expenses I've incurred.</p>\n<p><strike>Sincerely</strike></p>\n<p>Also enclosed <strike>are</strike> is a membership form for Eastern's Ionoshpere Club for your Chairman -- that's me.</p>\n<p>This will ease my travel and better enable <strike>you to</strike> me to raise money.</p>\n<p>Sincerely</p>\n<p>enc: ticket receipt<br/>\nmembership form &amp; envelope</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113607']},
#  {'PJB': 'PJB 8611',
#   'content': '\n<p>March 2, 1974</p>\n<p>Yancey:</p>\n<p>These are the lists I mentioned to you. If we can get good addresses for them, I think we can raise some money from them.</p>\n<p>Also, included is an organization whose list we should get and whose book we ought to buy.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Yancey Martin, Executive Director</p>\n<p>Southern Elections Fund<br/>\n87 Walton Street<br/>\nAtlanta, Georgia 30303</p>\n<p>JB/jj<br/>\ncc. <br/>\nencls: clips<br/>\norder black &amp; envelope brochure</p>\n<p>Thanks to FromThePage transcription contributors: Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113608']},
#  {'PJB': 'PJB 8612',
#   'content': '\n<p>Yancey:</p>\n<p>These are the lists I mentioned to you.</p>\n<p>If we can get good addresses for them, I think we can raise some money from them.</p>\n<p>Also included is an organization whose list we ought to <strike>Sincerely</strike> get, and a book we ought to buy.</p>\n<p><strike>enc: news clips</strike></p>\n<p>enc: clips<br/>\norder blank &amp; envelope <br/>\nprochure</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113609']},
#  {'PJB': 'PJB 8613',
#   'content': '\n<p>March 2, 1974</p>\n<p>Dear Bob:</p>\n<p>How about the following for the "Bond brochure"?</p>\n<p>In the world of American politics, Julian Bond is probably better known than any other state legislator in the country. A young, aggressive, outspoken political activist and reformer, Julian Bond is unique among American politicians.</p>\n<p>Julian Bond\'s adult life has been spent in fighting for basic human rights - the right to eat a hamburger or sit in the front of a bus, the right to vote, the right to an open political process, and more recently, the right to be represented by honestly chosen honest men and women. From dusty and sometimes dangerous plantation back roads in Mississippi, to national convention halls in Miami and Chicago, Julian Bond has fought for - and won - important victories for us all.</p>\n<p>In the streets, in the courts, at the ballot box or in a legislative committee hearing room, Julian Bond has tried to represent the unrepresented, and to insure that power to the people is more reality than rhetoric.</p>\n<p>Bond helped to found the Atlanta Student Movement in 1960 and helped direct massive student demonstrations that integrated public facilities all over that city.</p>\n<p>In that same year, he was one of the founders of the Student Nonviolent Coordinating Committee (SNCC), a youthful band of guerilla fighters against the rigid - and brutally enforced - racial segregation of the rural South.</p>\n<p>In 1965, Bond was part of the first group of Blacks elected to the Georgia House of Representatives since Reconstruction, but he was prevented from taking his seat by members of the Georgia House who charged him with treason and sedition, because he opposed the draft and American involvement in Vietnam. Bond had to win two additional elections in one year and a </p>\n \n<p>Mr. Bob Walker<br/>\nMarch 2, 1974<br/>\nPage two <br/>\nRe: "Bond brochure"</p>\n<p>unanimous decision of the United States Supreme Court before he was finally seated in 1967.</p>\n<p>In 1968 in Chicago, Bond was nominated for Vice-President, but had to withdraw his name because he was then too young.</p>\n<p>Charging that Blacks had been excluded from the 1968 Georgia Delegation, hand picked by then Governor Lester Maddox, Bond became the Co-Chariman of the Georgia Loyal National Democrats, an insurgent group that succeeded in ousting half of the Mad-dox regulars, eliminating the "unit rule" from future Democratic Conventions, and helped usher in the reforms of the \'72 con-vention.</p>\n<p>A militant reformer, a Black man, a politician - Julian Bond is out to radically change the nature of American politics. He believes that the time to speak is over - the time to act is now.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Bob Walker<br/>\nAmerican Program Bureau<br/>\n850 Boylston Street <br/>\nBrookline, Massachusetts</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113610', 'page-35113611']},
#  {'PJB': 'PJB 8614',
#   'content': '\n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113612']},
#  {'PJB': 'PJB 8615',
#   'content': "\n<p>March 4, 1974</p>\n<p>Dear Dr. Daugherty:</p>\n<p>It was a pleasure meeting you on the Pittsburgh flight last week.</p>\n<p>I'd like very much to come back to Toronto. If you can find some sponsoring group at the University, please put them in touch with my lecture bureau, the American Program Bureau in Boston.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Dr. Howard Daugherty <br/>\nFaculty of Environmental Studies<br/>\nYork University<br/>\nToronto, Ontario, Canada</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, Nakole Allen, lbaker</p>",
#   'FTP_page_ids': ['page-35113613']},
#  {'PJB': 'PJB 8616',
#   'content': "\n<p>Dr. Howard Daugherty <br/>\nFaculty of Environmental Studies<br/>\nYork University <br/>\nToronto, Ontario, Canada</p>\n<p>Dear <strike>Mr</strike> Dr Daugherty,</p>\n<p>It was a pleasure meeting you on the Pittsburgh flight last week.</p>\n<p>I'd like very much to come back to Toronto. If you can find some sponsoring group at the University, please put them in touch with my lecture bureau, the American Program Bureau in Boston.</p>\n<p>Sincerely</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113614']},
#  {'PJB': 'PJB 8617',
#   'content': '\n<p>March 4, 1974</p>\n<p>Dear Frank:</p>\n<p>Enclosed is my ticket receipt. I enjoyed sharing my newly learned "expertice" with A.A.I. John and I shared a hotel room so I have no hotel expenses. Cab fares came to about $20.00 on both ends.</p>\n<p>Let us know in advance when you come this way.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Frank Ferrari<br/>\nAfrican American Institute<br/>\n833 United Nations Plaza<br/>\nNew York, N.Y. 10017</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113615']},
#  {'PJB': 'PJB 8618',
#   'content': '\n<p>Frank Ferrari<br/>\nAfrican American Institute <br/>\n833 United Nations Plaza<br/>\nNew York, N.Y. 10017</p>\n<p>Dear Frank:</p>\n<p>Enclosed is my ticked receipt. I enjoyed sharing my newly learned "expertise" with A.A.I.</p>\n<p>John &amp; I have no hotel expenses. Cab fare came to about $20.00 on both ends.</p>\n<p>Let us know in advance when you come this way.</p>\n<p>cc: John Lewis<br/>\nV.E.P.<br/>\n52 Fairlie St<br/>\nAtlanta, Ga. </p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113616']},
#  {'PJB': 'PJB 8619',
#   'content': '\n<p>March 4, 1974</p>\n<p>Dear Governor Carter:</p>\n<p>I am writing to suggest some closer coordination between your 1974 Democratic election efforts and the Southern Elections Fund.</p>\n<p>The Fund does not involve itself in anyfederal or state-wide campaigns. We have, however, helped elect candidates for higher office by helping lower-level candidates and creating a bottom to top piggy back effect. This year we will concentrate on Georgia, South Carolina and Alabama, with special emphasis on state legislative races.</p>\n<p>We would like to work with you and Ham whene[illegible]er [illegible]ur interests coincide and look forward to a summer of electing good people and throwing out some bad ones.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>The Honorable James Carter <br/>\nState Capitol<br/>\nAtlanta, Georgia</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, Nakole Allen, lbaker</p>',
#   'FTP_page_ids': ['page-35113617']},
#  {'PJB': 'PJB 8620',
#   'content': "\n<p>The Hon. Jimmy Carter<br/>\nState Capitol<br/>\nAtlanta, Georgia</p>\n<p>Dear Governor Carter:</p>\n<p>I'm writing to suggest some closer coordination between your 1974 Democratic election efforts and the Southern Elections Fund.</p>\n<p>The Fund does not involve itself in any federal or state-wide campaigns. We have, however, <strike></strike> helped elect candidates for higher office by helping lower-level candidates and creating a <strike>top to bottom</strike> bottom to top piggy back effect.</p>\n<p>We will concentrat this year on Georgia, South Carolina and Alabama, with special emphasis on state legislative races.</p>\n<p>We'd like to work with you and Ham whenever our interests coincide, and look forward to a summer of electing good people and throwing out some bad ones.</p>\n<p>Sincerely</p>\n<p>blind cc: Yancey Martin  John Lewis</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113618']},
#  {'PJB': 'PJB 8621',
#   'content': "\n<p>March 4, 1974</p>\n<p>Dear Bob:</p>\n<p>Please excuse me for taking so long to write and thank you for being the go-between.</p>\n<p>I enjoyed the SanJuan trip and although things were left more up-in-the-air than on solid ground, I think we've made a be-ginning. How shall we proceed? Will you continue to mid-wife to this impending birth?</p>\n<p>I am interested in both Mr. D raising money for S.E.F&gt; and in his latent ability to pull other Black heavies together, despite what he seems to think about his falling out with his former friends.</p>\n<p>Let me know what you think. I'd like to have an address for him so that I may thank him for the evening.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Bob DeLeon<br/>\nJET Magazine<br/>\nJohnson Publishing Company, Inc. <br/>\n820 SO Michigan Avenue<br/>\nChicago, Ill. 60616</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113619']},
#  {'PJB': 'PJB 8622',
#   'content': "\n<p>Bob DeLeon<br/>\nJET<br/>\n820 N Michigan Ave<br/>\nChicago, Illinois</p>\n<p>Dear Bob:</p>\n<p>Please excuse me for taking so long to write and thank you for being the go-between. <strike>I</strike></p>\n<p>I enjoyed the San Juan trip, and although things were left more up-in-the air than on solid ground, I think we've made a beginning.</p>\n<p>How shall we proceed? Will you continue to be mid-wife to this impending birth?</p>\n<p>I'm interested both in Mr. D. raising money for S.E.F., and in his latent ability to pull other Black heavies toghether, despite what he seems to think about his falling out with his former friends.</p>\n<p>Let me know what you think. I'd like to have an address for him so I can thank him for the evening.</p>\n<p>Sincerely</p>\n<p>blind cc: Yancey Martin</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113620']},
#  {'PJB': 'PJB 8623',
#   'content': '\n<p>March 4, 1974</p>\n<p>Dear Mr. Hall:</p>\n<p>This letter has been written to recommen<strike>f</strike>d Customer Service Representative Winston Johnson of your Atlanta facility.</p>\n<p>On a recent trip to Pittsburgh from Atlanta, Mr. Johnson helped me invaluably. His kindness and consideration do great credit to Eastern Air Lines.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Floyd Hall, President<br/>\nEastern Air Lines<br/>\nMiami International Airport<br/>\nMiami, Florida</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113621']},
#  {'PJB': 'PJB 8624',
#   'content': '\n<p><u>F</u>lo<u>yd</u> <u>H</u>a<u>ll</u><br/>\nPresident<br/>\nEastern Air Lines<br/>\nMiami International Airport<br/>\nMiami, Florida</p>\n<p>Dear _ _ _ _</p>\n<p>I am writing to reccomend Customer Service Representative Winston Johnson of your Atlanta Facility.</p>\n<p>On a recent trip to Pillsburg from Atlanta, Mr. Johnson helped me invaluably.</p>\n<p>His kindness and consideration do great credit to Eastern Air Lines.</p>\n<p>Sincerely</p>\n<p>blind cc: WinstonJohnson<br/>\nCustomer Service Representative<br/>\nEastern Airlines<br/>\n<strike>Atla</strike> Hartsfield International Airport<br/>\nAtlanta, Georgia</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113622']},
#  {'PJB': 'PJB 8625',
#   'content': '\n<p>March 4, 1974</p>\n<p>Dear Mr. Hall:</p>\n<p>I am writing to recommend Supervisor Orville Buck of Atlanta.</p>\n<p>Mr. Buck was extremely helpful to me during a recent trip out of Atlanta. He is always eager to assist anyone in dif-ficulty and makes traveling by Eastern all the more pleasant.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Floyd Hall, President <br/>\nEastern Air Lines<br/>\nMiami International Airport<br/>\nMiami, Florida</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113623']},
#  {'PJB': 'PJB 8626',
#   'content': "\n<p>Floyd Hall<br/>\n<strike>Samuel Higginbottom</strike><br/>\nPresident<br/>\nEastern Air Lines<br/>\nMiami International Airport<br/>\nMiami, Florida</p>\n<p>Dear Mr _ _ _ _:</p>\n<p>I'm writing to reccomend Supervision Orville Buck of Atlanta.</p>\n<p>Mr. Buck was extremely helpful to me during a recent trip out of Atlanta.</p>\n<p>He has always been <strike>L</strike> eager to assist anyone in difficulty and makes traveling by Eastern <strike>much</strike> all <strike>more</strike> the more pleasant.</p>\n<p>Sincerely</p>\n<p>bind cc: Orville Buck<br/>\nSupervisor<br/>\nEastern Air Lines<br/>\n<strike>Atlan</strike> Hartsfield International Airport<br/>\nAtlanta, Georgia</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113624']},
#  {'PJB': 'PJB 8627',
#   'content': "\n<p>March 4, 1974</p>\n<p>Dear Mr. Borenkind:</p>\n<p>Please forgive me for not writing sooner and for not thanking you, before now, for your kind company on the flight to New York last week.</p>\n<p>By copy of this letter, I am having sent to you a copy of the Gulf Oil proposal I mentioned, as well as, some descriptive literature about the Southern Elections Fund. We concentrate solely on local level elections in the 13 states of the Old Confederacy. Over the past 4 years, we have helped elect over 300 mayors, councilmen, county commissioners, state legisla-tors and other assorted city and county officials.</p>\n<p>Our candidates are usually anonomous and cannot raise the relatively small <strike>o</strike>amounts of money their campaigns require - $500 to $3000 - from their intended constituents. We provide a portion - sometimes one half - of th<strike>i</strike>e<strike>e</strike>ir campaign funds, as well as, advice and expertise on organizing and campaign techniques. Because we are not involved in federal campaigns, we are eligible to receive corporate contributions.</p>\n<p>The Gulf proposal you will receive may have been stymied, be-cause I am involved in the boycott protesting Gulf's investments in white minority dominated Africa. If that is the case, then Gulf's reluctance - or unwillingness - to support an organisat<strike>u</strike>ion headed by someone who is interested in uing econ<strike>i</strike>omic sanctions against them is understandable, and we will search elsewhere for the funds we so badly need to continue our work.</p>\n<p>If you are able to expidite our request, or is you can determine whether Gulf is worth persuing, we'll be more htan grateful.</p>\n \n<p>Atty. Samuel H. Borenkind<br/>\nMarch 4, 1974<br/>\nPage two</p>\n<p>I would be remiss if I didn't, also, ask if you could direct us to other possible sources as well. I believe that our work represents a logical continuation of the nonviolent civil rights movement of the late '50s and early '60s. We are help-ing to democratize Southern politics, and firmly believe that the benefits of that process will be felt by Americans every-where and not just the struggling Black and hite citizens of the South.</p>\n<p>Please excuse the length of this letter. The Fund is very close to me, and I have a heavy emotional investment in it.</p>\n<p>Again, thanks for your company and your offer to help.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Attorney Samuel H. Borenkind<br/>\n350 Fifth Avenue<br/>\nNew York, New York 10001</p>\n<p>JB/jj<br/>\ncc. Mr. Yancey Martin, Executive Director<br/>\nSouthern Elections Fund</p>\n \n \n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113625',
#    'page-35113626',
#    'page-35113627',
#    'page-35113628']},
#  {'PJB': 'PJB 8628',
#   'content': "\n<p>Dear Mr. Borenkind:</p>\n<p>Please forgive me for not <strike>answeri</strike> writing sooner and for not thanking you before now for your kind company on the flight to New York last week.</p>\n<p>By copy of this letter, I'm having you sent a copy of the Gulf Oil proposal I mentioned as well as some descriptive literature about the Southern Elections Fund.</p>\n<p>We concentrate solely on local level elections in the 13 states of the Old Confederacy. Over the past 4 years, we've helped elect over 300 mayors, councilmen, county commissioners, state legislators and other assorted city and county officials.</p>\n<p>Our candidates are usually anonomous, and cannot raise the relatively small amounts of money their campaigns require - $500 to $3000.00 - from their intended constituencies.</p>\n<p>We provide a portion - sometimes one half - of their campaign funds, as well as <strike>technical</strike> advice and ex-pertise on organizing and campaign techniques.</p>\n<p>Because we are not involved in <strike>camp</strike> federal campaigns, we are eligible to receive corporate con-tributions. </p>\n \n<p>The Gulf proposal you'll receive may have been stymied because I am involved in the boycott protesting Gulf's investments in white minority dominated Africa.</p>\n<p>If that is the cae, then Gulf's reluctance - or unwillingness - to support an organization headed by someone who is interested in using economic sanctions against them is understandable, and we will search elsewhere for the funds we so badly need to continue our work.</p>\n<p>If you are able to expidite our request, or if you can determine whether Gulf is worth persuing, we'll be more <strike>tha</strike> than grateful.</p>\n<p>I would be remiss if I didn't also ask if you could direct us to other possible sources as well.</p>\n<p>I believe that our work rep-resents a logical continuation of the nonviolent civil rights movement of the late '50s and early '60s.</p>\n<p>We are helping to democratize Southern politics, and firmly believe that the benefits of that process will be felt by Americans everywhere and not just the struggling Black and white citizens of the South.</p>\n \n<p>Please excuse the length of this letter. The Fund is very close to me, and I have a heavy emotional investment in it.</p>\n<p>Again, thanks for your company and your offer of help.</p>\n<p>Sincerely</p>\n<p>cc: Yancey Martin<br/>\n- - - <br/>\n- -  - - </p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113629', 'page-35113630', 'page-35113631']},
#  {'PJB': 'PJB 8629',
#   'content': "\n<p>March 4, 1974</p>\n<p>Dear Ed:</p>\n<p>It was good talking to you at Fleetwood's the other night.</p>\n<p>I have enclosed some recent copies of <u>Black Enterprise</u> magazine and by copy of this letter I'm having the Southern Elections Fund send you a packet of materials about our work.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Edward Elson<br/>\nElson's Book Stores<br/>\n3393 Peachtree Road, N.E.<br/>\nAtlanta, Georgia</p>\n<p>J[illegible]/jj<br/>\ncc. Mr. Yancey Martin, Executive Director<br/>\nSouthern Elections Fund<br/>\nencl. 2 issues <u>Black Enterprise</u> magazine</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113632']},
#  {'PJB': 'PJB 8630',
#   'content': "\n<p>Edward</p>\n<p><strike>Robert</strike> Elson<br/>\nElson's Book Stores<br/>\n-- -- -- -- --  <br/>\nAtlanta, Georgia</p>\n<p>Dear <strike>[illegible]</strike> Ed:</p>\n<p>It was good talking to you at Fleetwood's the other night.</p>\n<p>I'm enclosing some recent copies of <u>Black Enterprise</u> magazine, and by copy of this letter I'm having the Southern Elections Fund send you a <strike>[illegible]</strike> packet of materials about our work.</p>\n<p>Sincerely</p>\n<p>enc: 2 issues, <u>Black Enterprise</u> magazine</p>\n<p>cc: Yaucet Martin</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113633']},
#  {'PJB': 'PJB 8631',
#   'content': "\n<p>March 4, 1974</p>\n<p>Dear Harvey:</p>\n<p>I'm sorry the evening passed so quickly last week and we weren't able to compare additional Kentucky notes.</p>\n<p>I am in and out of New York about once a month. I hope we can have lunch sometime and continue our rememberances.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Harvey Russell, Vice President<br/>\nCommunity Affairs<br/>\nPepsico, Inc.<br/>\nPurchase, New York 10577</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113634']},
#  {'PJB': 'PJB 8632',
#   'content': "\n<p>Harvey Russell, <strike>Executive</strike> V. P.<br/>\n(Ask John Lewis for address)<br/>\nPepsi-Cola Company<br/>\n-- -- -- -- -- --<br/>\nNew York, New York</p>\n<p>Dear Harvey:</p>\n<p>I'm sorry the evening passed so quickly last week and we weren't able to compare additional Kentucky notes.</p>\n<p>I'm in and out of New York about once a month. I hope we can have lunch sometime and continue our <strike>[illegible]</strike> rememberances.</p>\n<p>Sincerely</p>\n<p>[Scribbles]:<br/>\n3/4/74<br/>\nCalled for required addon... VEP to [illegible] call ___</p>\n<p>522-74[illegible]5</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113635']},
#  {'PJB': 'PJB 8633',
#   'content': '\n<p>Heritage<br/>\nBen H. Garfinkel<br/>\nPresident<br/>\n170 North Robertson Boulevard <br/>\nBeverly Hills, California  (213) 657-4500</p>\n \n<p>March 5, 1974</p>\n<p>Dear Ben:</p>\n<p>It was good to see you in San Juan. I was there to see Mr. D. on behalf of an organization called the Southern Elections Fund.</p>\n<p>I have asked the S.E.F. office to send you a packet of materials about our work. We have helped elect nearly 400 local level officials over the past 4 years, and intend to be heavily involved in state legislative elections in Alabama, Georgia and South Carolina this summer.</p>\n<p>Because we are not involved in federal elections, we are eligible to recieve corporate contributions. That was part of my reason for seeing Mr. D., to solicity his personal support as well as his help in attracting other supporters.</p>\n<p>We have a thousandaire club; if you care to join after you have looked over our material, send us a check. If not, may light enter your dark rooms, and may developing fluid stain your necktie.</p>\n<p>Seriously, folks, I hope to see you when next I venture west. If you find yourself in this part of the country,please let me know.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, Katelynn Lee, lbaker</p>',
#   'FTP_page_ids': ['page-35113636', 'page-35113637']},
#  {'PJB': 'PJB 8634',
#   'content': "\n<p>Dear Ben:</p>\n<p>It was good to see you in San Juan.</p>\n<p>I was there to see Mr. D. on behalf of an organization called the Southern Elections Fund.</p>\n<p>I'm asking the S.E.F. office to send you a packet of materials about our work.</p>\n<p>We <strike>b</strike> have helped <strike>[illegible]</strike> elect nearly 400 local level officials over the past 4 years, and intend to be heavily involved in state legislative elections in Alabama, Georgia, and South Carolina this summer.</p>\n<p>Because <strike>we're</strike> we are not involved in federal elections we are eligible <strike>for</strike> to receive corporate contributions. That was part of my reason for seeing Mr. D., to solicit his personal support as well as his help in attracting other supporters.</p>\n<p>We have a <strike>1000</strike> thousandaire club; if you care to join after you've looked over our material, send us a check.</p>\n<p>If not, may light enter your dark-rooms, and may developing fluid stain your necktie.</p>\n<p>Seriously, folks, I hope to see you when next I venture west.</p>\n<p>(over)</p>\n \n<p>If you find yourself in this part of the country, please let me know.</p>\n<p>Sincerely</p>\n<p>blind co. Yaucey Martin</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113638', 'page-35113639']},
#  {'PJB': 'PJB 8635',
#   'content': "\n<p>March 5, 1974</p>\n<p>Dear Willie:</p>\n<p>I am sorry about Alice and I will not be able to attend your birthday gala on March 17th.</p>\n<p>I would like to wish you many happy returns of the day and express my own appreciation for your friendship over the years.</p>\n<p>Make no mistake about it, Willie, you have brought a new standard to the profession we share, the practice of politics. We both belong to the finest body of men that money can buy, and are both proud, I'm sure, that we serve in the world's second oldest profession.</p>\n<p>Happy Birthday, Willie. Serve on and on in the knowledge that you occupy a position of leadership far above the elected office you hold; you have earned the respect of your peers, in California and throughout the Unied States.</p>\n<p>With every best wish,</p>\n<p>Julian Bond</p>\n<p>The Honorable Willie Brown, Distinguished Chairman<br/>\nThe Powerful Ways and Means Committee<br/>\nState Capitol<br/>\nSacremento, California</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113640']},
#  {'PJB': 'PJB 8636',
#   'content': "\n<p>The Hon Willie Brown<br/>\nDistinguished Chairman<br/>\nThe Powerful Ways and Means Committee<br/>\nState Capitol<br/>\nSacremento, California</p>\n<p>Dear Willie</p>\n<p>I'm sorry that Alice and I won't be able to attend your birthday gala on March 17.</p>\n<p>I did want to wish you many happy returns of the day and express my own appreciation for your friendship over the years.</p>\n<p>Make no mistake about it, Willie, you have brought a new standard to the profession we share, the practice of politics.</p>\n<p>We both belong to the finest body of men that money can buy, and are both proud, I'm sure, that we serve in the world's second oldest profession.</p>\n<p>Happy Birthday, Willie. Serve on and on in the knowledge that you occupy a position of leadership far above the elected office you hold; you have <strike>[illegible]</strike> earned the respect of your peers, in California and through- out the United States.</p>\n<p>With every best wish,</p>\n<p>Julian Bond</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113641']},
#  {'PJB': 'PJB 8637',
#   'content': "\n<p>March 5, 1974</p>\n<p>Dear Walter:</p>\n<p>I'm sorry I couldn't make the Tuesday meeting. Our legislative gymnastics have made any kind of planning difficult.</p>\n<p>I hope some kind of central planning for the '74 elections emerged from the gathering. It's crucial, I think, for everyone to know what everyone is doing, and for everyone to have access to the same facts and figures and knowledge about candidates. It would be ideal to have John Lewis serving as a data bank for Southern, non partisan information and the S.E.F. as a channel for partisan information on who's running against whom.</p>\n<p>We are tying in with Governor Carter's Democratic Re-election and election effort as an informational adjunct (since S.E.F. stays out of federal elections) and hope to have a good look at who's who through that medium.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>The Honorable Walter Fauntroy<br/>\nMember of Congress<br/>\nHouse Office Building<br/>\nWashington, D.C. 20515</p>\n<p>JB/jj<br/>\ncc. </p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113642']},
#  {'PJB': 'PJB 8638',
#   'content': "\n<p>The Hon Walter Fauntroy<br/>\nMember of Congress<br/>\nHouse Office Bldg.<br/>\nWashington D.C.</p>\n<p>Dear Walter:</p>\n<p>I'm sorry I couldn't make the Tuesday meeting.</p>\n<p>Our legislative gymnastics have made any kind of planning difficult.</p>\n<p>I hope some kind of central planning for the '74 elections emerged from the gathering.</p>\n<p>It's crucial, I think, for everyone to know what everyone is doing, and for everyone to have access to the same facts and figures and knowledge about candidates.</p>\n<p>It would be ideal to have John Lewis serving as a data bank for Southern, non-partisan information and the S.E.F. as a channel for partisan information on who's running against whom.</p>\n<p>We are tying in with Governor Carter's Democratic Re-election and election effort <strike>for</strike> as an informational adjunct (since S.E.F. stays out of federal elections) and hope to have a good look at who's who through that medium.</p>\n<p>Sincerely.</p>\n<p>(over)</p>\n \n<p>blind cc: John Lewis</p>\n<p>Yaucey Martin</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113643', 'page-35113644']},
#  {'PJB': 'PJB 8639',
#   'content': "\n<p>March 5, 1974</p>\n<p>Dear Ms. Davis:</p>\n<p>Thank you for your kind letter and also for choosing to write about me in your English class report.</p>\n<p>I have enclosed a biographical sketch, picture, and a few published speeches which I'm quite sure will enable you to give a good report.</p>\n<p>Good luck in your endeavors and remember to study hard, study strong, but never study wrong.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Ms. Dian Davis<br/>\n4119 East 26th Street<br/>\nKansas City, Missouri 64127</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>",
#   'FTP_page_ids': ['page-35113645']},
#  {'PJB': 'PJB 8640',
#   'content': '\n<p>4119 East 26 Street<br/>\nKansas City, Missouri<br/>\n64127</p>\n<p>Mr. Julian Bond<br/>\n162 Euharlee Street<br/>\nAtlanta, Georgia</p>\n<p>Dear Mr. Bond:</p>\n<p>My name is Dian Davis. I am an eigthth grade student at Central Junior High School in Kansas City Missouri . I am writing to tell you that I am writing a report on you in my English class. I would like to ask if you could give me some information on yourself, such as place of birth, your parentage, hobbies, and one of your most important decisions, and also a picture of you. I am learning more about outstanding American Blacks. Being a young black, I am very proud of the progress of our people. You, among many other blacks, are a inspiration to black youth of today. Please let me hear from you.</p>\n<p>Yours truly,<br/>\nDian Davis</p>\n<p>[Scribble]: Circle around "and also a picture of you"</p>\n<p>[Scribble]: bio (with a circle around it</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>',
#   'FTP_page_ids': ['page-35113646']},
#  {'PJB': 'PJB 8641',
#   'content': '\n<p>March 5, 1974</p>\n<p>Dear Sirs:</p>\n<p>Some weeks ago, Journal columnist, John Crown, wrote disparagingly of efforts to repeal the Byrd Amendment, enected by Congress in 1971 to override U.S. supported sanctions against the importation of strategic materials from white-minority dominated Rhodesia.</p>\n<p>The United States Senate has already voted for repeal; the issue will be voted on by the House in the next few weeks.</p>\n<p>The Byrd Amendment has threatened the jobs of American ferrochrome workers, has made the United States an international outlaw who supports a racist regime whose legitimacy is not recognized by any country in the world, and endangers our claim to the friendship of the independent African states.</p>\n<p>Because Rhodesian chrome and other materials are produced by forced labor denied the right to strike or bargain collectively, it is produced at a rate too low for American labor to compete with. Already, ferrochrome workers in Ohio and South Carolina have lost their jobs.</p>\n<p>The Byrd Amendment does not increase American dependence on chrome from the Soviet Union; the United States Department of Defense has estimated that we have enough chrome ore in stockpile to supply the military for 40 years of war, and Rhodesian chrome imports in 1973 were only ½ of one per cent. Both Secretary of State Henry Kissinger</p>\n \n<p>[cut from the page]: Letters to the Editor<br/>\nAtlanta Journal<br/>\nMarch 5, 1974<br/>\nPage two</p>\n<p>and Peter N. Flanigan, Assistant to President Nixon for International Economic Affairs, have stated that imports of Rhodesian chrome and nickel are not necessary for United States security or strategy. The Byrd Amendment does place us in violation of international sanctions imposed by the United Nations, and supported originally by the United States.</p>\n<p>In Rhodesia, 5% of the population - the white settlers - rule 95% of the population - the Black natives. Prime Minister Ian Smith answered "never" when he was asked when a phased hand-over to majority rule could be begun. The Rhodesian system of apartheid is matched only by that in South Africa.</p>\n<p>Sanctions against the Smith regime may be the last non-violent means of bringing the rule of law to that country before the native population decides to follow the example set by America in 1776 and turns toward violence to establish themselves as the rightful rulers of their homeland.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Letters to the Editor<br/>\nAtlanta Journal<br/>\n72 Marietta Street, N.W.<br/>\nAtlanta, Georgia, 30303</p>\n<p>Thanks to FromThePage transcription contributors: Katelynn Lee, lbaker</p>',
#   'FTP_page_ids': ['page-35113647', 'page-35113648']},
#  {'PJB': 'PJB 8642',
#   'content': '\n<p>Letters to the Editor<br/>\nAtlanta Journal<br/>\nxzxz Marietta Street<br/>\nAtlanta, Georgia</p>\n<p>Dear Sirs:</p>\n<p>Some weeks ago <u>Journal</u> columnist<strike>s</strike> John Crown wrote disparagingly of efforts to repeal the Byrd Amendment, enacted by Congress in 1971 to overide U.S. supported sanctions against the importation of strategic materials from white-minority dominated Rhodesia.</p>\n<p>The United States Senate has already voted for repeal: the issue will be voted on by the House in the next few weeks.</p>\n<p>The Byrd Amendment has threatened the jobs of American ferrochrome workers, has ma<strike>k</strike>de<strike>s</strike> the United States an international outlaw who supports a racist regime <strike>notzxsxxxixxd</strike> whose legitimacy is not recognized by any country in the world, and endagers our claim to the friendship of the independent Arfican states.</p>\n<p>Because Rhodesian chrome and other mater<strike>a</strike>ials are produced by by forced labor denied the right to strike or bargain collectively, it is produced at a rate <strike>below that</strike> too low for American labor to compete with. Already, ferrochrome workers in Ohio and South Carolina <strike>x</strike>have lost their jobs.</p>\n<p>The Byrd Amendment does not increase American dependence on chrome from the Soviet Union; the United States Department of Defense has estimated that we have enough chrome ore in stockpile to supply the military for 40 years of war, and Rhodesian chrome imports in 1973 were only 1/2 of of one per cent. Both Secretary of State Henry Kissi<strike>g</strike>nger and Peter N. Flan<strike>a</strike>igan, Assistant to President Nixon for International Economic Affairs, have stated that imports The Byrd Amendment does place us i<strike>m</strike>n violation of of international sanctions imposed by the United Nationsa, and supported originally by <strike>UxxSx</strike> the U.S. of Rhodesian chrome and nickel are not necessary for U.S. security or strategy</p>\n<p>In Rhodesia, 5% of the population - the white settlers - rule 95% of the population - the black natives. Prime Minister Ian Smith answered "never" when he was asked when a phased hand-over to majority rule could be beg<strike>i</strike>un. The Rhodesian system of apartheid is matched only by that <strike>the</strike> in South Africa.</p>\n<p>Sanctions against the Smith regime may be the last non-violent means of bring-ing the rule of law to that country before the native population decides to follow the example set by America in 1776 and turns toward violence to esta-blish themselves as the rightful rulers of their homeland.</p>\n<p>Sincerely,</p>\n<p>blind cc: Washington office on Africa<br/>\n110 Maryland Avenue, N E<br/>\nWashington, D.C. 20002</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113649']},
#  {'PJB': 'PJB 8643',
#   'content': "\n<p>March 5, 1974</p>\n<p>Dear Mr. Crosby:</p>\n<p>It was a pleasure meeting you in New York.</p>\n<p>By copy of this letter, I am asking the Southern Elections Fund to send you copies of the letters to Southern Black elected officials sent out by us when the Byrd Amendment was in the Senate.</p>\n<p>We're waiting for word from Digg's committee before a similar letter is sent to put pressures on members of the House.</p>\n<p>I am, also, having some material on the Fund sent to you, so that you may see what great works we're involved in. We are increasingly interested not only in electing new people, but also educating them about what we think are important domestic and international issues.</p>\n<p>Please let me know how the campaign for the Washington Office on Africa goes; I have an interest in fund-raising generally, and would like to compare techniques.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Edwin L. Crosby<br/>\n5995 Ridge Road<br/>\nExcelsior, Minn. 55331</p>\n<p>JB/jj<br/>\ncc: Mr. Yancey Martin, Executive Director <br/>\nSouthern Elections Fund</p>\n<p>Thanks to FromThePage transcription contributors: Sophia Melo-Malnowski, lbaker</p>",
#   'FTP_page_ids': ['page-35113650']},
#  {'PJB': 'PJB 8644',
#   'content': "\n<p>Dear Mr. Crosby,</p>\n<p>It was a pleasure meeting you in New York.</p>\n<p>By copy of this letter, I'm asking the Southern Elections Fund to send you copies of the letters to Southern Black elected officials sent out by us when the Byrd Amendment was in the Senate.</p>\n<p>We're waiting for word from Digg's committee before a similar letter is sent to put pressures on members of the House.</p>\n<p>I'm also having some material on the Fund sent to you, so you can see what great works we're involved in.</p>\n<p>We are increasingly interested not only in electing new people, but also in education them about what we think are important domestic and international issues.</p>\n<p>Please let me know how the campaign for the Washington Office on Africa goes; I have an interest in fund-raising generally, and would like to compare techniques.</p>\n<p>Sincerely,</p>\n<p>Thanks to FromThePage transcription contributors: Sophia Melo-Malnowski, lbaker</p>",
#   'FTP_page_ids': ['page-35113651']},
#  {'PJB': 'PJB 8645',
#   'content': '\n<p><sup>Edwin L. Crosby<br/>\n<strike>Route 4, Box 138</strike><br/>\n5995 Ridge Road<br/>\nExcelsior, Minnesota 55331</sup></p>\n<p>Feb 15, 1974</p>\n<p>Dear Mr. Bond,</p>\n<p>I am writing to ask your help in raising money for a group called the Washington Office on Africa. This is the principal group which is lobbying to repeal the "Byrd Ammendment". As you know, the Byrd Amendment is the bill which allows us to import chrome and other metals from Rhodesia.</p>\n<p>The help I would like from you is your signiture on a fund-raising letter which will be sent out to about 1600 people who are working in the area of African studies. I know there is not a great deal of money in this group, but our hope is that some of them will also help in organizing better writing camp-aigns, etc.</p>\n<p>Rep. Don fraser and Richard Lolar (a professor at UCLA who is known in African Studies) have agreed to sign the letter. Besides</p>\n \n<p>your signature, I also hope to get the signature of Abraham Vilakasi (a black Suth African who is currently head of the African Studies Assn.). You will find a copy of the letter enclosed, together with a copy of a brochure which will be sent with the better. <strike>and</strike> Also enclosed are a copy of a letter from Sen. McDee and an article from the Johannesburg<u>Star</u> in order to substantiate the quotes in the letter. The letter of course would not be included in the mailing.</p>\n<p>I have no formal connection with the Washington Office, but am deeply committed ro repeating the Byrd Ammend. Therefore I am trying to help them raise an additional $10,000 to lobby the bill through the House. I am obviously trying other avenues for raising money besides this letter to people in African Studies.</p>\n<p>I hope to be seeing you the evening of Wed. Feb 20 since I am on the Board of the African-American Institute. If you want to sign the letter, I hope to have a copy available of that time which you could sign.</p>\n<p>Yours sincerely,<br/>\nNed Crosby</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113652', 'page-35113653']},
#  {'PJB': 'PJB 8646',
#   'content': '\n<p>March 5, 1974</p>\n<p>Dear Mr. Marshall:</p>\n<p>Please forgive me for not answering your February 6th letter sooner.</p>\n<p>I have had to close my office, and unlike my colleagues in California, Georgia lawmakers are not provided with clerical staff or office space. Therefore, I am forced to rely on the kindness of the occasional volunteer to answer my mail.</p>\n<p>I could not have made the March 9th date, because of a previous commitment, but I do apologize for taking so long to answer your letter.</p>\n<p>I sincerely hope I did not inconvenience you.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Mr. Tim Marshall, Promotional Director<br/>\nThe Black Scholar<br/>\nP.O. Box 908<br/>\nSauslito, California 94965</p>\n<p>JB/jj<br/>\ncc.</p>\n<p>Thanks to FromThePage transcription contributors: Sophia Melo-Malnowski, lbaker</p>',
#   'FTP_page_ids': ['page-35113654']},
#  {'PJB': 'PJB 8647',
#   'content': "\n<p>Dear Mr. Marshall:</p>\n<p>Please forgive me for not answering your February 6th letter sooner.</p>\n<p>I have had to close my office, and unlike my colleagues in California, Georgia lawmakers are not provided with clerical staff or office space.</p>\n<p>Therefore I'm forced to rely on the kindness of the occasional volunteer to answer my mail.</p>\n<p>I could not have made the March 9th date because of a previous commitment, but I do apologize for taking so long to answer your letter.</p>\n<p>I hope I didn't inconvenience you.</p>\n<p>Sincerely,</p>\n<p>Thanks to FromThePage transcription contributors: Sophia Melo-Malnowski, lbaker</p>",
#   'FTP_page_ids': ['page-35113655']},
#  {'PJB': 'PJB 8648',
#   'content': '\n<p><sup>The Black Scholar<br/>\n<i>Journal of Black Studies and Research</i><br/>\nBox 908 (2658 Bridgeway), Sausalito, California 94965 * (415) 332-3130</sup></p>\n<p>Nathan Hare<br/>\nPublisher<br/>\nRobert Chrisman<br/>\nEditor<br/>\nRobert L. Allen<br/>\nAssociate Editor<br/>\nGlory Bevien<br/>\nExecutive Secretary</p>\n<p>February 6, 1974</p>\n<p>Hon. Julian Bond<br/>\nRepresentative, District 32<br/>\n266 Sunset Avenue, N.W. <br/>\nAtlanta, Georgia 30314</p>\n<p>Dear Brother Bond,</p>\n<p>The services of The Black Scholar Speakers Bureau have been retained in securing your services for a speaking engagement at a Canadian university near Toronto during the second week in March.</p>\n<p>The themes for the Black History Week Conference are "The Political Con-sciousness of Black People in the New World" and "The Political Revolution of Black People". A forum on "Afro-Carribean Relations in North America"; workshops on Black art, dance and drama; and poetry seminars are all scheduled for this activity filled week. The target date for your speaking engagmenet is Saturday, March 9, 1974.</p>\n<p>Please advise me of your availability on the above mentioned date and/or any date during the second week in March, fee, and any additional expenses you require.</p>\n<p>Also, enclosed please find a copy of a letter mailed to all affiliates of the Black Scholar Speakers Bureau. We are in the process of enlarging and crystallizing the bureau and would be very happy to have you join us.</p>\n<p>I look forward to hearing from you as well as working with you in the near future.</p>\n<p>Respectfully,<br/>\n[Tim Marshall signature]<br/>\nTim Marshall <br/>\nPromotional Director</p>\n<p>TM:1b<br/>\nencl.</p>\n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>',
#   'FTP_page_ids': ['page-35113656']},
#  {'PJB': 'PJB 8649',
#   'content': "\n<p><sup>The Black Scholar<br/>\n<i>Journal of Black Studies and Research</i><br/>\nBox 908 (2658 Bridgeway), Sausalito, California 94965 * (415) 332-3130</sup></p>\n<p>Nathan Hare<br/>\nPublisher<br/>\nRobert Chrisman<br/>\nEditor<br/>\nRobert L. Allen<br/>\nAssociate Editor<br/>\nGlory Bevien<br/>\nExecutive Secretary</p>\n<p>To: Affiliates - Speakers Bureau<br/>\nFrom: Promotions Department</p>\n<p>Dear Brothers and Sisters,</p>\n<p>This letter. comes at a time when our people are feeling the increasing shock waves of a failing nation. Endless crises reveal themselves, yet, none of them are new to us; for all we know they will confront us with greater intensity and heightened sophistication.</p>\n<p>It is imperative, therefore, that we come closer and rid ourselves of any communi-cation gaps. We must build a communications network with unparalled cohesion and direction, and lay the basis for a principled unity which will ultimately forge an untarnished freedom.</p>\n<p>It is with this vision in mind that THE BLACK SCHOLAR SPEAKERS BUREAU was founded three years ago. Since that time, the bureau has provided lectures, lecture-demonstrations, cultural presentations, film showings, black studies and black history workshops and seminars to colleges and universities, and professional and community organizations across the country. Literally thousands of black people have been exposed to some fo the most talented and advanced thinkers and activists among this country's celebrated black figures via the speakers bureau.</p>\n<p>We at THE BLACK SCHOLAR think you are making a meaningful contribution towards the complete freedom of black people. Our purpose is to do the same. TOGETHER we comprise the first national, all black speakers bureau of real consequence in this country. NOW is the time for u to consolidate our energies resources and increase our activity so that we will grow qualitatively and quantitatively.</p>\n<p><u>What Can You Do?</u></p>\n<p>A) Well, you can begin by sending an up-dated vita, recent press clippings, an 8x 10 glossy print photo, and a complete listing of 1974 bookings to date. (Note: If possible, please include a condensed, one page vita that can be duplicated and forwarded to the various applicants engaging your services, as well as an extended vita for TBSSB files. Please send as many clippings and photos as you can possibly spare. Include all home and business addresses and telephone numbers where you can be reached. At least once per month send in new dates booked (even bi-weekly or weekly according to the regularity with which you book dates). Include your social security number. </p>\n \n<p>Thanks to FromThePage transcription contributors: Amira Dennis, lbaker</p>",
#   'FTP_page_ids': ['page-35113657', 'page-35113658']},
#  {'PJB': 'PJB 8650',
#   'content': '\n<p>March 1, 1974</p>\n<p>Dear Rev. Pinkney:</p>\n<p>Thank you for your kind note. Your encyclopedia project sounds like it will be of great interest to all people in generations to follow.</p>\n<p>I have enclosed several pieces of literature that should prove to be helpful to you.</p>\n<p>Sincerely,</p>\n<p>Julian Bond</p>\n<p>Rev. J.F. Pinkney<br/>\n709 Kennedy Drive<br/>\nAdel, Georgia</p>\n<p>JB/jj<br/>\ncc.<br/>\nencl.</p>\n \n<p><strike>753-0519</strike></p>\n<p>688-6186</p>\n<p>Thanks to FromThePage transcription contributors: Sophia Melo-Malnowski, lbaker</p>',
#   'FTP_page_ids': ['page-35113659', 'page-35113669']},
#  {'PJB': 'PJB 8651',
#   'content': '\n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113660']},
#  {'PJB': 'PJB 8652',
#   'content': '\n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113661']},
#  {'PJB': 'PJB 8653',
#   'content': '\n \n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113666', 'page-35113665']},
#  {'PJB': 'PJB 8654',
#   'content': '\n \n \n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113662', 'page-35113663', 'page-35113664']},
#  {'PJB': 'PJB 8655',
#   'content': '\n \n<p>Thanks to FromThePage transcription contributors: lbaker</p>',
#   'FTP_page_ids': ['page-35113667', 'page-35113668']}]

# %%
os.chdir('PDF experimentation/output CSVs')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 os.chdir('PDF experimentation/output CSVs')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'PDF experimentation/output CSVs'

# %%
# no worries it's just because I'm already in that directory, if I run the script top to bottom it's all good

# %%
to_remove = []
for page in merged_pages:
    if len(page['content']) >= 2700: # this obviously can and should be higher, but just as an example
        pjb_id = page['PJB']
        text = page['content']
        with open(f"{pjb_id}_output.txt", "w", encoding="utf-8") as f:
            f.write(text)
        to_remove.append(page)
    
for page in to_remove:
    merged_pages.remove(page)

# %%
export = pd.DataFrame(merged_pages)

# %%
export
# Out:
#          PJB                                            content  \
# 0   PJB 8601  \n<p>March 1, 1974</p>\n<p>Dear Ms. Henzie,</p...
# 1   PJB 8602  \n<p><sup>big other matter</sup></p>\n<p>212 H...
# 2   PJB 8603  \n<p>March 1, 1974</p>\n<p>Dear Mr. Hamburger,...
# 3   PJB 8604  \n<p>Thanks to FromThePage transcription contr...
# 4   PJB 8605  \n<p>March 1, 1974</p>\n<p>Dear Mr. Williams:<...
# 5   PJB 8606  \n<p>Thanks to FromThePage transcription contr...
# 6   PJB 8607  \n<p>March 1, 1974</p>\n<p>Dear Abe:</p>\n<p>O...
# 7   PJB 8608  \n<p><sup>24</sup></p>\n<p>Dear <u>[Rep. Julia...
# 8   PJB 8609  \n<p>March 2, 1974</p>\n<p>Dear Yancey:</p>\n<...
# 9   PJB 8610  \n<p>Yancey Martin<br/>\nS.E.F. <br/>\n87 Walt...
# 10  PJB 8611  \n<p>March 2, 1974</p>\n<p>Yancey:</p>\n<p>The...
# 11  PJB 8612  \n<p>Yancey:</p>\n<p>These are the lists I men...
# 12  PJB 8614  \n<p>Thanks to FromThePage transcription contr...
# 13  PJB 8615  \n<p>March 4, 1974</p>\n<p>Dear Dr. Daugherty:...
# 14  PJB 8616  \n<p>Dr. Howard Daugherty <br/>\nFaculty of En...
# 15  PJB 8617  \n<p>March 4, 1974</p>\n<p>Dear Frank:</p>\n<p...
# 16  PJB 8618  \n<p>Frank Ferrari<br/>\nAfrican American Inst...
# 17  PJB 8619  \n<p>March 4, 1974</p>\n<p>Dear Governor Carte...
# 18  PJB 8620  \n<p>The Hon. Jimmy Carter<br/>\nState Capitol...
# 19  PJB 8621  \n<p>March 4, 1974</p>\n<p>Dear Bob:</p>\n<p>P...
# 20  PJB 8622  \n<p>Bob DeLeon<br/>\nJET<br/>\n820 N Michigan...
# 21  PJB 8623  \n<p>March 4, 1974</p>\n<p>Dear Mr. Hall:</p>\...
# 22  PJB 8624  \n<p><u>F</u>lo<u>yd</u> <u>H</u>a<u>ll</u><br...
# 23  PJB 8625  \n<p>March 4, 1974</p>\n<p>Dear Mr. Hall:</p>\...
# 24  PJB 8626  \n<p>Floyd Hall<br/>\n<strike>Samuel Higginbot...
# 25  PJB 8627  \n<p>March 4, 1974</p>\n<p>Dear Mr. Borenkind:...
# 26  PJB 8628  \n<p>Dear Mr. Borenkind:</p>\n<p>Please forgiv...
# 27  PJB 8629  \n<p>March 4, 1974</p>\n<p>Dear Ed:</p>\n<p>It...
# 28  PJB 8630  \n<p>Edward</p>\n<p><strike>Robert</strike> El...
# 29  PJB 8631  \n<p>March 4, 1974</p>\n<p>Dear Harvey:</p>\n<...
# 30  PJB 8632  \n<p>Harvey Russell, <strike>Executive</strike...
# 31  PJB 8633  \n<p>Heritage<br/>\nBen H. Garfinkel<br/>\nPre...
# 32  PJB 8634  \n<p>Dear Ben:</p>\n<p>It was good to see you ...
# 33  PJB 8635  \n<p>March 5, 1974</p>\n<p>Dear Willie:</p>\n<...
# 34  PJB 8636  \n<p>The Hon Willie Brown<br/>\nDistinguished ...
# 35  PJB 8637  \n<p>March 5, 1974</p>\n<p>Dear Walter:</p>\n<...
# 36  PJB 8638  \n<p>The Hon Walter Fauntroy<br/>\nMember of C...
# 37  PJB 8639  \n<p>March 5, 1974</p>\n<p>Dear Ms. Davis:</p>...
# 38  PJB 8640  \n<p>4119 East 26 Street<br/>\nKansas City, Mi...
# 39  PJB 8641  \n<p>March 5, 1974</p>\n<p>Dear Sirs:</p>\n<p>...
# 40  PJB 8643  \n<p>March 5, 1974</p>\n<p>Dear Mr. Crosby:</p...
# 41  PJB 8644  \n<p>Dear Mr. Crosby,</p>\n<p>It was a pleasur...
# 42  PJB 8645  \n<p><sup>Edwin L. Crosby<br/>\n<strike>Route ...
# 43  PJB 8646  \n<p>March 5, 1974</p>\n<p>Dear Mr. Marshall:<...
# 44  PJB 8647  \n<p>Dear Mr. Marshall:</p>\n<p>Please forgive...
# 45  PJB 8648  \n<p><sup>The Black Scholar<br/>\n<i>Journal o...
# 46  PJB 8650  \n<p>March 1, 1974</p>\n<p>Dear Rev. Pinkney:<...
# 47  PJB 8651  \n<p>Thanks to FromThePage transcription contr...
# 48  PJB 8652  \n<p>Thanks to FromThePage transcription contr...
# 49  PJB 8653  \n \n<p>Thanks to FromThePage transcription co...
# 50  PJB 8654  \n \n \n<p>Thanks to FromThePage transcription...
# 51  PJB 8655  \n \n<p>Thanks to FromThePage transcription co...
#
#                                          FTP_page_ids
# 0                                     [page-35113595]
# 1                                     [page-35113596]
# 2                                     [page-35113597]
# 3                                     [page-35113598]
# 4                                     [page-35113599]
# 5                                     [page-35113600]
# 6                      [page-35113601, page-35113602]
# 7       [page-35113603, page-35113604, page-35113605]
# 8                                     [page-35113606]
# 9                                     [page-35113607]
# 10                                    [page-35113608]
# 11                                    [page-35113609]
# 12                                    [page-35113612]
# 13                                    [page-35113613]
# 14                                    [page-35113614]
# 15                                    [page-35113615]
# 16                                    [page-35113616]
# 17                                    [page-35113617]
# 18                                    [page-35113618]
# 19                                    [page-35113619]
# 20                                    [page-35113620]
# 21                                    [page-35113621]
# 22                                    [page-35113622]
# 23                                    [page-35113623]
# 24                                    [page-35113624]
# 25  [page-35113625, page-35113626, page-35113627, ...
# 26      [page-35113629, page-35113630, page-35113631]
# 27                                    [page-35113632]
# 28                                    [page-35113633]
# 29                                    [page-35113634]
# 30                                    [page-35113635]
# 31                     [page-35113636, page-35113637]
# 32                     [page-35113638, page-35113639]
# 33                                    [page-35113640]
# 34                                    [page-35113641]
# 35                                    [page-35113642]
# 36                     [page-35113643, page-35113644]
# 37                                    [page-35113645]
# 38                                    [page-35113646]
# 39                     [page-35113647, page-35113648]
# 40                                    [page-35113650]
# 41                                    [page-35113651]
# 42                     [page-35113652, page-35113653]
# 43                                    [page-35113654]
# 44                                    [page-35113655]
# 45                                    [page-35113656]
# 46                     [page-35113659, page-35113669]
# 47                                    [page-35113660]
# 48                                    [page-35113661]
# 49                     [page-35113666, page-35113665]
# 50      [page-35113662, page-35113663, page-35113664]
# 51                     [page-35113667, page-35113668]

# %% [markdown]
# ### Joining on Title / PJB ID
#
# At some point during this process we will need to perform a join to connect PJB IDs to titles. Though we can avoid duplication at the folder level, there is no surefire way to avoid duplication at a higher level.
#
# This whole process does rely on each document within the folder having a distinctive title. I could presumably also write a script to do it based on a separate list of page counts, though. Would just have to adapt cell [61].

# %%
export.to_csv(f'export_{label}.csv', index=False)
