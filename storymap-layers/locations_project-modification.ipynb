# %% [markdown]
# ## Locations extraction, Series I

# %% [markdown]
# ### Part 1: Regex matching

# %%
import pandas as pd
import requests
import json

# %%
doc_catalog = pd.read_csv('document-catalog-07112025.csv')
uscities = pd.read_csv('uscities.csv')

# %%
doc_catalog[(doc_catalog['ID'] >= 1) & (doc_catalog['ID'] <= 700) & (doc_catalog['Workflow Stage'] == 'Cataloged')].sort_values(by = 'ID').head(30)
# Out:
#        ID               Box  \
# 1752  110   Box 1 Folder 25
# 1771  130   Box 4 Folder 17
# 1770  133    Box 4 Folder 4
# 1769  134    Box 4 Folder 4
# 1768  135    Box 4 Folder 4
# 1799  138    Box 4 Folder 7
# 1798  139    Box 4 Folder 7
# 1797  140    Box 4 Folder 7
# 1796  141    Box 4 Folder 7
# 1795  142    Box 4 Folder 7
# 1794  143    Box 4 Folder 7
# 1784  144    Box 4 Folder 7
# 2061  425               NaN
# 2279  457               NaN
# 2131  495   Box 10 Folder 3
# 2130  496   Box 10 Folder 4
# 2138  526  Box 10 Folder 25
# 2158  539   Box 11 Folder 3
# 2170  558  Box 11 Folder 16
# 2246  636   Box 12 Folder 2
# 2245  637   Box 12 Folder 2
# 2244  638   Box 12 Folder 2
# 2243  639   Box 12 Folder 2
# 2241  641   Box 12 Folder 2
# 2239  643   Box 12 Folder 2
# 2238  644   Box 12 Folder 2
#
#                                                   title  \
# 1752  Duplicate of 458: Address at the Dedication of...
# 1771  Duplicate of ID120: Speech concerning South Af...
# 1770  Duplicate of ID81: Speech  to the Racial Harmo...
# 1769  Duplicate of ID82: Draft, Speech to Racial Har...
# 1768          Duplicate of ID310: Du Bois "Credo," 1904
# 1799  Duplicate of ID86: Speech at Press Conference ...
# 1798  Duplicate of ID87: May the White Blossom of Ba...
# 1797  Duplicate of ID87: Diplomats, newsmen see ruin...
# 1796  Duplicate of ID87: Press Conference Participan...
# 1795  Duplicate of ID86: Largest Hospital in Hanoi R...
# 1794  Duplicate of ID87: Heavy Air Raids in North Vi...
# 1784  Duplicate of ID87: Hanoi is Reported Scarred B...
# 2061  Julian Bond's Tweets, September 2012 - August ...
# 2279                                 Julian Bond Quotes
# 2131  Speech concerning the structure and operation ...
# 2130  Speech- "Civil Rights, Now & Then " delivered ...
# 2138         Speech concerning affirmative action, 2002
# 2158  Research Material for Speech- "The Broken Prom...
# 2170  Ephemera in the folder of speech fragments con...
# 2246  Speech File Material: Facts about Public Housi...
# 2245  Speech File Material: President Nixon's Statem...
# 2244  Speech File Material: “Why Not Another WPA?" b...
# 2243  Speech File Material: Testimony Before Senate ...
# 2241  Speech File Material: Memo from Georgia Depart...
# 2239  Speech File Material: National Urban League Ve...
# 2238  Speech File Material: Reference materials on v...
#
#                                           Document Date  Document Length  \
# 1752                            Sat, 10/18/1969 - 12:00              6.0
# 1771  Mon, 01/01/1973 - 12:00\n - Mon, 12/31/1973 - ...             16.0
# 1770  Sat, 01/01/1972 - 12:00\n - Sun, 12/31/1972 - ...             15.0
# 1769  Sat, 01/01/1972 - 12:00\n - Sun, 12/31/1972 - ...             15.0
# 1768                                                NaN              2.0
# 1799                            Tue, 01/02/1973 - 12:00              6.0
# 1798  Mon, 01/01/1973 - 12:00\n - Mon, 12/31/1973 - ...              2.0
# 1797                            Sat, 12/30/1972 - 12:00              1.0
# 1796                            Wed, 01/03/1973 - 12:00              1.0
# 1795                            Sat, 12/23/1972 - 12:00              1.0
# 1794                            Sun, 12/24/1972 - 12:00              1.0
# 1784                            Mon, 12/25/1972 - 12:00              1.0
# 2061  Sun, 09/09/2012 - 12:00\n - Thu, 08/13/2015 - ...              NaN
# 2279                                                NaN              NaN
# 2131                            Fri, 12/03/1999 - 12:00              5.0
# 2130  Fri, 01/01/1999 - 12:00\n - Fri, 12/31/1999 - ...             23.0
# 2138  Mon, 04/01/2002 - 12:00\n - Tue, 04/30/2002 - ...             23.0
# 2158  Thu, 01/01/2004 - 12:00\n - Fri, 12/31/2004 - ...            118.0
# 2170  Mon, 01/01/1968 - 12:00\n - Tue, 12/31/1968 - ...              7.0
# 2246  Mon, 09/01/1969 - 12:00\n - Tue, 09/30/1969 - ...              2.0
# 2245                            Fri, 06/11/1971 - 12:00              4.0
# 2244                            Sat, 02/06/1971 - 12:00              2.0
# 2243                            Thu, 02/25/1971 - 12:00             41.0
# 2241                            Fri, 05/14/1971 - 12:00              3.0
# 2239                            Fri, 06/02/1972 - 12:00              4.0
# 2238  Mon, 01/01/1973 - 12:00\n - Fri, 02/28/1975 - ...             27.0
#
#                   Manuscript Type                          Collection  \
# 1752                          NaN     Papers of Julian Bond 1897-2006
# 1771                  Typed, Copy     Papers of Julian Bond 1897-2006
# 1770                 Typed, Draft     Papers of Julian Bond 1897-2006
# 1769                 Typed, Draft     Papers of Julian Bond 1897-2006
# 1768                  Typed, Copy     Papers of Julian Bond 1897-2006
# 1799    Handwritten, Typed, Draft     Papers of Julian Bond 1897-2006
# 1798              Typed, Document     Papers of Julian Bond 1897-2006
# 1797                      Printed     Papers of Julian Bond 1897-2006
# 1796              Typed, Document     Papers of Julian Bond 1897-2006
# 1795                        Typed     Papers of Julian Bond 1897-2006
# 1794                        Typed     Papers of Julian Bond 1897-2006
# 1784                        Typed     Papers of Julian Bond 1897-2006
# 2061                          NaN                                 NaN
# 2279                          NaN     Papers of Julian Bond 1897-2006
# 2131           Typed, Handwritten     Papers of Julian Bond 1897-2006
# 2130           Typed, Handwritten     Papers of Julian Bond 1897-2006
# 2138                        Typed     Papers of Julian Bond 1897-2006
# 2158         Handwritten, Printed     Papers of Julian Bond 1897-2006
# 2170   Copy, Handwritten, Printed     Papers of Julian Bond 1897-2006
# 2246                  Typed, Copy     Papers of Julian Bond 1897-2006
# 2245              Typed, Fragment     Papers of Julian Bond 1897-2006
# 2244                Printed, Copy     Papers of Julian Bond 1897-2006
# 2243                        Typed  Papers of Julian Bond 1897-2006\n
# 2241                        Typed     Papers of Julian Bond 1897-2006
# 2239             Autograph, Typed     Papers of Julian Bond 1897-2006
# 2238  Handwritten, Printed, Typed     Papers of Julian Bond 1897-2006
#
#                                                  Source  \
# 1752  Special Collections, University of Virginia Li...
# 1771  Special Collections, University of Virginia Li...
# 1770  Special Collections, University of Virginia Li...
# 1769  Special Collections, University of Virginia Li...
# 1768  Special Collections, University of Virginia Li...
# 1799  Special Collections, University of Virginia Li...
# 1798  Special Collections, University of Virginia Li...
# 1797  Special Collections, University of Virginia Li...
# 1796  Special Collections, University of Virginia Li...
# 1795  Special Collections, University of Virginia Li...
# 1794  Special Collections, University of Virginia Li...
# 1784  Special Collections, University of Virginia Li...
# 2061                                                NaN
# 2279  Special Collections, University of Virginia Li...
# 2131  Special Collections, University of Virginia Li...
# 2130  Special Collections, University of Virginia Li...
# 2138  Special Collections, University of Virginia Li...
# 2158  Special Collections, University of Virginia Li...
# 2170  Special Collections, University of Virginia Li...
# 2246  Special Collections, University of Virginia Li...
# 2245  Special Collections, University of Virginia Li...
# 2244  Special Collections, University of Virginia Li...
# 2243  Special Collections, University of Virginia Li...
# 2241  Special Collections, University of Virginia Li...
# 2239  Special Collections, University of Virginia Li...
# 2238  Special Collections, University of Virginia Li...
#
#                                          Internal Notes Workflow Stage  ...  \
# 1752  Duplicate record that we'll delete after confi...      Cataloged  ...
# 1771  Duplicate of ID120. Do not publish this record...      Cataloged  ...
# 1770  Duplicate of ID81. Do not publish this record ...      Cataloged  ...
# 1769  Duplicate of ID82. Do not publish this record ...      Cataloged  ...
# 1768  Duplicate of ID310. Do not publish this record...      Cataloged  ...
# 1799  Duplicate of ID86. Do not publish this record ...      Cataloged  ...
# 1798  Duplicate of ID87. Do not publish this record ...      Cataloged  ...
# 1797  Duplicate of ID87. Do not publish this record ...      Cataloged  ...
# 1796  Duplicate of ID87. Do not publish this record ...      Cataloged  ...
# 1795  Duplicate of ID86. Do not publish this record ...      Cataloged  ...
# 1794  Duplicate of ID87. Do not publish this record ...      Cataloged  ...
# 1784  Duplicate of ID87. Do not publish this record ...      Cataloged  ...
# 2061  Needs Review: Included in collection so that t...      Cataloged  ...
# 2279  https://docs.google.com/spreadsheets/d/1jwnp-1...      Cataloged  ...
# 2131  Scanning Notes: There is one item in this folder.      Cataloged  ...
# 2130  Scanning Notes: There is one item in this fold...      Cataloged  ...
# 2138  Scanning Notes: There is one item in this folder.      Cataloged  ...
# 2158  Scanning Notes: There are two records for this...      Cataloged  ...
# 2170  Scanning Notes: There are several items in thi...      Cataloged  ...
# 2246  Scanning Notes: There are 13 items in this fol...      Cataloged  ...
# 2245  Scanning Notes: There are 13 items in this fol...      Cataloged  ...
# 2244  Scanning Notes: There are 13 items in this fol...      Cataloged  ...
# 2243  Scanning Notes: There are 13 items in this fol...      Cataloged  ...
# 2241  Scanning Notes: There are 13 items in this fol...      Cataloged  ...
# 2239  Needs review: Check that verso got scanned.\nS...      Cataloged  ...
# 2238  Needs Review: IMAGES: Note is being rescanned ...      Cataloged  ...
#
#                                           Document Body Signature Post Script  \
# 1752                                                NaN       NaN         NaN
# 1771                                                NaN       NaN         NaN
# 1770                                                NaN       NaN         NaN
# 1769                                                NaN       NaN         NaN
# 1768                                                NaN       NaN         NaN
# 1799                                                NaN       NaN         NaN
# 1798                                                NaN       NaN         NaN
# 1797                                                NaN       NaN         NaN
# 1796                                                NaN       NaN         NaN
# 1795                                                NaN       NaN         NaN
# 1794                                                NaN       NaN         NaN
# 1784                                                NaN       NaN         NaN
# 2061  Keywords\nid\nscreen_name\ncreated_at\nfav\nrt...       NaN         NaN
# 2279                                                NaN       NaN         NaN
# 2131                                                NaN       NaN         NaN
# 2130                                                NaN       NaN         NaN
# 2138                                                NaN       NaN         NaN
# 2158                                                NaN       NaN         NaN
# 2170                                                NaN       NaN         NaN
# 2246                                                NaN       NaN         NaN
# 2245                                                NaN       NaN         NaN
# 2244                                                NaN       NaN         NaN
# 2243                                                NaN       NaN         NaN
# 2241                                                NaN       NaN         NaN
# 2239                                                NaN       NaN         NaN
# 2238                                                NaN       NaN         NaN
#
#      Document Extra Marginalia Enclosure Footnote  \
# 1752            NaN        NaN       NaN      NaN
# 1771            NaN        NaN       NaN      NaN
# 1770            NaN        NaN       NaN      NaN
# 1769            NaN        NaN       NaN      NaN
# 1768            NaN        NaN       NaN      NaN
# 1799            NaN        NaN       NaN      NaN
# 1798            NaN        NaN       NaN      NaN
# 1797            NaN        NaN       NaN      NaN
# 1796            NaN        NaN       NaN      NaN
# 1795            NaN        NaN       NaN      NaN
# 1794            NaN        NaN       NaN      NaN
# 1784            NaN        NaN       NaN      NaN
# 2061            NaN        NaN       NaN      NaN
# 2279            NaN        NaN       NaN      NaN
# 2131            NaN        NaN       NaN      NaN
# 2130            NaN        NaN       NaN      NaN
# 2138            NaN        NaN       NaN      NaN
# 2158            NaN        NaN       NaN      NaN
# 2170            NaN        NaN       NaN      NaN
# 2246            NaN        NaN       NaN      NaN
# 2245            NaN        NaN       NaN      NaN
# 2244            NaN        NaN       NaN      NaN
# 2243            NaN        NaN       NaN      NaN
# 2241            NaN        NaN       NaN      NaN
# 2239            NaN        NaN       NaN      NaN
# 2238            NaN        NaN       NaN      NaN
#
#                                                 General  \
# 1752                                                NaN
# 1771                                                NaN
# 1770                                                NaN
# 1769                                                NaN
# 1768                                                NaN
# 1799                                                NaN
# 1798                                                NaN
# 1797                                                NaN
# 1796                                                NaN
# 1795                                                NaN
# 1794                                                NaN
# 1784                                                NaN
# 2061                                                NaN
# 2279                                                NaN
# 2131                                                NaN
# 2130                                                NaN
# 2138                                                NaN
# 2158  Research Material for Speech- "The Broken Prom...
# 2170                                                NaN
# 2246                                                NaN
# 2245                                                NaN
# 2244                                                NaN
# 2243                                                NaN
# 2241                                                NaN
# 2239                                                NaN
# 2238                                                NaN
#
#                                        Image Identifier Response
# 1752                                                NaN      NaN
# 1771                                                NaN      NaN
# 1770                                                NaN      NaN
# 1769                                                NaN      NaN
# 1768                                                NaN      NaN
# 1799                                                NaN      NaN
# 1798                                                NaN      NaN
# 1797                                                NaN      NaN
# 1796                                                NaN      NaN
# 1795                                                NaN      NaN
# 1794                                                NaN      NaN
# 1784                                                NaN      NaN
# 2061                                                NaN      NaN
# 2279                                                NaN      NaN
# 2131        3242858, 3242859, 3242860, 3242861, 3242862      NaN
# 2130  3242835, 3242836, 3242837, 3242838, 3242839, 3...      NaN
# 2138  3242195, 3242196, 3242197, 3242198, 3242199, 3...      NaN
# 2158  3243427, 3243428, 3243429, 3243430, 3243431, 3...      NaN
# 2170  3243186, 3243187, 3243188, 3243189, 3243190, 3...      NaN
# 2246                                   3243822, 3243823      NaN
# 2245                 3243818, 3243819, 3243820, 3243821      NaN
# 2244                                   3243816, 3243817      NaN
# 2243  3243776, 3243777, 3243778, 3243779, 3243780, 3...      NaN
# 2241                          3243769, 3243770, 3243771      NaN
# 2239                 3243757, 3243758, 3243759, 3243760      NaN
# 2238  3243730, 3243731, 3243732, 3243733, 3243734, 3...      NaN
#
# [26 rows x 27 columns]

# %%
drop_cols = ['Document Date', 'Manuscript Type', 'Collection', 'Source', 'Internal Notes',
       'Object Type', 'Author', 'Keywords', 'Head',
       'Document Top', 'Dateline', 'Salutation', 'Document Body', 'Signature',
       'Post Script', 'Document Extra', 'Marginalia', 'Enclosure', 'Footnote',
       'General', 'Image Identifier', 'Response']
missing_docs = missing_docs.drop(drop_cols, axis = 1)

# %%
missing_docs.to_csv('missing_docs.csv')

# %%
early_access = doc_catalog[doc_catalog['Workflow Stage'] == 'Early Access']

# %%
early_access.columns
# Out:
# Index(['ID', 'Box', 'title', 'Document Date', 'Document Length',
#        'Manuscript Type', 'Collection', 'Source', 'Internal Notes',
#        'Workflow Stage', 'Object Type', 'Author', 'Keywords', 'Head',
#        'Document Top', 'Dateline', 'Salutation', 'Document Body', 'Signature',
#        'Post Script', 'Document Extra', 'Marginalia', 'Enclosure', 'Footnote',
#        'General', 'Image Identifier', 'Response'],
#       dtype='object')

# %%
early_access['Document Date'].iloc[0]
# Out:
# 'Thu, 06/28/1984 - 12:00'

# %%
import datetime
import dateutil.parser as parser

# %%
dt = parser.parse(early_access['Document Date'].iloc[0])
dt.year
# Out:
# 1984

# %%
early_access['date_mod'] = early_access.apply(lambda row: row['Document Date'].split('-')[0].strip(' '), axis=1)
early_access['year'] = early_access.apply(lambda row: parser.parse(row['date_mod']).year, axis=1)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_35760\810399839.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   early_access['date_mod'] = early_access.apply(lambda row: row['Document Date'].split('-')[0].strip(' '), axis=1)
# C:\Users\charl\AppData\Local\Temp\ipykernel_35760\810399839.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   early_access['year'] = early_access.apply(lambda row: parser.parse(row['date_mod']).year, axis=1)

# %%
early_access['year'].value_counts()
# Out:
# year
# 1975    58
# 1977    48
# 1971    39
# 1976    34
# 1969    32
# 1972    30
# 1973    20
# 1968    16
# 1970    16
# 1998    12
# 1979    11
# 1988    11
# 1985    11
# 1967    10
# 2004     9
# 1978     9
# 1995     9
# 1990     8
# 2003     8
# 2002     8
# 1992     8
# 1980     7
# 2000     7
# 1991     7
# 2001     7
# 1981     6
# 1993     6
# 1984     5
# 1989     5
# 1999     5
# 1996     5
# 1997     5
# 1974     4
# 1982     4
# 1986     3
# 2005     3
# 1994     2
# 1966     2
# 1987     2
# 1983     2
# 1965     2
# 1964     1
# 1958     1
# 1945     1
# Name: count, dtype: int64

# %%
import numpy as np
np.__version__
# Out:
# '2.3.0'

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
text = "I visited Paris, France, and then hiked in the Alps."
doc = nlp(text)

locations = [ent.text for ent in doc.ents if ent.label_ in ["GPE", "LOC"]]
print(locations)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 import spacy
#       3 nlp = spacy.load("en_core_web_sm")
#       4 text = "I visited Paris, France, and then hiked in the Alps."
#
# File ~\anaconda3\Lib\site-packages\spacy\__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~\anaconda3\Lib\site-packages\spacy\errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~\anaconda3\Lib\site-packages\spacy\compat.py:4
#       1 """Helpers for Python and platform compatibility."""
#       2 import sys
# ----> 4 from thinc.util import copy_array
#       6 try:
#       7     import cPickle as pickle
#
# File ~\anaconda3\Lib\site-packages\thinc\__init__.py:5
#       2 import numpy
#       4 from .about import __version__
# ----> 5 from .config import registry
#       7 # fmt: off
#       8 __all__ = [
#       9     "registry",
#      10     "__version__",
#      11 ]
#
# File ~\anaconda3\Lib\site-packages\thinc\config.py:5
#       2 import confection
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
# ----> 5 from .types import Decorator
#       8 class registry(confection.registry):
#       9     # fmt: off
#      10     optimizers: Decorator = catalogue.create("thinc", "optimizers", entry_points=True)
#
# File ~\anaconda3\Lib\site-packages\thinc\types.py:27
#      24 from pydantic import GetCoreSchemaHandler
#      25 from pydantic_core import core_schema
# ---> 27 from .compat import cupy, has_cupy
#      29 if has_cupy:
#      30     get_array_module = cupy.get_array_module
#
# File ~\anaconda3\Lib\site-packages\thinc\compat.py:99
#      95 has_mxnet = False
#      98 try:
# ---> 99     import h5py
#     100 except ImportError:  # pragma: no cover
#     101     h5py = None
#
# File ~\anaconda3\Lib\site-packages\h5py\__init__.py:45
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#      43 _errors.silence_errors()
# ---> 45 from ._conv import register_converters as _register_converters, \
#      46                    unregister_converters as _unregister_converters
#      47 _register_converters()
#      48 atexit.register(_unregister_converters)
#
# File h5py\\_conv.pyx:1, in init h5py._conv()
#
# File h5py\\h5r.pyx:1, in init h5py.h5r()
#
# File h5py\\h5p.pyx:1, in init h5py.h5p()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
early_access.columns
# Out:
# Index(['ID', 'Box', 'title', 'Document Date', 'Document Length',
#        'Manuscript Type', 'Collection', 'Source', 'Internal Notes',
#        'Workflow Stage', 'Object Type', 'Author', 'Keywords', 'Head',
#        'Document Top', 'Dateline', 'Salutation', 'Document Body', 'Signature',
#        'Post Script', 'Document Extra', 'Marginalia', 'Enclosure', 'Footnote',
#        'General', 'Image Identifier', 'Response', 'date_mod', 'year'],
#       dtype='object')

# %%
letters.Salutation
# Out:
# 1755                                         Dear Julian:
# 1811                                   Dear Senator Bond:
# 1848                                                  NaN
# 1853                                                  NaN
# 1905                                                  NaN
# 2014                                                  NaN
# 2260                                                  NaN
# 2374    Miss Sonya Moulder\nEdmund Asa Ware Elementary...
# 2408    Mr. Julian Bond:\nHouse of Representative\nGeo...
# 2677                                     Dear Mr. Hughes:
# 2882                                       Dear Dr. King:
# 2890                                           Gentlemen:
# 3389    Mr. Julian Bond\n162 Ehuralee Street, S. W.\nA...
# 3391    Dr. Hugh Gloster, President\nMorehouse College...
# 5558                                    Dear Miss Bolton,
# 5559                                     Dear Ms. Chally,
# 5560                                    Dear Miss Mooney,
# 5561                                    Dear Mr. Hoffman,
# 5563                                      Dear Mrs. King,
# Name: Salutation, dtype: object

# %%
letters = early_access[early_access['Object Type'] == 'Letter']

storage = {}
for idx, row in letters.iterrows():
    places = []
    for field in ['Dateline', 'Salutation']:
        text = row[field]
        if pd.notnull(text):
            hits = re.findall(pattern, text, flags=re.IGNORECASE)
            places.append(hits) if hits else None
    storage[idx] = places

# %%
storage
# Out:
# {1755: [],
#  1811: [],
#  1848: [],
#  1853: [],
#  1905: [],
#  2014: [],
#  2260: [],
#  2374: [['Atlanta, Georgia']],
#  2408: [['Atlanta, Georgia'], ['Atlanta, Georgia']],
#  2677: [['New York, New York']],
#  2882: [['Atlanta, Georgia']],
#  2890: [['Niagara Falls, New York']],
#  3389: [['Atlanta, Georgia'], ['Atlanta, Georgia']],
#  3391: [['Atlanta, Georgia']],
#  5558: [['Atlanta, Georgia']],
#  5559: [['Morris, Illinois']],
#  5560: [['Decatur, Georgia']],
#  5561: [],
#  5563: [['Atlanta, Georgia']]}

# %%
# can work with that. Still don't love using regex though. But let's call it a day.

# %%
uscities.head(50)
# Out:
#               city            state_name      lat       lng  \
# 0         New York              New York  40.6943  -73.9249
# 1      Los Angeles            California  34.1141 -118.4068
# 2          Chicago              Illinois  41.8375  -87.6866
# 3            Miami               Florida  25.7840  -80.2101
# 4          Houston                 Texas  29.7860  -95.3885
# 5           Dallas                 Texas  32.7935  -96.7667
# 6     Philadelphia          Pennsylvania  40.0077  -75.1339
# 7          Atlanta               Georgia  33.7628  -84.4220
# 8       Washington  District of Columbia  38.9047  -77.0163
# 9           Boston         Massachusetts  42.3188  -71.0852
# 10         Phoenix               Arizona  33.5722 -112.0892
# 11         Detroit              Michigan  42.3834  -83.1024
# 12         Seattle            Washington  47.6211 -122.3244
# 13   San Francisco            California  37.7558 -122.4449
# 14       San Diego            California  32.8313 -117.1222
# 15     Minneapolis             Minnesota  44.9635  -93.2678
# 16           Tampa               Florida  27.9945  -82.4447
# 17        Brooklyn              New York  40.6501  -73.9496
# 18          Denver              Colorado  39.7620 -104.8758
# 19          Queens              New York  40.7498  -73.7976
# 20       Riverside            California  33.9381 -117.3949
# 21       Las Vegas                Nevada  36.2333 -115.2654
# 22       Baltimore              Maryland  39.3051  -76.6144
# 23       St. Louis              Missouri  38.6359  -90.2451
# 24        Portland                Oregon  45.5371 -122.6500
# 25     San Antonio                 Texas  29.4632  -98.5238
# 26      Sacramento            California  38.5677 -121.4685
# 27          Austin                 Texas  30.3005  -97.7522
# 28         Orlando               Florida  28.4773  -81.3370
# 29        San Juan           Puerto Rico  18.3985  -66.0610
# 30        San Jose            California  37.3012 -121.8480
# 31      Pittsburgh          Pennsylvania  40.4397  -79.9763
# 32    Indianapolis               Indiana  39.7771  -86.1458
# 33       Manhattan              New York  40.7834  -73.9662
# 34      Cincinnati                  Ohio  39.1413  -84.5060
# 35     Kansas City              Missouri  39.1238  -94.5541
# 36       Cleveland                  Ohio  41.4764  -81.6805
# 37        Columbus                  Ohio  39.9862  -82.9855
# 38           Bronx              New York  40.8501  -73.8662
# 39  Virginia Beach              Virginia  36.7335  -76.0435
# 40       Charlotte        North Carolina  35.2083  -80.8303
# 41       Milwaukee             Wisconsin  43.0642  -87.9675
# 42      Providence          Rhode Island  41.8230  -71.4187
# 43    Jacksonville               Florida  30.3322  -81.6749
# 44       Nashville             Tennessee  36.1715  -86.7842
# 45  Salt Lake City                  Utah  40.7776 -111.9311
# 46         Raleigh        North Carolina  35.8324  -78.6429
# 47        Richmond              Virginia  37.5295  -77.4756
# 48         Memphis             Tennessee  35.1087  -89.9663
# 49   Oklahoma City              Oklahoma  35.4676  -97.5136
#
#                                                  zips          id
# 0   11229 11228 11226 11225 11224 11222 11221 1122...  1840034016
# 1   91367 90291 90293 90292 91316 91311 90035 9003...  1840020491
# 2   60018 60649 60641 60640 60643 60642 60645 6064...  1840000494
# 3   33128 33129 33125 33126 33127 33149 33144 3314...  1840015149
# 4   77069 77068 77061 77060 77063 77062 77065 7706...  1840020925
# 5   75098 75287 75230 75231 75236 75237 75235 7525...  1840019440
# 6   19154 19151 19150 19153 19152 19102 19103 1910...  1840000673
# 7   30334 30331 30332 30309 30308 30354 30327 3032...  1840013660
# 8   20250 20010 20011 20012 20015 20520 20418 2041...  1840006060
# 9   02120 02121 02122 02124 02125 02126 02127 0212...  1840000455
# 10  85009 85003 85006 85007 85004 85083 85086 8508...  1840020568
# 11  48209 48208 48202 48201 48207 48206 48205 4820...  1840003971
# 12  98109 98108 98105 98104 98107 98106 98101 9810...  1840021117
# 13  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 14  92182 92109 92108 92107 92106 92103 92101 9211...  1840021990
# 15  55404 55409 55408 55407 55406 55405 55403 5540...  1840007830
# 16  33637 33629 33621 33620 33609 33604 33606 3360...  1840015982
# 17  11229 11226 11225 11224 11223 11221 11220 1124...  1840034030
# 18  80264 80266 80230 80231 80236 80237 80235 8023...  1840018789
# 19  11385 11109 11102 11103 11106 11104 11379 1137...  1840034002
# 20  92508 92503 92501 92506 92505 92504 92507 9252...  1840020551
# 21  89146 89149 89107 89106 89104 89102 89101 8910...  1840020364
# 22  21218 21211 21210 21213 21212 21215 21214 2121...  1840001592
# 23  63110 63111 63112 63113 63115 63116 63118 6312...  1840001651
# 24  97227 97221 97220 97229 97203 97202 97201 9720...  1840019941
# 25  78112 78239 78259 78258 78252 78251 78250 7825...  1840022220
# 26  95821 95820 95823 95838 95832 95833 95831 9583...  1840021491
# 27  78749 78748 78741 78742 78745 78744 78747 7874...  1840019590
# 28  32829 32827 32824 32822 32804 32805 32806 3280...  1840015099
# 29  00918 00913 00912 00911 00917 00915 00926 0092...  1630035577
# 30  95119 95118 95128 95124 95125 95122 95008 9500...  1840021570
# 31  15282 15216 15217 15214 15212 15213 15210 1521...  1840001254
# 32  46234 46237 46218 46219 46217 46214 46260 4626...  1840030084
# 33  10169 10168 10167 10165 10162 10282 10280 1004...  1840034000
# 34  45267 45219 45213 45212 45211 45217 45216 4521...  1840003814
# 35  64161 64163 64164 64165 64167 64053 64118 6411...  1840008535
# 36  44135 44120 44119 44113 44112 44111 44110 4411...  1840000596
# 37  43109 43026 43054 43220 43221 43222 43223 4322...  1840003760
# 38  10452 10475 10474 10471 10470 10473 10472 1045...  1840033999
# 39  23459 23451 23453 23452 23455 23457 23456 2345...  1840003871
# 40  28269 28262 28105 28280 28282 28209 28208 2820...  1840014557
# 41  53203 53202 53207 53206 53205 53204 53209 5320...  1840003046
# 42  02903 02906 02907 02908 02904 02905 02909 0291...  1840003289
# 43  32224 32225 32226 32227 32220 32221 32222 3222...  1840015031
# 44  37027 37138 37076 37072 37203 37206 37201 3708...  1840036155
# 45  84116 84115 84114 84113 84112 84111 84128 8415...  1840021383
# 46  27617 27616 27615 27614 27613 27612 27610 2760...  1840014497
# 47  23222 23223 23298 23284 23220 23221 23226 2322...  1840001698
# 48  38120 38127 38126 38107 38106 38105 38104 3810...  1840015457
# 49  73099 73119 73118 73114 73117 73116 73111 7311...  1840020428

# %%
# zips poses interesting possibilities for doing location tagging for letters, but I fear that it may be time-consuming.

# %%
state_abbrev_to_name = {
    "AL": "Alabama", "AK": "Alaska", "AZ": "Arizona", "AR": "Arkansas",
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DE": "Delaware",
    "FL": "Florida", "GA": "Georgia", "HI": "Hawaii", "ID": "Idaho",
    "IL": "Illinois", "IN": "Indiana", "IA": "Iowa", "KS": "Kansas",
    "KY": "Kentucky", "LA": "Louisiana", "ME": "Maine", "MD": "Maryland",
    "MA": "Massachusetts", "MI": "Michigan", "MN": "Minnesota", "MS": "Mississippi",
    "MO": "Missouri", "MT": "Montana", "NE": "Nebraska", "NV": "Nevada",
    "NH": "New Hampshire", "NJ": "New Jersey", "NM": "New Mexico", "NY": "New York",
    "NC": "North Carolina", "ND": "North Dakota", "OH": "Ohio", "OK": "Oklahoma",
    "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island", "SC": "South Carolina",
    "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas", "UT": "Utah",
    "VT": "Vermont", "VA": "Virginia", "WA": "Washington", "WV": "West Virginia",
    "WI": "Wisconsin", "WY": "Wyoming", "D.C.": "District of Columbia"
}

state_name_to_abbrev = {v: k for k, v in state_abbrev_to_name.items()}

uscities['state_abbrev'] = uscities['state_name'].map(state_name_to_abbrev)

# Step 3: Generate all combinations
location_variants = set()

for _, row in uscities.iterrows():
    city = row['city']
    state = row['state_name']
    abbrev = row['state_abbrev']
    
    # location_variants.add(city)
    location_variants.add(f"{city}, {state}")
    location_variants.add(f"{city}, {abbrev}")

# Step 4: Escape and build regex pattern
escaped_locations = [re.escape(loc) for loc in location_variants]
pattern = r'\b(?:' + '|'.join(escaped_locations) + r')\b'

# Step 5: Test text
title = "Top Tech Events in San Francisco, Austin, and Miami, FL"

# Find matches
matches = re.findall(pattern, title, flags=re.IGNORECASE)
print(matches)
# Out:
# ['Miami, FL']

# %%
early_access['potential_matches'] = early_access.apply(lambda row: re.findall(pattern, row['title'], flags=re.IGNORECASE), axis=1)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_35760\3648656043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   early_access['potential_matches'] = early_access.apply(lambda row: re.findall(pattern, row['title'], flags=re.IGNORECASE), axis=1)

# %%
matches = pd.DataFrame([(row['potential_matches'],row['title'],row['ID'],row['year']) for idx, row in early_access.iterrows() if row['potential_matches']])

# %%
# makes me sadddddd how do I fix also why is Washington, D.C. still not showing up ffs

# %%
matches[matches[3] == 1970]
# Out:
#                               0  \
# 93  [Atlantic City, New Jersey]
#
#                                                     1    2     3
# 93  Speech given at the Philadelphia Bar Associati...  470  1970

# %%
early_access[early_access['year'] == 1970]
# Out:
#         ID               Box  \
# 1947   309   Box 4 Folder 14
# 2111   470   Box 2 Folder 14
# 2117   462    Box 2 Folder 8
# 2118   461    Box 2 Folder 9
# 2121   456   Box 2 Folder 10
# 2180   548  Box 11 Folder 12
# 2187   577   Box 1 Folder 15
# 2189   575  Box 11 Folder 29
# 2191   572  Box 11 Folder 27
# 2194   569  Box 11 Folder 25
# 2208   595   Box 2 Folder 17
# 2293   573  Box 11 Folder 28
# 5558  4189   Box 15 Folder 1
# 5559  4682   Box 15 Folder 2
# 5560  4780   Box 15 Folder 3
# 5561  4910   Box 15 Folder 3
#
#                                                   title  \
# 1947  Speech about Black Economic Development Dec 19...
# 2111  Speech given at the Philadelphia Bar Associati...
# 2117  "Rush Towards Freedom" Television Series, Corr...
# 2118  Speech- "The Nature of the Crisis in Health Ca...
# 2121  Background Paper for "Speech to Doctors" on Me...
# 2180  Speech concerning the crisis in black schools,...
# 2187  Draft Speech 1970? (similar to Speech at the H...
# 2189  Speech- "Today's Youth Tomorrow's Leaders ", n...
# 2191  COPY: Speech concerning the crisis in black sc...
# 2194  Speech concerning the black college (HBCU): it...
# 2208  Speech concerning what the university should o...
# 2293  Speech concerning the role of the university, ...
# 5558   From Julian Bond to Menthalia Bolton, 9 Jun 1970
# 5559  From Julian Bond to Josephine Chally, 22 Sep 1970
# 5560    From Julian Bond to Jeannie Mooney, 21 Oct 1970
# 5561    From Julian Bond to Dustin Hoffman, 24 Nov 1970
#
#                                           Document Date  Document Length  \
# 1947  Tue, 12/01/1970 - 12:00\n - Thu, 12/31/1970 - ...             14.0
# 2111  Tue, 09/01/1970 - 12:00\n - Wed, 09/30/1970 - ...             10.0
# 2117  Sat, 02/21/1970 - 12:00\n - Sun, 02/22/1970 - ...             50.0
# 2118                            Fri, 02/13/1970 - 12:00             10.0
# 2121                            Tue, 03/31/1970 - 12:00             10.0
# 2180  Thu, 01/01/1970 - 12:00\n - Thu, 12/31/1970 - ...             21.0
# 2187  Thu, 01/01/1970 - 12:00\n - Tue, 12/01/1970 - ...             12.0
# 2189  Thu, 01/01/1970 - 12:00\n - Thu, 12/31/1970 - ...             12.0
# 2191  Thu, 01/01/1970 - 12:00\n - Thu, 12/31/1970 - ...             21.0
# 2194  Thu, 01/01/1970 - 12:00\n - Thu, 12/31/1970 - ...              3.0
# 2208  Thu, 01/01/1970 - 12:00\n - Thu, 04/30/1970 - ...             14.0
# 2293                            Tue, 12/01/1970 - 12:00             14.0
# 5558                            Tue, 06/09/1970 - 12:00              1.0
# 5559                            Tue, 09/22/1970 - 12:00              1.0
# 5560                            Wed, 10/21/1970 - 12:00              1.0
# 5561                            Tue, 11/24/1970 - 12:00              1.0
#
#                          Manuscript Type                          Collection  \
# 1947         Handwritten, Typed, Version     Papers of Julian Bond 1897-2006
# 2111                  Handwritten, Typed     Papers of Julian Bond 1897-2006
# 2117                  Handwritten, Typed     Papers of Julian Bond 1897-2006
# 2118                  Handwritten, Typed     Papers of Julian Bond 1897-2006
# 2121                  Handwritten, Typed     Papers of Julian Bond 1897-2006
# 2180                  Handwritten, Typed     Papers of Julian Bond 1897-2006
# 2187  Draft, Typed, Handwritten, Version  Papers of Julian Bond 1897-2006\n
# 2189                Copy, Typed, Version     Papers of Julian Bond 1897-2006
# 2191                         Copy, Typed     Papers of Julian Bond 1897-2006
# 2194                               Typed     Papers of Julian Bond 1897-2006
# 2208         Handwritten, Typed, Version     Papers of Julian Bond 1897-2006
# 2293            Copy, Handwritten, Typed     Papers of Julian Bond 1897-2006
# 5558                         Copy, Typed     Papers of Julian Bond 1897-2006
# 5559                 Copy, Signed, Typed     Papers of Julian Bond 1897-2006
# 5560                 Copy, Signed, Typed     Papers of Julian Bond 1897-2006
# 5561                 Copy, Signed, Typed     Papers of Julian Bond 1897-2006
#
#                                                  Source  \
# 1947  Special Collections, University of Virginia Li...
# 2111  Special Collections, University of Virginia Li...
# 2117  Special Collections, University of Virginia Li...
# 2118  Special Collections, University of Virginia Li...
# 2121  Special Collections, University of Virginia Li...
# 2180  Special Collections, University of Virginia Li...
# 2187  Special Collections, University of Virginia Li...
# 2189  Special Collections, University of Virginia Li...
# 2191  Special Collections, University of Virginia Li...
# 2194  Special Collections, University of Virginia Li...
# 2208  Special Collections, University of Virginia Li...
# 2293  Special Collections, University of Virginia Li...
# 5558  Special Collections, University of Virginia Li...
# 5559  Special Collections, University of Virginia Li...
# 5560  Special Collections, University of Virginia Li...
# 5561  Special Collections, University of Virginia Li...
#
#                                          Internal Notes Workflow Stage  ...  \
# 1947  There are three items in this folder. This ent...   Early Access  ...
# 2111  Scanning Notes: There is one item in this fold...   Early Access  ...
# 2117  Scanning Note: Please scan all pages in this f...   Early Access  ...
# 2118  Scanning Notes: There is one item in this fold...   Early Access  ...
# 2121  Scanning Notes: There is one item in this fold...   Early Access  ...
# 2180  Scanning Notes: There is one item in this fold...   Early Access  ...
# 2187  Scanning Notes: There are two items in this fo...   Early Access  ...
# 2189  Scanning Notes: There is one item in this fold...   Early Access  ...
# 2191  Scanning Notes: Please see if the camera setti...   Early Access  ...
# 2194  Scanning Notes: There is one item in this fold...   Early Access  ...
# 2208  Scanning Notes: There is one item in this fold...   Early Access  ...
# 2293  NEEDS REVIEW: Needs UVA IIIF -- sent images bu...   Early Access  ...
# 5558  Bulk imported. The letters to the kids who are...   Early Access  ...
# 5559  Bulk imported. Original letter not in collecti...   Early Access  ...
# 5560  Bulk imported.\nEditorial Notes:\n\nPublishing...   Early Access  ...
# 5561  Bulk imported.\nEditorial Notes:\n\nConcerns S...   Early Access  ...
#
#                    Document Extra  \
# 1947                          NaN
# 2111                          NaN
# 2117                          NaN
# 2118                          NaN
# 2121                          NaN
# 2180                          NaN
# 2187                          NaN
# 2189                          NaN
# 2191                          NaN
# 2194                          NaN
# 2208                          NaN
# 2293                          NaN
# 5558                          NaN
# 5559                          NaN
# 5560                          NaN
# 5561  cc: Southern Elections Fund
#
#                                              Marginalia Enclosure  \
# 1947                                                NaN       NaN
# 2111                                                NaN       NaN
# 2117                                                NaN       NaN
# 2118                                                NaN       NaN
# 2121                                                NaN       NaN
# 2180                                                NaN       NaN
# 2187                                                NaN       NaN
# 2189                                                NaN       NaN
# 2191                                                NaN       NaN
# 2194                                                NaN       NaN
# 2208  [Starting on page 3, the images include slight...       NaN
# 2293  [Starting on page 3, the images include slight...       NaN
# 5558                                                NaN       NaN
# 5559                                                NaN       NaN
# 5560                                                NaN       NaN
# 5561                                                NaN       NaN
#
#                                                Footnote  \
# 1947  1 Theodore L. Cross, Black Capitalism, p. 5 (1...
# 2111  *Tom Hayden, Colonialism & Liberation, Politic...
# 2117                                                NaN
# 2118                                                NaN
# 2121                                                NaN
# 2180  * Tom Hayden, Colonialism & Liberation, Politi...
# 2187                                                NaN
# 2189  1 Richard J. Barnet, The Economy of Death\n, 2...
# 2191  * Tom Hayden, Colonialism & Liberation, Politi...
# 2194                                                NaN
# 2208  * Peter Marin, The Center Magazine, September ...
# 2293  * Peter Martin, The Center Magazine, September...
# 5558                                                NaN
# 5559                                                NaN
# 5560                                                NaN
# 5561                                                NaN
#
#                                                 General  \
# 1947  Speech concerning black people and economic st...
# 2111                                                NaN
# 2117                                                NaN
# 2118                                                NaN
# 2121  Speech- "The Nature of the Crisis in Health Ca...
# 2180                                                NaN
# 2187  Speech at the Hungry Club Atlanta, February 12...
# 2189  Speech about race and war in American life, 19...
# 2191  Speech concerning the crisis in black schools,...
# 2194                                                NaN
# 2208  Speech concerning the role of the university, ...
# 2293  Speech concerning the role of the university, ...
# 5558                                                NaN
# 5559                                                NaN
# 5560                                                NaN
# 5561                                                NaN
#
#                                        Image Identifier Response  \
# 1947  2858886, 2858887, 2858888, 2858889, 2858890, 2...      NaN
# 2111  3202754, 3202755, 3202756, 3202757, 3202758, 3...      NaN
# 2117  3202782, 3202783, 3202784, 3202785, 3202786, 3...      NaN
# 2118  3202867, 3202868, 3202869, 3202870, 3202871, 3...      NaN
# 2121  3202857, 3202858, 3202859, 3202860, 3202861, 3...      NaN
# 2180  3243287, 3243288, 3243289, 3243290, 3243291, 3...      NaN
# 2187  3201949, 3201950, 3201951, 3201952, 3201953, 3...      NaN
# 2189  3242964, 3242965, 3242966, 3242967, 3242968, 3...      NaN
# 2191  3242990, 3242991, 3242992, 3242993, 3242994, 3...      NaN
# 2194                          3243057, 3243058, 3243059      NaN
# 2208  3202524, 3202525, 3202526, 3202527, 3202528, 3...      NaN
# 2293                                                NaN      NaN
# 5558                                                NaN      NaN
# 5559                                                NaN      NaN
# 5560                                                NaN      NaN
# 5561                                                NaN      NaN
#
#              date_mod  year            potential_matches
# 1947  Tue, 12/01/1970  1970                           []
# 2111  Tue, 09/01/1970  1970  [Atlantic City, New Jersey]
# 2117  Sat, 02/21/1970  1970                           []
# 2118  Fri, 02/13/1970  1970                           []
# 2121  Tue, 03/31/1970  1970                           []
# 2180  Thu, 01/01/1970  1970                           []
# 2187  Thu, 01/01/1970  1970                           []
# 2189  Thu, 01/01/1970  1970                           []
# 2191  Thu, 01/01/1970  1970                           []
# 2194  Thu, 01/01/1970  1970                           []
# 2208  Thu, 01/01/1970  1970                           []
# 2293  Tue, 12/01/1970  1970                           []
# 5558  Tue, 06/09/1970  1970                           []
# 5559  Tue, 09/22/1970  1970                           []
# 5560  Wed, 10/21/1970  1970                           []
# 5561  Tue, 11/24/1970  1970                           []
#
# [16 rows x 30 columns]

# %%
doc_catalog.drop(['Box', 'Document Length', 'Workflow Stage',
                  'Image Filename', 'Image Identifier', 'Image URL'], axis=1, inplace=True)

# %%
doc_catalog
# Out:
#       ID                                              Title  \
# 0    670  Undated Speech concerning Conditions of Black ...
# 1    667  Speeches making observations about the recent ...
# 2    666  Speeches making observations about the recent ...
# 3    665  Speeches making observations about the recent ...
# 4    663  Speech about the upcoming presidential electio...
# ..   ...                                                ...
# 235   83  Speech concerning black bankers and businesses...
# 236   84  Speech concerning challenges facing the Americ...
# 237   85  Speech from the Alabama Voter Education Projec...
# 238   86  Speech at Press Conference in Washington conce...
# 239   88  Speech on the health of the United States educ...
#
#                                          Document Body
# 0    [This speech includes pages with many differen...
# 1    Now that the nation's voters — at least, 54% o...
# 2    Now that the nation's voters — at least, 54% o...
# 3    1\nNow that the nations voters — at least, 54%...
# 4    The election approaching on November seventh i...
# ..                                                 ...
# 235  Before I begin, let me tell you my financial q...
# 236  Now that the nation has changed had a change o...
# 237  Thank you a great deal. As John Lewis has told...
# 238  [Handwritten.]\none the point of today's conce...
# 239  Insert x [Handwritten pages contain the conten...
#
# [240 rows x 3 columns]

# %%
doc_catalog_ext = pd.read_xml('1970s/document-catalog.csv.xml')

# %%
def clean_dataframe(df):
    df = df.replace(r'\\r|\\n|\\t|\n', '', regex=True)
    df = df.replace(r'<[^>]*>', '', regex=True)
    return df

clean_dataframe(doc_catalog_ext)
# Out:
#       key   nid        field_box  \
# 0       0  8277  Box 17 Folder 2
# 1       1  8276  Box 17 Folder 2
# 2       2  8275  Box 17 Folder 2
# 3       3  8274  Box 17 Folder 2
# 4       4  8273  Box 17 Folder 2
# ...   ...   ...              ...
# 8225  225   483             None
# 8226  226   482             None
# 8227  227   481             None
# 8228  228   480             None
# 8229  229   479             None
#
#                                                   title  \
# 0     From Julian Bond Memo Concerning the Westbrook...
# 1     From Julian Bond Memo Concerning the Westbrook...
# 2     To Julian Bond from Dr. Richard Allen Williams...
# 3     [Fragment] From Julian Bond to Cary Internatio...
# 4     To Julian Bond from Panke Bradley, Mrs. L. Fit...
# ...                                                 ...
# 8225                                               Home
# 8226                                     Press Coverage
# 8227                                   Editorial Method
# 8228                                        Julian Bond
# 8229                                  About The Project
#
#                    field_date field_document_length  \
# 0                        None                     1
# 1                        None                     1
# 2     Thu, 11/29/1973 - 12:00                     1
# 3                        None                     1
# 4     Mon, 09/30/1974 - 12:00                     2
# ...                       ...                   ...
# 8225                     None                  None
# 8226                     None                  None
# 8227                     None                  None
# 8228                     None                  None
# 8229                     None                  None
#
#                        field_manuscript_type                 field_collection  \
# 0                                Copy, Typed  Papers of Julian Bond 1897-2006
# 1                                Copy, Typed  Papers of Julian Bond 1897-2006
# 2                  Letterhead, Signed, Typed  Papers of Julian Bond 1897-2006
# 3               Copy, Draft, Typed, Fragment  Papers of Julian Bond 1897-2006
# 4     Letterhead, Handwritten, Signed, Typed  Papers of Julian Bond 1897-2006
# ...                                      ...                              ...
# 8225                                    None                             None
# 8226                                    None                             None
# 8227                                    None                             None
# 8228                                    None                             None
# 8229                                    None                             None
#
#                                            field_source  \
# 0     Special Collections, University of Virginia Li...
# 1     Special Collections, University of Virginia Li...
# 2     Special Collections, University of Virginia Li...
# 3     Special Collections, University of Virginia Li...
# 4     Special Collections, University of Virginia Li...
# ...                                                 ...
# 8225                                               None
# 8226                                               None
# 8227                                               None
# 8228                                               None
# 8229                                               None
#
#                                    field_internal_notes  ...  \
# 0     Bulk imported. no date clues, but it is in the...  ...
# 1     Bulk imported. no date clues, but it is in the...  ...
# 2                   Bulk imported. no response attached  ...
# 3     Bulk imported. no date clues, but it is in the...  ...
# 4     Bulk imported. Scanning note: please remove th...  ...
# ...                                                 ...  ...
# 8225                                               None  ...
# 8226                                               None  ...
# 8227                                               None  ...
# 8228                                               None  ...
# 8229                                               None  ...
#
#      field_document_body field_signature field_post_script  \
# 0                   None            None              None
# 1                   None            None              None
# 2                   None            None              None
# 3                   None            None              None
# 4                   None            None              None
# ...                  ...             ...               ...
# 8225                None            None              None
# 8226                None            None              None
# 8227                None            None              None
# 8228                None            None              None
# 8229                None            None              None
#
#      field_document_extra field_marginalia field_enclosure field_footnote  \
# 0                    None             None            None           None
# 1                    None             None            None           None
# 2                    None             None            None           None
# 3                    None             None            None           None
# 4                    None             None            None           None
# ...                   ...              ...             ...            ...
# 8225                 None             None            None           None
# 8226                 None             None            None           None
# 8227                 None             None            None           None
# 8228                 None             None            None           None
# 8229                 None             None            None           None
#
#                                           field_general  \
# 0     From Julian Bond Memo Concerning the Westbrook...
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 8225                                               None
# 8226                                               None
# 8227                                               None
# 8228                                               None
# 8229                                               None
#
#      field_image_identifier                                    field_response
# 0                      None                                              None
# 1                      None                                              None
# 2                      None                                              None
# 3                      None                                              None
# 4                      None  From Julian Bond to Panke Bradley, 23 Oct [1974]
# ...                     ...                                               ...
# 8225                   None                                              None
# 8226                   None                                              None
# 8227                   None                                              None
# 8228                   None                                              None
# 8229                   None                                              None
#
# [8230 rows x 28 columns]

# %%
full_catalog = clean_dataframe(doc_catalog_ext)
full_catalog.columns
# Out:
# Index(['key', 'nid', 'field_box', 'title', 'field_date',
#        'field_document_length', 'field_manuscript_type', 'field_collection',
#        'field_source', 'field_internal_notes', 'moderation_state',
#        'field_object_type', 'field_author', 'field_keywords', 'field_head',
#        'field_document_top', 'field_dateline', 'field_salutation',
#        'field_document_body', 'field_signature', 'field_post_script',
#        'field_document_extra', 'field_marginalia', 'field_enclosure',
#        'field_footnote', 'field_general', 'field_image_identifier',
#        'field_response'],
#       dtype='object')

# %%
full_catalog.moderation_state.unique()
# Out:
# array(['Cataloged', 'Early Access', 'Digitized', 'Transcribed',
#        'Proof read', 'Tandem read', 'Draft', None], dtype=object)

# %%
full_catalog.field_object_type.unique()
# Out:
# array(['Letter', 'Article', None, 'Speech', 'Essay', 'Ephemera',
#        'Interview', 'Report', 'Pamphlet', 'Legal'], dtype=object)

# %%
speeches = full_catalog[full_catalog['field_object_type']=='Speech']
speeches = speeches[speeches['moderation_state']=='Early Access']

# %%
uscities.drop(['zips', 'id'], axis=1, inplace=True)

# %%
uscities
# Out:
#                  city    state_name      lat       lng
# 0            New York      New York  40.6943  -73.9249
# 1         Los Angeles    California  34.1141 -118.4068
# 2             Chicago      Illinois  41.8375  -87.6866
# 3               Miami       Florida  25.7840  -80.2101
# 4             Houston         Texas  29.7860  -95.3885
# ...               ...           ...      ...       ...
# 31115          Kohatk       Arizona  32.5781 -112.0032
# 31116       Ironville  Pennsylvania  40.6586  -78.2155
# 31117         Newkirk    New Mexico  35.0635 -104.2715
# 31118  Falcon Village         Texas  26.5652  -99.1341
# 31119     Millerstown  Pennsylvania  40.2771  -78.3029
#
# [31120 rows x 4 columns]

# %%
uscities['City'] = uscities['city'] + ', ' + uscities['state_name']

# %%
cities = list(uscities.City)
city_pattern = '|'.join([f'\\b{city}\\b' for city in cities])

# Extract the city name using str.extract()
speeches['city'] = speeches['title'].str.extract(f'({city_pattern})', expand=False)

speeches
# Out:
#       key  nid         field_box  \
# 1340  340  347   Box 7 Folder 30
# 1341  341  346   Box 7 Folder 30
# 1342  342  379   Box 8 Folder 18
# 1343  343   88    Box 4 Folder 8
# 1352  352   86    Box 4 Folder 7
# ...   ...  ...               ...
# 1900  900  434   Box 9 Folder 30
# 1902  902  503   Box 10 Folder 9
# 1903  903  518  Box 10 Folder 20
# 1904  904  566  Box 11 Folder 23
# 1915  915  573  Box 11 Folder 28
#
#                                                   title  \
# 1340  Speech attacking the Reagan Administration&#03...
# 1341  Speech attacking the Reagan Administration&#03...
# 1342  Paper- &quot;The Movement and the Media: An An...
# 1343  Speech on the health of the United States educ...
# 1352  Speech at Press Conference in Washington conce...
# ...                                                 ...
# 1900  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 1902  Commencement Address at Washington University,...
# 1903  Speech- &quot;Public Intellectuals &quot;, 12 ...
# 1904  Speech concerning politics and the debate surr...
# 1915  Speech concerning the role of the university, ...
#
#                    field_date field_document_length  \
# 1340  Thu, 06/28/1984 - 12:00                    12
# 1341  Thu, 06/28/1984 - 12:00                    13
# 1342  Tue, 04/17/1990 - 12:00                    19
# 1343  Fri, 02/02/1973 - 12:00                    29
# 1352  Tue, 01/02/1973 - 12:00                     9
# ...                       ...                   ...
# 1900  Fri, 10/02/1998 - 12:00                    18
# 1902  Fri, 05/19/2000 - 12:00                     9
# 1903  Fri, 04/12/2002 - 12:00                     7
# 1904  Wed, 01/01/1969 - 12:00                    13
# 1915  Tue, 12/01/1970 - 12:00                    14
#
#             field_manuscript_type                 field_collection  \
# 1340  Handwritten, Typed, Version  Papers of Julian Bond 1897-2006
# 1341  Handwritten, Typed, Version  Papers of Julian Bond 1897-2006
# 1342           Handwritten, Typed  Papers of Julian Bond 1897-2006
# 1343                         None  Papers of Julian Bond 1897-2006
# 1352   Type, Handwritten, Version  Papers of Julian Bond 1897-2006
# ...                           ...                              ...
# 1900               Typed, Version  Papers of Julian Bond 1897-2006
# 1902                        Typed  Papers of Julian Bond 1897-2006
# 1903               Typed, Version  Papers of Julian Bond 1897-2006
# 1904               Typed, Version  Papers of Julian Bond 1897-2006
# 1915     Copy, Handwritten, Typed  Papers of Julian Bond 1897-2006
#
#                                            field_source  \
# 1340  Special Collections, University of Virginia Li...
# 1341  Special Collections, University of Virginia Li...
# 1342  Special Collections, University of Virginia Li...
# 1343  Special Collections, University of Virginia Li...
# 1352  Special Collections, University of Virginia Li...
# ...                                                 ...
# 1900  Special Collections, University of Virginia Li...
# 1902  Special Collections, University of Virginia Li...
# 1903  Special Collections, University of Virginia Li...
# 1904  Special Collections, University of Virginia Li...
# 1915  Special Collections, University of Virginia Li...
#
#                                    field_internal_notes  ... field_signature  \
# 1340  There are two items in this folder. This entry...  ...            None
# 1341  NEEDS REVIEW: Needs UVA IIIF -- sent images bu...  ...            None
# 1342  There is one item in this folder.Genre note: T...  ...            None
# 1343  6/7/22 - Reviewed by KZantowScanning Notes:Jus...  ...            None
# 1352  Scanning Notes:Box 4 Folder 7 contains two doc...  ...            None
# ...                                                 ...  ...             ...
# 1900  NEEDS REVIEW: Needs UVA IIIF -- sent images bu...  ...            None
# 1902  NEEDS REVIEW: Needs UVA IIIF -- sent images bu...  ...            None
# 1903  NEEDS REVIEW: IIIF did not get created; report...  ...            None
# 1904  NEEDS REVIEW: Needs UVA IIIF -- sent images bu...  ...            None
# 1915  NEEDS REVIEW: Needs UVA IIIF -- sent images bu...  ...            None
#
#      field_post_script                               field_document_extra  \
# 1340              None                                               None
# 1341              None                                               None
# 1342              None                                               None
# 1343              None                                               None
# 1352              None  THE NEW YORK TIMES, SATURDAY, DECEMBER 23, 197...
# ...                ...                                                ...
# 1900              None                                               None
# 1902              None                                               None
# 1903              None                                               None
# 1904              None                                               None
# 1915              None                                               None
#
#                                        field_marginalia field_enclosure  \
# 1340                                               None            None
# 1341                                               None            None
# 1342                                               None            None
# 1343                                               None            None
# 1352  [The title and description of this document ar...            None
# ...                                                 ...             ...
# 1900                                               None            None
# 1902                                               None            None
# 1903                                               None            None
# 1904                                               None            None
# 1915  [Starting on page 3, the images include slight...            None
#
#                                          field_footnote  \
# 1340                                               None
# 1341                                               None
# 1342  1. Quoted in The New York Times, March 18, 199...
# 1343  1 Who Cares&nbsp;About Education?" Craig S. Ba...
# 1352                                               None
# ...                                                 ...
# 1900  1 President Lyndon B. Johnson, March 15, 1965....
# 1902  1. Bond, James, Commencement Address, Berea Co...
# 1903  1 Mills, C. Wright, White Collar: the American...
# 1904  * Dr. Kenneth Clark, 1967 speech to the Southe...
# 1915  * Peter Martin, The Center Magazine, September...
#
#                                           field_general  \
# 1340                                               None
# 1341  Speech attacking the Reagan Administration&#03...
# 1342                                               None
# 1343                                               None
# 1352                                               None
# ...                                                 ...
# 1900  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 1902  Commencement Address at Washington University,...
# 1903                                               None
# 1904  (Draft) Speech concerning politics and the deb...
# 1915  Speech concerning the role of the university, ...
#
#                                  field_image_identifier field_response city
# 1340  3205197, 3205198, 3205199, 3205200, 3205201, 3...           None  NaN
# 1341                                               None           None  NaN
# 1342  3205955, 3205956, 3205957, 3205958, 3205959, 3...           None  NaN
# 1343  2857526, 2857527, 2857528, 2857529, 2857530, 2...           None  NaN
# 1352  2857508, 2857509, 2857510, 2857511, 2857512, 2...           None  NaN
# ...                                                 ...            ...  ...
# 1900                                               None           None  NaN
# 1902                                               None           None  NaN
# 1903                                               None           None  NaN
# 1904                                               None           None  NaN
# 1915                                               None           None  NaN
#
# [387 rows x 29 columns]

# %%
speeches.to_excel('speeches.xlsx')

# %%
speeches = pd.read_excel('speeches.xlsx')

# %%
speeches
# Out:
#      Unnamed: 0  key  nid         field_box  \
# 0          1340  340  347   Box 7 Folder 30
# 1          1341  341  346   Box 7 Folder 30
# 2          1342  342  379   Box 8 Folder 18
# 3          1343  343   88    Box 4 Folder 8
# 4          1352  352   86    Box 4 Folder 7
# ..          ...  ...  ...               ...
# 382        1900  900  434   Box 9 Folder 30
# 383        1902  902  503   Box 10 Folder 9
# 384        1903  903  518  Box 10 Folder 20
# 385        1904  904  566  Box 11 Folder 23
# 386        1915  915  573  Box 11 Folder 28
#
#                                                  title  \
# 0    Speech attacking the Reagan Administration&#03...
# 1    Speech attacking the Reagan Administration&#03...
# 2    Paper- &quot;The Movement and the Media: An An...
# 3    Speech on the health of the United States educ...
# 4    Speech at Press Conference in Washington conce...
# ..                                                 ...
# 382  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 383  Commencement Address at Washington University,...
# 384  Speech- &quot;Public Intellectuals &quot;, 12 ...
# 385  Speech concerning politics and the debate surr...
# 386  Speech concerning the role of the university, ...
#
#                   field_date  field_document_length  \
# 0    Thu, 06/28/1984 - 12:00                     12
# 1    Thu, 06/28/1984 - 12:00                     13
# 2    Tue, 04/17/1990 - 12:00                     19
# 3    Fri, 02/02/1973 - 12:00                     29
# 4    Tue, 01/02/1973 - 12:00                      9
# ..                       ...                    ...
# 382  Fri, 10/02/1998 - 12:00                     18
# 383  Fri, 05/19/2000 - 12:00                      9
# 384  Fri, 04/12/2002 - 12:00                      7
# 385  Wed, 01/01/1969 - 12:00                     13
# 386  Tue, 12/01/1970 - 12:00                     14
#
#            field_manuscript_type                 field_collection  \
# 0    Handwritten, Typed, Version  Papers of Julian Bond 1897-2006
# 1    Handwritten, Typed, Version  Papers of Julian Bond 1897-2006
# 2             Handwritten, Typed  Papers of Julian Bond 1897-2006
# 3                            NaN  Papers of Julian Bond 1897-2006
# 4     Type, Handwritten, Version  Papers of Julian Bond 1897-2006
# ..                           ...                              ...
# 382               Typed, Version  Papers of Julian Bond 1897-2006
# 383                        Typed  Papers of Julian Bond 1897-2006
# 384               Typed, Version  Papers of Julian Bond 1897-2006
# 385               Typed, Version  Papers of Julian Bond 1897-2006
# 386     Copy, Handwritten, Typed  Papers of Julian Bond 1897-2006
#
#                                           field_source  ... field_signature  \
# 0    Special Collections, University of Virginia Li...  ...             NaN
# 1    Special Collections, University of Virginia Li...  ...             NaN
# 2    Special Collections, University of Virginia Li...  ...             NaN
# 3    Special Collections, University of Virginia Li...  ...             NaN
# 4    Special Collections, University of Virginia Li...  ...             NaN
# ..                                                 ...  ...             ...
# 382  Special Collections, University of Virginia Li...  ...             NaN
# 383  Special Collections, University of Virginia Li...  ...             NaN
# 384  Special Collections, University of Virginia Li...  ...             NaN
# 385  Special Collections, University of Virginia Li...  ...             NaN
# 386  Special Collections, University of Virginia Li...  ...             NaN
#
#     field_post_script                               field_document_extra  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN  THE NEW YORK TIMES, SATURDAY, DECEMBER 23, 197...
# ..                ...                                                ...
# 382               NaN                                                NaN
# 383               NaN                                                NaN
# 384               NaN                                                NaN
# 385               NaN                                                NaN
# 386               NaN                                                NaN
#
#                                       field_marginalia field_enclosure  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4    [The title and description of this document ar...             NaN
# ..                                                 ...             ...
# 382                                                NaN             NaN
# 383                                                NaN             NaN
# 384                                                NaN             NaN
# 385                                                NaN             NaN
# 386  [Starting on page 3, the images include slight...             NaN
#
#                                         field_footnote  \
# 0                                                  NaN
# 1                                                  NaN
# 2    1. Quoted in The New York Times, March 18, 199...
# 3    1 Who Cares&nbsp;About Education?" Craig S. Ba...
# 4                                                  NaN
# ..                                                 ...
# 382  1 President Lyndon B. Johnson, March 15, 1965....
# 383  1. Bond, James, Commencement Address, Berea Co...
# 384  1 Mills, C. Wright, White Collar: the American...
# 385  * Dr. Kenneth Clark, 1967 speech to the Southe...
# 386  * Peter Martin, The Center Magazine, September...
#
#                                          field_general  \
# 0                                                  NaN
# 1    Speech attacking the Reagan Administration&#03...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 382  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 383  Commencement Address at Washington University,...
# 384                                                NaN
# 385  (Draft) Speech concerning politics and the deb...
# 386  Speech concerning the role of the university, ...
#
#                                 field_image_identifier field_response  \
# 0    3205197, 3205198, 3205199, 3205200, 3205201, 3...            NaN
# 1                                                  NaN            NaN
# 2    3205955, 3205956, 3205957, 3205958, 3205959, 3...            NaN
# 3    2857526, 2857527, 2857528, 2857529, 2857530, 2...            NaN
# 4    2857508, 2857509, 2857510, 2857511, 2857512, 2...            NaN
# ..                                                 ...            ...
# 382                                                NaN            NaN
# 383                                                NaN            NaN
# 384                                                NaN            NaN
# 385                                                NaN            NaN
# 386                                                NaN            NaN
#
#                city
# 0        Boston, MA
# 1        Boston, MA
# 2     Cambridge, MA
# 3               NaN
# 4    Washington, DC
# ..              ...
# 382             NaN
# 383   St. Louis, MO
# 384             NaN
# 385             NaN
# 386             NaN
#
# [387 rows x 30 columns]

# %%
sum(speeches.city.value_counts())
# Out:
# 161

# %%
# doc_catalog['city_from_body'] = doc_catalog['Document Body'].str.extract(f'({city_pattern})', expand=False)

# print(doc_catalog)

# %%
# sum(doc_catalog.city_from_body.value_counts())

# %%
speeches.columns
# Out:
# Index(['Unnamed: 0', 'key', 'nid', 'field_box', 'title', 'field_date',
#        'field_document_length', 'field_manuscript_type', 'field_collection',
#        'field_source', 'field_internal_notes', 'moderation_state',
#        'field_object_type', 'field_author', 'field_keywords', 'field_head',
#        'field_document_top', 'field_dateline', 'field_salutation',
#        'field_document_body', 'field_signature', 'field_post_script',
#        'field_document_extra', 'field_marginalia', 'field_enclosure',
#        'field_footnote', 'field_general', 'field_image_identifier',
#        'field_response', 'city'],
#       dtype='object')

# %%
drop_cols = ['Unnamed: 0', 'field_box', 'field_date',
       'field_document_length', 'field_manuscript_type', 'field_collection',
       'field_source', 'field_internal_notes', 'moderation_state',
       'field_object_type', 'field_head',
       'field_document_top', 'field_dateline', 'field_salutation',
       'field_document_body', 'field_signature', 'field_post_script',
       'field_document_extra', 'field_marginalia',
       'field_footnote', 'field_image_identifier']
speeches.drop(drop_cols, axis=1, inplace=True)

# %%
speeches.drop('field_response', axis=1, inplace=True)

# %%
import re

# %%
state_abbrev_to_name = {
    "AL": "Alabama", "AK": "Alaska", "AZ": "Arizona", "AR": "Arkansas",
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DE": "Delaware",
    "FL": "Florida", "GA": "Georgia", "HI": "Hawaii", "ID": "Idaho",
    "IL": "Illinois", "IN": "Indiana", "IA": "Iowa", "KS": "Kansas",
    "KY": "Kentucky", "LA": "Louisiana", "ME": "Maine", "MD": "Maryland",
    "MA": "Massachusetts", "MI": "Michigan", "MN": "Minnesota", "MS": "Mississippi",
    "MO": "Missouri", "MT": "Montana", "NE": "Nebraska", "NV": "Nevada",
    "NH": "New Hampshire", "NJ": "New Jersey", "NM": "New Mexico", "NY": "New York",
    "NC": "North Carolina", "ND": "North Dakota", "OH": "Ohio", "OK": "Oklahoma",
    "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island", "SC": "South Carolina",
    "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas", "UT": "Utah",
    "VT": "Vermont", "VA": "Virginia", "WA": "Washington", "WV": "West Virginia",
    "WI": "Wisconsin", "WY": "Wyoming", "DC": "District of Columbia"
}

def replace_state_abbreviations(text):
    # Compile a regex pattern that matches all two-letter state abbreviations as whole words
    pattern = r'\b(' + '|'.join(state_abbrev_to_name.keys()) + r')\b'
    return re.sub(pattern, lambda m: state_abbrev_to_name[m.group()], text)

speeches.city = speeches.city.fillna('').apply(replace_state_abbreviations)
speeches
# Out:
#      key  nid                                              title  \
# 0    340  347  Speech attacking the Reagan Administration&#03...
# 1    341  346  Speech attacking the Reagan Administration&#03...
# 2    342  379  Paper- &quot;The Movement and the Media: An An...
# 3    343   88  Speech on the health of the United States educ...
# 4    352   86  Speech at Press Conference in Washington conce...
# ..   ...  ...                                                ...
# 382  900  434  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 383  902  503  Commencement Address at Washington University,...
# 384  903  518  Speech- &quot;Public Intellectuals &quot;, 12 ...
# 385  904  566  Speech concerning politics and the debate surr...
# 386  915  573  Speech concerning the role of the university, ...
#
#      field_author                    field_keywords field_enclosure  \
# 0    Bond, Julian                      Race and Law             NaN
# 1    Bond, Julian                      Race and Law             NaN
# 2    Bond, Julian             Education, Organizing             NaN
# 3    Bond, Julian                               NaN             NaN
# 4    Bond, Julian                               NaN             NaN
# ..            ...                               ...             ...
# 382  Bond, Julian  Disenfranchisement, Race and Law             NaN
# 383  Bond, Julian                         Education             NaN
# 384  Bond, Julian             Education, Organizing             NaN
# 385  Bond, Julian             Economics, Organizing             NaN
# 386  Bond, Julian                         Education             NaN
#
#                                          field_general  \
# 0                                                  NaN
# 1    Speech attacking the Reagan Administration&#03...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 382  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 383  Commencement Address at Washington University,...
# 384                                                NaN
# 385  (Draft) Speech concerning politics and the deb...
# 386  Speech concerning the role of the university, ...
#
#                                  city
# 0               Boston, Massachusetts
# 1               Boston, Massachusetts
# 2            Cambridge, Massachusetts
# 3
# 4    Washington, District of Columbia
# ..                                ...
# 382
# 383               St. Louis, Missouri
# 384
# 385
# 386
#
# [387 rows x 8 columns]

# %%
merged = pd.merge(speeches, uscities, left_on = 'city', right_on='City', how='left')
# merged_pt_2.dropna(inplace=True)
merged
# Out:
#      key  nid                                              title  \
# 0    340  347  Speech attacking the Reagan Administration&#03...
# 1    341  346  Speech attacking the Reagan Administration&#03...
# 2    342  379  Paper- &quot;The Movement and the Media: An An...
# 3    343   88  Speech on the health of the United States educ...
# 4    352   86  Speech at Press Conference in Washington conce...
# ..   ...  ...                                                ...
# 382  900  434  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 383  902  503  Commencement Address at Washington University,...
# 384  903  518  Speech- &quot;Public Intellectuals &quot;, 12 ...
# 385  904  566  Speech concerning politics and the debate surr...
# 386  915  573  Speech concerning the role of the university, ...
#
#      field_author                    field_keywords field_enclosure  \
# 0    Bond, Julian                      Race and Law             NaN
# 1    Bond, Julian                      Race and Law             NaN
# 2    Bond, Julian             Education, Organizing             NaN
# 3    Bond, Julian                               NaN             NaN
# 4    Bond, Julian                               NaN             NaN
# ..            ...                               ...             ...
# 382  Bond, Julian  Disenfranchisement, Race and Law             NaN
# 383  Bond, Julian                         Education             NaN
# 384  Bond, Julian             Education, Organizing             NaN
# 385  Bond, Julian             Economics, Organizing             NaN
# 386  Bond, Julian                         Education             NaN
#
#                                          field_general  \
# 0                                                  NaN
# 1    Speech attacking the Reagan Administration&#03...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 382  Speech- &quot;The 1965 Voting Rights Act, A Be...
# 383  Commencement Address at Washington University,...
# 384                                                NaN
# 385  (Draft) Speech concerning politics and the deb...
# 386  Speech concerning the role of the university, ...
#
#                                city_x      city_y            state_name  \
# 0               Boston, Massachusetts      Boston         Massachusetts
# 1               Boston, Massachusetts      Boston         Massachusetts
# 2            Cambridge, Massachusetts   Cambridge         Massachusetts
# 3                                             NaN                   NaN
# 4    Washington, District of Columbia  Washington  District of Columbia
# ..                                ...         ...                   ...
# 382                                           NaN                   NaN
# 383               St. Louis, Missouri   St. Louis              Missouri
# 384                                           NaN                   NaN
# 385                                           NaN                   NaN
# 386                                           NaN                   NaN
#
#          lat      lng                              City
# 0    42.3188 -71.0852             Boston, Massachusetts
# 1    42.3188 -71.0852             Boston, Massachusetts
# 2    42.3759 -71.1185          Cambridge, Massachusetts
# 3        NaN      NaN                               NaN
# 4    38.9047 -77.0163  Washington, District of Columbia
# ..       ...      ...                               ...
# 382      NaN      NaN                               NaN
# 383  38.6359 -90.2451               St. Louis, Missouri
# 384      NaN      NaN                               NaN
# 385      NaN      NaN                               NaN
# 386      NaN      NaN                               NaN
#
# [387 rows x 13 columns]

# %%
merged.to_csv('speeches_to_ArcGIS.csv')

# %%
mystr = merged[merged['nid']==610]

# %%
doc_catalog['ID'] = doc_catalog['ID'].astype('str')
doc_catalog['url'] = "http://bondpapersproject.org/node/" + doc_catalog['ID']
doc_catalog
# Out:
#       ID                                              Title  \
# 0    670  Undated Speech concerning Conditions of Black ...
# 1    667  Speeches making observations about the recent ...
# 2    666  Speeches making observations about the recent ...
# 3    665  Speeches making observations about the recent ...
# 4    663  Speech about the upcoming presidential electio...
# ..   ...                                                ...
# 235   83  Speech concerning black bankers and businesses...
# 236   84  Speech concerning challenges facing the Americ...
# 237   85  Speech from the Alabama Voter Education Projec...
# 238   86  Speech at Press Conference in Washington conce...
# 239   88  Speech on the health of the United States educ...
#
#                                          Document Body  \
# 0    [This speech includes pages with many differen...
# 1    Now that the nation's voters — at least, 54% o...
# 2    Now that the nation's voters — at least, 54% o...
# 3    1\nNow that the nations voters — at least, 54%...
# 4    The election approaching on November seventh i...
# ..                                                 ...
# 235  Before I begin, let me tell you my financial q...
# 236  Now that the nation has changed had a change o...
# 237  Thank you a great deal. As John Lewis has told...
# 238  [Handwritten.]\none the point of today's conce...
# 239  Insert x [Handwritten pages contain the conten...
#
#                        City                                    url
# 0                       NaN  http://bondpapersproject.org/node/670
# 1                       NaN  http://bondpapersproject.org/node/667
# 2                       NaN  http://bondpapersproject.org/node/666
# 3                       NaN  http://bondpapersproject.org/node/665
# 4    New Orleans, Louisiana  http://bondpapersproject.org/node/663
# ..                      ...                                    ...
# 235                     NaN   http://bondpapersproject.org/node/83
# 236                     NaN   http://bondpapersproject.org/node/84
# 237                     NaN   http://bondpapersproject.org/node/85
# 238                     NaN   http://bondpapersproject.org/node/86
# 239                     NaN   http://bondpapersproject.org/node/88
#
# [240 rows x 5 columns]

# %%
doc_catalog['url'][1]
# Out:
# 'http://bondpapersproject.org/node/667'

# %% [markdown]
# So I think the conclusion here is that location tagging ought to be done during proofreading. I wish there was an easy way to make that location tagging happen, especially vis a vis creating the locations, but maybe this can be a jumping off point.
#
# Essentially, there is no foolproof way to do this, but if the location is in the title, we can create entries for those and then build out from there. And hopefully, we can then go in and scrape that location data and apply it to the map tile layer.

# %% [markdown]
# city_from_body seems fairly useless

# %%
grouped = doc_catalog.groupby('City').agg({'Title': lambda x: ' | '.join(x),
                                           'ID': 'count',
                                           'url': lambda x: ' | '.join(x)
                                           }).reset_index()
grouped
# Out:
#                           City  \
# 0             Arlington, Texas
# 1             Atlanta, Georgia
# 2    Atlantic City, New Jersey
# 3          Baltimore, Maryland
# 4          Birmingham, Alabama
# 5    Charlotte, North Carolina
# 6            Chicago, Illinois
# 7              Cleveland, Ohio
# 8   Greensboro, North Carolina
# 9               Houston, Texas
# 10        Jackson, Mississippi
# 11       Kansas City, Missouri
# 12     Los Angeles, California
# 13              Macon, Georgia
# 14         Montgomery, Alabama
# 15      New Orleans, Louisiana
# 16    Pittsburgh, Pennsylvania
# 17      Ruleville, Mississippi
# 18            Sanford, Florida
# 19         Seattle, Washington
# 20         St. Louis, Missouri
#
#                                                 Title  ID  \
# 0   Speech--"Strategies for Change" The Texas Regi...   1
# 1   Speech about the roles of black students in ad...  25
# 2   Speech given at the Philadelphia Bar Associati...   1
# 3   Commencement Address at Morgan State Universit...   1
# 4   Speech concerning opposition to the War in Sou...   2
# 5   Speech prepared for Black Democrats Conference...   2
# 6   Speech concerning the 1972 Presidential Electi...   1
# 7   Remarks prepared for Morehouse College Alumni ...   3
# 8   Remarks to the Triad Sickle Cell Anemia Founda...   1
# 9   Speech delivered at the NAACP Convention, Geor...   4
# 10  Speech for Project Media, Jackson, Mississippi...   2
# 11  Speech at the National Urban League Meeting, K...   2
# 12  Remarks prepared for delivery at the Marriott ...   2
# 13  Remarks prepared for delivery at the 35th Geor...   1
# 14  Speech at the dedication of the Southern Pover...   1
# 15  Speech about the upcoming presidential electio...   5
# 16  Speech concerning the challenges facing black ...   2
# 17  Tribute to Mrs. Fannie Lou Hamer delivered at ...   1
# 18  Speech concerning political action, black peop...   2
# 19  Remarks delivered to National Drug Abuse Confe...   1
# 20  Speech at National Urban League, St. Louis, Mi...   2
#
#                                                   url
# 0               http://bondpapersproject.org/node/336
# 1   http://bondpapersproject.org/node/618 | http:/...
# 2               http://bondpapersproject.org/node/470
# 3               http://bondpapersproject.org/node/442
# 4   http://bondpapersproject.org/node/213 | http:/...
# 5   http://bondpapersproject.org/node/311 | http:/...
# 6               http://bondpapersproject.org/node/118
# 7   http://bondpapersproject.org/node/157 | http:/...
# 8               http://bondpapersproject.org/node/237
# 9   http://bondpapersproject.org/node/521 | http:/...
# 10  http://bondpapersproject.org/node/160 | http:/...
# 11  http://bondpapersproject.org/node/89 | http://...
# 12  http://bondpapersproject.org/node/329 | http:/...
# 13              http://bondpapersproject.org/node/302
# 14              http://bondpapersproject.org/node/377
# 15  http://bondpapersproject.org/node/663 | http:/...
# 16  http://bondpapersproject.org/node/270 | http:/...
# 17              http://bondpapersproject.org/node/258
# 18  http://bondpapersproject.org/node/613 | http:/...
# 19              http://bondpapersproject.org/node/337
# 20  http://bondpapersproject.org/node/127 | http:/...

# %%
merged = pd.merge(grouped, uscities, on='City', how='left')
merged
# Out:
#                           City  \
# 0             Arlington, Texas
# 1             Atlanta, Georgia
# 2    Atlantic City, New Jersey
# 3          Baltimore, Maryland
# 4          Birmingham, Alabama
# 5    Charlotte, North Carolina
# 6            Chicago, Illinois
# 7              Cleveland, Ohio
# 8   Greensboro, North Carolina
# 9               Houston, Texas
# 10        Jackson, Mississippi
# 11       Kansas City, Missouri
# 12     Los Angeles, California
# 13              Macon, Georgia
# 14         Montgomery, Alabama
# 15      New Orleans, Louisiana
# 16    Pittsburgh, Pennsylvania
# 17      Ruleville, Mississippi
# 18            Sanford, Florida
# 19         Seattle, Washington
# 20         St. Louis, Missouri
#
#                                                 Title  ID  \
# 0   Speech--"Strategies for Change" The Texas Regi...   1
# 1   Speech about the roles of black students in ad...  25
# 2   Speech given at the Philadelphia Bar Associati...   1
# 3   Commencement Address at Morgan State Universit...   1
# 4   Speech concerning opposition to the War in Sou...   2
# 5   Speech prepared for Black Democrats Conference...   2
# 6   Speech concerning the 1972 Presidential Electi...   1
# 7   Remarks prepared for Morehouse College Alumni ...   3
# 8   Remarks to the Triad Sickle Cell Anemia Founda...   1
# 9   Speech delivered at the NAACP Convention, Geor...   4
# 10  Speech for Project Media, Jackson, Mississippi...   2
# 11  Speech at the National Urban League Meeting, K...   2
# 12  Remarks prepared for delivery at the Marriott ...   2
# 13  Remarks prepared for delivery at the 35th Geor...   1
# 14  Speech at the dedication of the Southern Pover...   1
# 15  Speech about the upcoming presidential electio...   5
# 16  Speech concerning the challenges facing black ...   2
# 17  Tribute to Mrs. Fannie Lou Hamer delivered at ...   1
# 18  Speech concerning political action, black peop...   2
# 19  Remarks delivered to National Drug Abuse Confe...   1
# 20  Speech at National Urban League, St. Louis, Mi...   2
#
#                                                   url           city  \
# 0               http://bondpapersproject.org/node/336      Arlington
# 1   http://bondpapersproject.org/node/618 | http:/...        Atlanta
# 2               http://bondpapersproject.org/node/470  Atlantic City
# 3               http://bondpapersproject.org/node/442      Baltimore
# 4   http://bondpapersproject.org/node/213 | http:/...     Birmingham
# 5   http://bondpapersproject.org/node/311 | http:/...      Charlotte
# 6               http://bondpapersproject.org/node/118        Chicago
# 7   http://bondpapersproject.org/node/157 | http:/...      Cleveland
# 8               http://bondpapersproject.org/node/237     Greensboro
# 9   http://bondpapersproject.org/node/521 | http:/...        Houston
# 10  http://bondpapersproject.org/node/160 | http:/...        Jackson
# 11  http://bondpapersproject.org/node/89 | http://...    Kansas City
# 12  http://bondpapersproject.org/node/329 | http:/...    Los Angeles
# 13              http://bondpapersproject.org/node/302          Macon
# 14              http://bondpapersproject.org/node/377     Montgomery
# 15  http://bondpapersproject.org/node/663 | http:/...    New Orleans
# 16  http://bondpapersproject.org/node/270 | http:/...     Pittsburgh
# 17              http://bondpapersproject.org/node/258      Ruleville
# 18  http://bondpapersproject.org/node/613 | http:/...        Sanford
# 19              http://bondpapersproject.org/node/337        Seattle
# 20  http://bondpapersproject.org/node/127 | http:/...      St. Louis
#
#         state_name      lat       lng
# 0            Texas  32.6998  -97.1250
# 1          Georgia  33.7628  -84.4220
# 2       New Jersey  39.3797  -74.4527
# 3         Maryland  39.3051  -76.6144
# 4          Alabama  33.5279  -86.7971
# 5   North Carolina  35.2083  -80.8303
# 6         Illinois  41.8375  -87.6866
# 7             Ohio  41.4764  -81.6805
# 8   North Carolina  36.0956  -79.8271
# 9            Texas  29.7860  -95.3885
# 10     Mississippi  32.3157  -90.2125
# 11        Missouri  39.1238  -94.5541
# 12      California  34.1141 -118.4068
# 13         Georgia  32.8065  -83.6974
# 14         Alabama  32.3482  -86.2668
# 15       Louisiana  30.0687  -89.9288
# 16    Pennsylvania  40.4397  -79.9763
# 17     Mississippi  33.7245  -90.5500
# 18         Florida  28.7891  -81.2757
# 19      Washington  47.6211 -122.3244
# 20        Missouri  38.6359  -90.2451

# %%
drop_map = ['city', 'state_name']
merged.drop(drop_map, axis=1, inplace=True)
merged.rename({'ID':'count', 'Title':'Documents'}, axis=1, inplace=True)
merged
# Out:
#                           City  \
# 0             Arlington, Texas
# 1             Atlanta, Georgia
# 2    Atlantic City, New Jersey
# 3          Baltimore, Maryland
# 4          Birmingham, Alabama
# 5    Charlotte, North Carolina
# 6            Chicago, Illinois
# 7              Cleveland, Ohio
# 8   Greensboro, North Carolina
# 9               Houston, Texas
# 10        Jackson, Mississippi
# 11       Kansas City, Missouri
# 12     Los Angeles, California
# 13              Macon, Georgia
# 14         Montgomery, Alabama
# 15      New Orleans, Louisiana
# 16    Pittsburgh, Pennsylvania
# 17      Ruleville, Mississippi
# 18            Sanford, Florida
# 19         Seattle, Washington
# 20         St. Louis, Missouri
#
#                                             Documents  count  \
# 0   Speech--"Strategies for Change" The Texas Regi...      1
# 1   Speech about the roles of black students in ad...     25
# 2   Speech given at the Philadelphia Bar Associati...      1
# 3   Commencement Address at Morgan State Universit...      1
# 4   Speech concerning opposition to the War in Sou...      2
# 5   Speech prepared for Black Democrats Conference...      2
# 6   Speech concerning the 1972 Presidential Electi...      1
# 7   Remarks prepared for Morehouse College Alumni ...      3
# 8   Remarks to the Triad Sickle Cell Anemia Founda...      1
# 9   Speech delivered at the NAACP Convention, Geor...      4
# 10  Speech for Project Media, Jackson, Mississippi...      2
# 11  Speech at the National Urban League Meeting, K...      2
# 12  Remarks prepared for delivery at the Marriott ...      2
# 13  Remarks prepared for delivery at the 35th Geor...      1
# 14  Speech at the dedication of the Southern Pover...      1
# 15  Speech about the upcoming presidential electio...      5
# 16  Speech concerning the challenges facing black ...      2
# 17  Tribute to Mrs. Fannie Lou Hamer delivered at ...      1
# 18  Speech concerning political action, black peop...      2
# 19  Remarks delivered to National Drug Abuse Confe...      1
# 20  Speech at National Urban League, St. Louis, Mi...      2
#
#                                                   url      lat       lng
# 0               http://bondpapersproject.org/node/336  32.6998  -97.1250
# 1   http://bondpapersproject.org/node/618 | http:/...  33.7628  -84.4220
# 2               http://bondpapersproject.org/node/470  39.3797  -74.4527
# 3               http://bondpapersproject.org/node/442  39.3051  -76.6144
# 4   http://bondpapersproject.org/node/213 | http:/...  33.5279  -86.7971
# 5   http://bondpapersproject.org/node/311 | http:/...  35.2083  -80.8303
# 6               http://bondpapersproject.org/node/118  41.8375  -87.6866
# 7   http://bondpapersproject.org/node/157 | http:/...  41.4764  -81.6805
# 8               http://bondpapersproject.org/node/237  36.0956  -79.8271
# 9   http://bondpapersproject.org/node/521 | http:/...  29.7860  -95.3885
# 10  http://bondpapersproject.org/node/160 | http:/...  32.3157  -90.2125
# 11  http://bondpapersproject.org/node/89 | http://...  39.1238  -94.5541
# 12  http://bondpapersproject.org/node/329 | http:/...  34.1141 -118.4068
# 13              http://bondpapersproject.org/node/302  32.8065  -83.6974
# 14              http://bondpapersproject.org/node/377  32.3482  -86.2668
# 15  http://bondpapersproject.org/node/663 | http:/...  30.0687  -89.9288
# 16  http://bondpapersproject.org/node/270 | http:/...  40.4397  -79.9763
# 17              http://bondpapersproject.org/node/258  33.7245  -90.5500
# 18  http://bondpapersproject.org/node/613 | http:/...  28.7891  -81.2757
# 19              http://bondpapersproject.org/node/337  47.6211 -122.3244
# 20  http://bondpapersproject.org/node/127 | http:/...  38.6359  -90.2451

# %% [markdown]
# Of course, the next question is how to hyperlink them all, but perhaps that is one for later. Not bad work today.
#
# I have some thoughts on how to hyperlink, too. Definitely not nothing.

# %% [markdown]
# Ok, so, cannot create a content field with a list of hyperlinks and have it work. Individual hyperlinks do work though - could create links to each place name and have links to content

# %%
merged.to_csv('test_layer_2.csv')

# %% [markdown]
# alternatively:

# %%
merged_pt_2 = pd.merge(doc_catalog, uscities, on='City', how='left')
merged_pt_2.dropna(inplace=True)
merged_pt_2
# Out:
#       ID                                              Title  \
# 4    663  Speech about the upcoming presidential electio...
# 5    662  (Draft) Speech about the upcoming presidential...
# 6    661  (Draft) Speech about the upcoming presidential...
# 11   618  Speech about the roles of black students in ad...
# 16   613  Speech concerning political action, black peop...
# ..   ...                                                ...
# 221   90  Speech at the National Urban League Meeting, K...
# 226   95  Testimony before the Commission on Delegate Se...
# 227   96  Testimony before the Commission on Delegate Se...
# 228   97  Testimony before the Commission on Delegate Se...
# 232   80  Speech made before the Hungry Club [Forum, Atl...
#
#                                          Document Body  \
# 4    The election approaching on November seventh i...
# 5    Page 1\nJULIAN BOND\nThe election approaching ...
# 6    [Handwritten on legal pad paper.]\n[The follow...
# 11   1\n[Handwritten.]\nI have been asked to say a ...
# 16   It is a great pleasure to be in Florida this e...
# ..                                                 ...
# 221  The quadrennial occasion for American reaction...
# 226  I am pleased to testify on behalf of the refor...
# 227  "Quotas" is the code word for 1972. Like most ...
# 228  "Quotas" is the code word for 1972. Like most ...
# 232  Although the Hungry Club is a non-partisan for...
#
#                        City                                    url  \
# 4    New Orleans, Louisiana  http://bondpapersproject.org/node/663
# 5    New Orleans, Louisiana  http://bondpapersproject.org/node/662
# 6    New Orleans, Louisiana  http://bondpapersproject.org/node/661
# 11         Atlanta, Georgia  http://bondpapersproject.org/node/618
# 16         Sanford, Florida  http://bondpapersproject.org/node/613
# ..                      ...                                    ...
# 221   Kansas City, Missouri   http://bondpapersproject.org/node/90
# 226        Atlanta, Georgia   http://bondpapersproject.org/node/95
# 227        Atlanta, Georgia   http://bondpapersproject.org/node/96
# 228        Atlanta, Georgia   http://bondpapersproject.org/node/97
# 232        Atlanta, Georgia   http://bondpapersproject.org/node/80
#
#             city state_name      lat      lng
# 4    New Orleans  Louisiana  30.0687 -89.9288
# 5    New Orleans  Louisiana  30.0687 -89.9288
# 6    New Orleans  Louisiana  30.0687 -89.9288
# 11       Atlanta    Georgia  33.7628 -84.4220
# 16       Sanford    Florida  28.7891 -81.2757
# ..           ...        ...      ...      ...
# 221  Kansas City   Missouri  39.1238 -94.5541
# 226      Atlanta    Georgia  33.7628 -84.4220
# 227      Atlanta    Georgia  33.7628 -84.4220
# 228      Atlanta    Georgia  33.7628 -84.4220
# 232      Atlanta    Georgia  33.7628 -84.4220
#
# [62 rows x 9 columns]

# %%
drop_map_2 = drop_map + ['Document Body']
merged_pt_2.drop(drop_map_2, axis=1, inplace=True)
merged_pt_2
# Out:
#       ID                                              Title  \
# 4    663  Speech about the upcoming presidential electio...
# 5    662  (Draft) Speech about the upcoming presidential...
# 6    661  (Draft) Speech about the upcoming presidential...
# 11   618  Speech about the roles of black students in ad...
# 16   613  Speech concerning political action, black peop...
# ..   ...                                                ...
# 221   90  Speech at the National Urban League Meeting, K...
# 226   95  Testimony before the Commission on Delegate Se...
# 227   96  Testimony before the Commission on Delegate Se...
# 228   97  Testimony before the Commission on Delegate Se...
# 232   80  Speech made before the Hungry Club [Forum, Atl...
#
#                        City                                    url      lat  \
# 4    New Orleans, Louisiana  http://bondpapersproject.org/node/663  30.0687
# 5    New Orleans, Louisiana  http://bondpapersproject.org/node/662  30.0687
# 6    New Orleans, Louisiana  http://bondpapersproject.org/node/661  30.0687
# 11         Atlanta, Georgia  http://bondpapersproject.org/node/618  33.7628
# 16         Sanford, Florida  http://bondpapersproject.org/node/613  28.7891
# ..                      ...                                    ...      ...
# 221   Kansas City, Missouri   http://bondpapersproject.org/node/90  39.1238
# 226        Atlanta, Georgia   http://bondpapersproject.org/node/95  33.7628
# 227        Atlanta, Georgia   http://bondpapersproject.org/node/96  33.7628
# 228        Atlanta, Georgia   http://bondpapersproject.org/node/97  33.7628
# 232        Atlanta, Georgia   http://bondpapersproject.org/node/80  33.7628
#
#          lng
# 4   -89.9288
# 5   -89.9288
# 6   -89.9288
# 11  -84.4220
# 16  -81.2757
# ..       ...
# 221 -94.5541
# 226 -84.4220
# 227 -84.4220
# 228 -84.4220
# 232 -84.4220
#
# [62 rows x 6 columns]

# %%
merged_pt_2.to_csv('test_layer_3.csv')

# %% [markdown]
# # Using all the speeches

# %%
catalog_extended = pd.read_csv('document-catalog_extended.csv')
catalog_extended
# Out:
#        ID                                              Title              Box  \
# 0    4375  Speech concerning Black Voters and Officials d...  Box 15 Folder 1
# 1    3261  Enclosure: Julian Bond's revisions to text abo...  Box 14 Folder 6
# 2     671       Speech File Material: Speech Fragment, 1971?  Box 12 Folder 3
# 3     670  Undated Speech concerning Conditions of Black ...  Box 12 Folder 3
# 4     668  Speech File Material: Undated Speech about the...  Box 12 Folder 3
# ..    ...                                                ...              ...
# 433    88  Speech on the health of the United States educ...   Box 4 Folder 8
# 434     4            "Collision Course in a Divided America"              NaN
# 435     7  Address at the "New Directions in Civil Rights...              NaN
# 436    11  DUPLICATE DO NOT PUBLISH: "Civil Rights and Wr...              NaN
# 437    12  Speech concerning the black college: its effec...              NaN
#
#      Document Length Workflow Stage  \
# 0                6.0      Cataloged
# 1                1.0      Cataloged
# 2                4.0    Transcribed
# 3               17.0   Early Access
# 4               10.0      Cataloged
# ..               ...            ...
# 433             29.0   Early Access
# 434              NaN      Digitized
# 435              NaN    Transcribed
# 436              NaN      Digitized
# 437              NaN      Digitized
#
#                                         Image Filename  \
# 0                                                  NaN
# 1                                                  NaN
# 2    PJB671_mss13347-b12-f3_0088.tif\n, PJB671_mss1...
# 3    PJB670_mss13347-b12-f3_0071.tif\n, PJB670_mss1...
# 4    PJB668_mss13347-b12-f3_0058.tif\n, PJB668_mss1...
# ..                                                 ...
# 433  PJB88_0001.tif\n, PJB88_0002.tif\n, PJB88_0003...
# 434                                                NaN
# 435                                                NaN
# 436                       1578302.tiff\n, 1578303.tiff
# 437                                                NaN
#
#                                       Image Identifier Image URL  \
# 0                                                  NaN       NaN
# 1                                                  NaN       NaN
# 2                   3243642, 3243643, 3243644, 3243645       NaN
# 3    3243646, 3243647, 3243648, 3243649, 3243650, 3...       NaN
# 4    3243666, 3243667, 3243668, 3243669, 3243670, 3...       NaN
# ..                                                 ...       ...
# 433  2857526, 2857527, 2857528, 2857529, 2857530, 2...       NaN
# 434                                                NaN       NaN
# 435                                                NaN       NaN
# 436                                   1578302, 1578303       NaN
# 437                                                NaN       NaN
#
#                                          Document Body
# 0                                                  NaN
# 1                                                  NaN
# 2    (9)\nNearly 100 years ago, a group of black pe...
# 3    [This speech includes pages with many differen...
# 4                                                  NaN
# ..                                                 ...
# 433  Insert x [Handwritten pages contain the conten...
# 434  Unnamed speaker:\nIn the past few years, espec...
# 435  This is the twentieth anniversary year of the ...
# 436  The women’s movement was given new life in the...
# 437  It is a pleasure to speak on behalf of an inst...
#
# [438 rows x 9 columns]

# %%
catalog_extended.drop(['Box', 'Document Length',
                  'Image Filename', 'Image Identifier', 'Image URL'], axis=1, inplace=True)

# %%
catalog_extended['City'] = catalog_extended['Title'].str.extract(f'({city_pattern})', expand=False)

sum(catalog_extended.City.value_counts())
# Out:
# 97

# %% [markdown]
# EDA unfortunately shows that it will be awfully difficult to extract the dates because they are not in the same pattern.

# %%
years = np.arange(1960, 2016)
years = years.astype('str')
years_list = list(years)
years_pattern = '|'.join([f'\\b{year}\\b' for year in years])
years_pattern
# Out:
# '\\b1960\\b|\\b1961\\b|\\b1962\\b|\\b1963\\b|\\b1964\\b|\\b1965\\b|\\b1966\\b|\\b1967\\b|\\b1968\\b|\\b1969\\b|\\b1970\\b|\\b1971\\b|\\b1972\\b|\\b1973\\b|\\b1974\\b|\\b1975\\b|\\b1976\\b|\\b1977\\b|\\b1978\\b|\\b1979\\b|\\b1980\\b|\\b1981\\b|\\b1982\\b|\\b1983\\b|\\b1984\\b|\\b1985\\b|\\b1986\\b|\\b1987\\b|\\b1988\\b|\\b1989\\b|\\b1990\\b|\\b1991\\b|\\b1992\\b|\\b1993\\b|\\b1994\\b|\\b1995\\b|\\b1996\\b|\\b1997\\b|\\b1998\\b|\\b1999\\b|\\b2000\\b|\\b2001\\b|\\b2002\\b|\\b2003\\b|\\b2004\\b|\\b2005\\b|\\b2006\\b|\\b2007\\b|\\b2008\\b|\\b2009\\b|\\b2010\\b|\\b2011\\b|\\b2012\\b|\\b2013\\b|\\b2014\\b|\\b2015\\b'

# %%
catalog_extended['Year'] = catalog_extended['Title'].str.extract(f'({years_pattern})', expand=False)
catalog_extended['Year'].value_counts()
# Out:
# Year
# 1977    17
# 1972     9
# 1975     8
# 1976     8
# 1971     6
# 1979     5
# 1970     4
# 1980     4
# 1981     3
# 1978     3
# 1973     3
# 1998     3
# 1991     2
# 1974     2
# 1983     2
# 2001     2
# 1989     2
# 1965     1
# 2003     1
# 2002     1
# 2000     1
# 1996     1
# 1999     1
# 1994     1
# 1988     1
# 1968     1
# 1995     1
# 1987     1
# Name: count, dtype: int64

# %%
catalog_extended.dropna(inplace=True)
catalog_extended.Year.value_counts()
# Out:
# Year
# 1977    17
# 1972     9
# 1975     8
# 1976     8
# 1971     6
# 1979     5
# 1970     4
# 1980     4
# 1981     3
# 1978     3
# 1973     3
# 1998     3
# 1991     2
# 1974     2
# 1983     2
# 2001     2
# 1989     2
# 1965     1
# 2003     1
# 2002     1
# 2000     1
# 1996     1
# 1999     1
# 1994     1
# 1988     1
# 1968     1
# 1995     1
# 1987     1
# Name: count, dtype: int64

# %%
merged_cat = pd.merge(catalog_extended, uscities, on='City', how='left')
merged_cat.drop(['Document Body', 'city', 'state_name'], axis=1, inplace=True)
merged_cat['ID'] = merged_cat['ID'].astype('str')
merged_cat['url'] = "http://bondpapersproject.org/node/" + merged_cat['ID']
merged_cat
# Out:
#      ID                                              Title  \
# 0   663  Speech about the upcoming presidential electio...
# 1   662  (Draft) Speech about the upcoming presidential...
# 2   661  (Draft) Speech about the upcoming presidential...
# 3   618  Speech about the roles of black students in ad...
# 4   613  Speech concerning political action, black peop...
# ..  ...                                                ...
# 89   89  Speech at the National Urban League Meeting, K...
# 90   90  Speech at the National Urban League Meeting, K...
# 91   95  Testimony before the Commission on Delegate Se...
# 92   96  Testimony before the Commission on Delegate Se...
# 93   97  Testimony before the Commission on Delegate Se...
#
#                       City  Year      lat      lng  \
# 0   New Orleans, Louisiana  1972  30.0687 -89.9288
# 1   New Orleans, Louisiana  1972  30.0687 -89.9288
# 2   New Orleans, Louisiana  1972  30.0687 -89.9288
# 3         Atlanta, Georgia  1972  33.7628 -84.4220
# 4         Sanford, Florida  1972  28.7891 -81.2757
# ..                     ...   ...      ...      ...
# 89   Kansas City, Missouri  1974  39.1238 -94.5541
# 90   Kansas City, Missouri  1974  39.1238 -94.5541
# 91        Atlanta, Georgia  1973  33.7628 -84.4220
# 92        Atlanta, Georgia  1973  33.7628 -84.4220
# 93        Atlanta, Georgia  1973  33.7628 -84.4220
#
#                                       url
# 0   http://bondpapersproject.org/node/663
# 1   http://bondpapersproject.org/node/662
# 2   http://bondpapersproject.org/node/661
# 3   http://bondpapersproject.org/node/618
# 4   http://bondpapersproject.org/node/613
# ..                                    ...
# 89   http://bondpapersproject.org/node/89
# 90   http://bondpapersproject.org/node/90
# 91   http://bondpapersproject.org/node/95
# 92   http://bondpapersproject.org/node/96
# 93   http://bondpapersproject.org/node/97
#
# [94 rows x 7 columns]

# %%
merged_cat['Year'] = merged_cat['Year'].astype('str')

# %%
mydict = {}
for year in merged_cat['Year'].unique():
    mydict[year] = merged_cat[merged_cat['Year'] == year]

filtered_dict = {k: v for k, v in mydict.items() if k in np.arange(1970,1980).astype('str')}
filtered_dict = dict(sorted(filtered_dict.items()))

filtered_dict.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 mydict = {}
# ----> 2 for year in merged_cat['Year'].unique():
#       3     mydict[year] = merged_cat[merged_cat['Year'] == year]
#       5 filtered_dict = {k: v for k, v in mydict.items() if k in np.arange(1970,1980).astype('str')}
#
# NameError: name 'merged_cat' is not defined

# %%
for k, v in filtered_dict.items():
    path = f'speeches_{str(k)}.csv'
    v.to_csv(path)

# %%
frames = filtered_dict.values()
speeches_70s = pd.concat(frames)
speeches_70s.to_csv('speeches_70s.csv')

# %% [markdown]
# Next week's puzzle (or maybe this weekend): try to get state abbreviations (CA, AL, etc.)
#
# 1. Create a second state string to extract based on. So, I would do an str.replace with a map to each state's abbreviation on the uscities dataset: would mean I had like "Huntsville, Alabama" but also "Huntsville, AL".
# 2. Then I can add both of those to the regex function and get it all in one column (some will be "Huntsville, AL" and others will be "Huntsville, Alabama")
# 4. From there, I can use the same replace map I made in the first place to loop through that column and convert all like "Huntsville, Alabama" to "Huntsville, AL".
# 5. Now, I can join based on that column in the uscities dataset, and go from there. Once I drop the columns, the entries will look exactly the same as before, just hopefully with even more information.
# 6. I think I am going to create a new Jupyter notebook for this and work on it on Sunday while I watch football. The new Jupyter notebook will allow me to clean up the mess I have made so far.

# %%
uscities
# Out:
#                  city    state_name      lat       lng  \
# 0            New York      New York  40.6943  -73.9249
# 1         Los Angeles    California  34.1141 -118.4068
# 2             Chicago      Illinois  41.8375  -87.6866
# 3               Miami       Florida  25.7840  -80.2101
# 4             Houston         Texas  29.7860  -95.3885
# ...               ...           ...      ...       ...
# 31115          Kohatk       Arizona  32.5781 -112.0032
# 31116       Ironville  Pennsylvania  40.6586  -78.2155
# 31117         Newkirk    New Mexico  35.0635 -104.2715
# 31118  Falcon Village         Texas  26.5652  -99.1341
# 31119     Millerstown  Pennsylvania  40.2771  -78.3029
#
#                             City
# 0             New York, New York
# 1        Los Angeles, California
# 2              Chicago, Illinois
# 3                 Miami, Florida
# 4                 Houston, Texas
# ...                          ...
# 31115            Kohatk, Arizona
# 31116    Ironville, Pennsylvania
# 31117        Newkirk, New Mexico
# 31118      Falcon Village, Texas
# 31119  Millerstown, Pennsylvania
#
# [31120 rows x 5 columns]

# %%
state_map = pd.read_csv('states.csv')
state_map
# Out:
#                    State Abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20               Montana           MT
# 21              Nebraska           NE
# 22                Nevada           NV
# 23         New Hampshire           NH
# 24            New Jersey           NJ
# 25            New Mexico           NM
# 26              New York           NY
# 27        North Carolina           NC
# 28          North Dakota           ND
# 29                  Ohio           OH
# 30              Oklahoma           OK
# 31                Oregon           OR
# 32              Maryland           MD
# 33         Massachusetts           MA
# 34              Michigan           MI
# 35             Minnesota           MN
# 36           Mississippi           MS
# 37              Missouri           MO
# 38          Pennsylvania           PA
# 39          Rhode Island           RI
# 40        South Carolina           SC
# 41          South Dakota           SD
# 42             Tennessee           TN
# 43                 Texas           TX
# 44                  Utah           UT
# 45               Vermont           VT
# 46              Virginia           VA
# 47            Washington           WA
# 48         West Virginia           WV
# 49             Wisconsin           WI
# 50               Wyoming           WY

# %%
state_map_dict = dict(zip(state_map['State'], state_map['Abbreviation']))
uscities['state_abbrev'] = uscities['state_name'].map(state_map_dict)
uscities
# Out:
#                  city    state_name      lat       lng  \
# 0            New York      New York  40.6943  -73.9249
# 1         Los Angeles    California  34.1141 -118.4068
# 2             Chicago      Illinois  41.8375  -87.6866
# 3               Miami       Florida  25.7840  -80.2101
# 4             Houston         Texas  29.7860  -95.3885
# ...               ...           ...      ...       ...
# 31115          Kohatk       Arizona  32.5781 -112.0032
# 31116       Ironville  Pennsylvania  40.6586  -78.2155
# 31117         Newkirk    New Mexico  35.0635 -104.2715
# 31118  Falcon Village         Texas  26.5652  -99.1341
# 31119     Millerstown  Pennsylvania  40.2771  -78.3029
#
#                             City state_abbrev
# 0             New York, New York           NY
# 1        Los Angeles, California           CA
# 2              Chicago, Illinois           IL
# 3                 Miami, Florida           FL
# 4                 Houston, Texas           TX
# ...                          ...          ...
# 31115            Kohatk, Arizona           AZ
# 31116    Ironville, Pennsylvania           PA
# 31117        Newkirk, New Mexico           NM
# 31118      Falcon Village, Texas           TX
# 31119  Millerstown, Pennsylvania           PA
#
# [31120 rows x 6 columns]

# %%
uscities.rename({'City': 'city_full'}, axis = 1, inplace = True)

uscities['city_abbrev'] = uscities['city'] + ', ' + uscities['state_abbrev']
uscities
# Out:
#                  city    state_name      lat       lng  \
# 0            New York      New York  40.6943  -73.9249
# 1         Los Angeles    California  34.1141 -118.4068
# 2             Chicago      Illinois  41.8375  -87.6866
# 3               Miami       Florida  25.7840  -80.2101
# 4             Houston         Texas  29.7860  -95.3885
# ...               ...           ...      ...       ...
# 31115          Kohatk       Arizona  32.5781 -112.0032
# 31116       Ironville  Pennsylvania  40.6586  -78.2155
# 31117         Newkirk    New Mexico  35.0635 -104.2715
# 31118  Falcon Village         Texas  26.5652  -99.1341
# 31119     Millerstown  Pennsylvania  40.2771  -78.3029
#
#                        city_full state_abbrev         city_abbrev
# 0             New York, New York           NY        New York, NY
# 1        Los Angeles, California           CA     Los Angeles, CA
# 2              Chicago, Illinois           IL         Chicago, IL
# 3                 Miami, Florida           FL           Miami, FL
# 4                 Houston, Texas           TX         Houston, TX
# ...                          ...          ...                 ...
# 31115            Kohatk, Arizona           AZ          Kohatk, AZ
# 31116    Ironville, Pennsylvania           PA       Ironville, PA
# 31117        Newkirk, New Mexico           NM         Newkirk, NM
# 31118      Falcon Village, Texas           TX  Falcon Village, TX
# 31119  Millerstown, Pennsylvania           PA     Millerstown, PA
#
# [31120 rows x 7 columns]

# %%
cities = uscities['city_full'].tolist() + uscities['city_abbrev'].tolist()

# Create regex pattern for cities
city_pattern = '|'.join([f'\\b{city}\\b' for city in cities])

# %%
# Extract the city and state from the Address column
catalog_extended = pd.read_csv('document-catalog_extended.csv')

catalog_extended['city_full'] = catalog_extended['Title'].str.extract(f'({city_pattern})', expand=False)

print(catalog_extended)
# Out:
#        ID                                              Title              Box  \
# 0    4375  Speech concerning Black Voters and Officials d...  Box 15 Folder 1
# 1    3261  Enclosure: Julian Bond's revisions to text abo...  Box 14 Folder 6
# 2     671       Speech File Material: Speech Fragment, 1971?  Box 12 Folder 3
# 3     670  Undated Speech concerning Conditions of Black ...  Box 12 Folder 3
# 4     668  Speech File Material: Undated Speech about the...  Box 12 Folder 3
# ..    ...                                                ...              ...
# 433    88  Speech on the health of the United States educ...   Box 4 Folder 8
# 434     4            "Collision Course in a Divided America"              NaN
# 435     7  Address at the "New Directions in Civil Rights...              NaN
# 436    11  DUPLICATE DO NOT PUBLISH: "Civil Rights and Wr...              NaN
# 437    12  Speech concerning the black college: its effec...              NaN
#
#      Document Length Workflow Stage  \
# 0                6.0      Cataloged
# 1                1.0      Cataloged
# 2                4.0    Transcribed
# 3               17.0   Early Access
# 4               10.0      Cataloged
# ..               ...            ...
# 433             29.0   Early Access
# 434              NaN      Digitized
# 435              NaN    Transcribed
# 436              NaN      Digitized
# 437              NaN      Digitized
#
#                                         Image Filename  \
# 0                                                  NaN
# 1                                                  NaN
# 2    PJB671_mss13347-b12-f3_0088.tif\n, PJB671_mss1...
# 3    PJB670_mss13347-b12-f3_0071.tif\n, PJB670_mss1...
# 4    PJB668_mss13347-b12-f3_0058.tif\n, PJB668_mss1...
# ..                                                 ...
# 433  PJB88_0001.tif\n, PJB88_0002.tif\n, PJB88_0003...
# 434                                                NaN
# 435                                                NaN
# 436                       1578302.tiff\n, 1578303.tiff
# 437                                                NaN
#
#                                       Image Identifier Image URL  \
# 0                                                  NaN       NaN
# 1                                                  NaN       NaN
# 2                   3243642, 3243643, 3243644, 3243645       NaN
# 3    3243646, 3243647, 3243648, 3243649, 3243650, 3...       NaN
# 4    3243666, 3243667, 3243668, 3243669, 3243670, 3...       NaN
# ..                                                 ...       ...
# 433  2857526, 2857527, 2857528, 2857529, 2857530, 2...       NaN
# 434                                                NaN       NaN
# 435                                                NaN       NaN
# 436                                   1578302, 1578303       NaN
# 437                                                NaN       NaN
#
#                                          Document Body          city_full
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2    (9)\nNearly 100 years ago, a group of black pe...                NaN
# 3    [This speech includes pages with many differen...                NaN
# 4                                                  NaN  Chicago, Illinois
# ..                                                 ...                ...
# 433  Insert x [Handwritten pages contain the conten...                NaN
# 434  Unnamed speaker:\nIn the past few years, espec...                NaN
# 435  This is the twentieth anniversary year of the ...                NaN
# 436  The women’s movement was given new life in the...                NaN
# 437  It is a pleasure to speak on behalf of an inst...                NaN
#
# [438 rows x 10 columns]

# %%
catalog_extended.drop(['Box', 'Document Length',
                  'Image Filename', 'Image Identifier', 'Image URL'], axis=1, inplace=True)

# %%
filtered_df = catalog_extended[catalog_extended['city_full'].notnull()]
filtered_df
# Out:
#       ID                                              Title Workflow Stage  \
# 4    668  Speech File Material: Undated Speech about the...      Cataloged
# 8    663  Speech about the upcoming presidential electio...   Early Access
# 9    662  (Draft) Speech about the upcoming presidential...   Early Access
# 10   661  (Draft) Speech about the upcoming presidential...   Early Access
# 11   660  Speech concerning the trial of the RNA–11 (Rep...   Early Access
# ..   ...                                                ...            ...
# 415   90  Speech at the National Urban League Meeting, K...   Early Access
# 420   95  Testimony before the Commission on Delegate Se...   Early Access
# 421   96  Testimony before the Commission on Delegate Se...   Early Access
# 422   97  Testimony before the Commission on Delegate Se...   Early Access
# 426   80  Speech made before the Hungry Club [Forum, Atl...   Early Access
#
#                                          Document Body               city_full
# 4                                                  NaN       Chicago, Illinois
# 8    The election approaching on November seventh i...  New Orleans, Louisiana
# 9    Page 1\nJULIAN BOND\nThe election approaching ...  New Orleans, Louisiana
# 10   [Handwritten on legal pad paper.]\n[The follow...  New Orleans, Louisiana
# 11   Writing of another political trial, his own, D...             Jackson, MS
# ..                                                 ...                     ...
# 415  The quadrennial occasion for American reaction...   Kansas City, Missouri
# 420  I am pleased to testify on behalf of the refor...        Atlanta, Georgia
# 421  "Quotas" is the code word for 1972. Like most ...        Atlanta, Georgia
# 422  "Quotas" is the code word for 1972. Like most ...        Atlanta, Georgia
# 426  Although the Hungry Club is a non-partisan for...        Atlanta, Georgia
#
# [102 rows x 5 columns]

# %%
for abbrev, full_name in state_map_dict.items():
    filtered_df['city_full'] = filtered_df['city_full'].str.replace(full_name, abbrev)

print(filtered_df)
# Out:
#       ID                                              Title Workflow Stage  \
# 4    668  Speech File Material: Undated Speech about the...      Cataloged
# 8    663  Speech about the upcoming presidential electio...   Early Access
# 9    662  (Draft) Speech about the upcoming presidential...   Early Access
# 10   661  (Draft) Speech about the upcoming presidential...   Early Access
# 11   660  Speech concerning the trial of the RNA–11 (Rep...   Early Access
# ..   ...                                                ...            ...
# 415   90  Speech at the National Urban League Meeting, K...   Early Access
# 420   95  Testimony before the Commission on Delegate Se...   Early Access
# 421   96  Testimony before the Commission on Delegate Se...   Early Access
# 422   97  Testimony before the Commission on Delegate Se...   Early Access
# 426   80  Speech made before the Hungry Club [Forum, Atl...   Early Access
#
#                                          Document Body               city_full
# 4                                                  NaN       Chicago, Illinois
# 8    The election approaching on November seventh i...  New Orleans, Louisiana
# 9    Page 1\nJULIAN BOND\nThe election approaching ...  New Orleans, Louisiana
# 10   [Handwritten on legal pad paper.]\n[The follow...  New Orleans, Louisiana
# 11   Writing of another political trial, his own, D...    Jackson, Mississippi
# ..                                                 ...                     ...
# 415  The quadrennial occasion for American reaction...   Kansas City, Missouri
# 420  I am pleased to testify on behalf of the refor...        Atlanta, Georgia
# 421  "Quotas" is the code word for 1972. Like most ...        Atlanta, Georgia
# 422  "Quotas" is the code word for 1972. Like most ...        Atlanta, Georgia
# 426  Although the Hungry Club is a non-partisan for...        Atlanta, Georgia
#
# [102 rows x 5 columns]
# C:\Users\charl\AppData\Local\Temp\ipykernel_23116\1392622918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['city_full'] = filtered_df['city_full'].str.replace(full_name, abbrev)

# %% [markdown]
# hmmm. Setting With Copy warning is decidedly a concern, but not sure how big of a concern it ought to be. The dataset's so small, and I can always just filter the way I had filtered before... trying to remember why I want to keep it. Every doc has a workflow stage, right?
#
# Oh also none of this will matter once the other interns start doing location tagging. Duh. Main deliverable should just be a way to tag places. Sigh.

# %%
filtered_df.loc[415,:]
# Out:
# ID                                                               90
# Title             Speech at the National Urban League Meeting, K...
# Workflow Stage                                         Early Access
# Document Body     The quadrennial occasion for American reaction...
# city_full                                     Kansas City, Missouri
# Name: 415, dtype: object
