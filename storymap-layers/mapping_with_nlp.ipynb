# %% [markdown]
# # Locations extraction

# %% [markdown]
# ## Part 1: Regex
#
# Links locations in standardized format directly to cities with linked lat/lng (using USCities dataset)

# %%
# import required packages and read in datasets

import numpy as np
import pandas as pd
import spacy
import re
import datetime
import dateutil.parser as parser

doc_catalog = pd.read_csv('document_catalog_20250815.csv')
uscities = pd.read_csv('uscities.csv')

# %%
doc_catalog.columns
# Out:
# Index(['ID', 'Box', 'title', 'Document Date', 'Document Length',
#        'Manuscript Type', 'Collection', 'Source', 'Internal Notes',
#        'Workflow Stage', 'Object Type', 'Author', 'Keywords', 'Head',
#        'Document Top', 'Dateline', 'Salutation', 'Document Body', 'Signature',
#        'Post Script', 'Document Extra', 'Marginalia', 'Enclosure', 'Footnote',
#        'General', 'Image Identifier', 'Response'],
#       dtype='object')

# %%
# ideal would be if Series was a part of the export

# %%
doc_catalog['Object Type'].unique()
# Out:
# array([nan, 'Letter', 'Pamphlet', 'Article', 'Speech', 'Essay',
#        'Ephemera', 'Interview', 'Report', 'Legal'], dtype=object)

# %%
speeches = doc_catalog[(doc_catalog['Object Type'] == 'Speech') | (doc_catalog['Object Type'] == 'Ephemera')]

# %%
speeches['Workflow Stage'].value_counts()
# Out:
# Workflow Stage
# Early Access    396
# Proof read       60
# Cataloged        13
# Transcribed      13
# Digitized         3
# Tandem read       2
# Name: count, dtype: int64

# %%
speeches[speeches['Workflow Stage'] == 'Transcribed']
# Out:
#         ID              Box  \
# 1877     7              NaN
# 2280   498  Box 10 Folder 5
# 2450   603  Box 2 Folder 22
# 2451   602  Box 2 Folder 23
# 2887  1117  Box 12 Folder 8
# 3718  1921  Box 13 Folder 4
# 3792  2004  Box 13 Folder 5
# 3855  2081  Box 13 Folder 6
# 3908  2117  Box 13 Folder 6
# 4089  2307  Box 13 Folder 7
# 4225  2451  Box 14 Folder 2
# 5021  3261  Box 14 Folder 6
#
#                                                   title  \
# 1877  Address at the "New Directions in Civil Rights...
# 2280  Reference Materials for Speech concerning the ...
# 2450  Speech about Politics and the Ways Policies Ig...
# 2451  Speech about Politics and the Ways Policies Ig...
# 2887  Constituent List for Newsletter Distribution, ...
# 3718  Memo from Julian Bond to call Mers. Gerado Eub...
# 3792  Radnor Junior High School "Go Series" Business...
# 3855  From Julian Bond to Georgia Secretary of State...
# 3908      Julian Bond's Tentative Schedule, 30 Oct 1968
# 4089                      Handwritten Note ca. Nov 1968
# 4225  Enclosure: Quote by T. Thomas Fortune (1884), ...
# 5021  Enclosure: Julian Bond's revisions to text abo...
#
#                                           Document Date  Document Length  \
# 1877                            Mon, 05/04/1998 - 12:00              NaN
# 2280  Fri, 01/01/1999 - 12:00\n - Fri, 12/31/1999 - ...            260.0
# 2450  Thu, 01/01/1970 - 12:00\n - Thu, 12/31/1970 - ...             20.0
# 2451  Thu, 01/01/1970 - 12:00\n - Thu, 12/31/1970 - ...              6.0
# 2887                            Wed, 06/28/1967 - 12:00              1.0
# 3718                            Mon, 09/09/1968 - 12:00              1.0
# 3792  Mon, 01/01/1968 - 12:00\n - Tue, 12/31/1968 - ...              1.0
# 3855                            Tue, 10/08/1968 - 12:00              1.0
# 3908                            Wed, 10/30/1968 - 12:00              1.0
# 4089  Fri, 11/01/1968 - 12:00\n - Sat, 11/30/1968 - ...              1.0
# 4225                            Tue, 06/03/1969 - 12:00              1.0
# 5021                            Tue, 01/20/1970 - 12:00              1.0
#
#                                         Manuscript Type  \
# 1877                                                NaN
# 2280                                            Printed
# 2450                 Draft, Handwritten, Typed, Version
# 2451                                        Copy, Typed
# 2887                                              Typed
# 3718                                        Handwritten
# 3792                                            Printed
# 3855  Autograph, Copy, Handwritten, Printed, Signed,...
# 3908                                              Typed
# 4089                                        Handwritten
# 4225                                        Copy, Typed
# 5021                                        Copy, Typed
#
#                            Collection  \
# 1877  Papers of Julian Bond 1897-2006
# 2280  Papers of Julian Bond 1897-2006
# 2450  Papers of Julian Bond 1897-2006
# 2451  Papers of Julian Bond 1897-2006
# 2887  Papers of Julian Bond 1897-2006
# 3718  Papers of Julian Bond 1897-2006
# 3792  Papers of Julian Bond 1897-2006
# 3855  Papers of Julian Bond 1897-2006
# 3908  Papers of Julian Bond 1897-2006
# 4089  Papers of Julian Bond 1897-2006
# 4225  Papers of Julian Bond 1897-2006
# 5021  Papers of Julian Bond 1897-2006
#
#                                                  Source  \
# 1877  Special Collections, University of Virginia Li...
# 2280  Special Collections, University of Virginia Li...
# 2450  Special Collections, University of Virginia Li...
# 2451  Special Collections, University of Virginia Li...
# 2887  Special Collections, University of Virginia Li...
# 3718  Special Collections, University of Virginia Li...
# 3792  Special Collections, University of Virginia Li...
# 3855  Special Collections, University of Virginia Li...
# 3908  Special Collections, University of Virginia Li...
# 4089  Special Collections, University of Virginia Li...
# 4225  Special Collections, University of Virginia Li...
# 5021  Special Collections, University of Virginia Li...
#
#                                          Internal Notes Workflow Stage  ...  \
# 1877                                                NaN    Transcribed  ...
# 2280  Scanning Notes: There are two records associat...    Transcribed  ...
# 2450  Scanning Notes: There is one item in this fold...    Transcribed  ...
# 2451  Scanning Notes: There is one item in this fold...    Transcribed  ...
# 2887  Scanning Note: Please scan each page of this s...    Transcribed  ...
# 3718  Scanning Note: You may remove the staple and r...    Transcribed  ...
# 3792  Scanning Note: It looks like you'll need to re...    Transcribed  ...
# 3855                                                NaN    Transcribed  ...
# 3908  Scanning Note: There are two separate items in...    Transcribed  ...
# 4089  Date based on location at the end of box 13 fo...    Transcribed  ...
# 4225  Editorial Notes:\n\nThis quote is in the manus...    Transcribed  ...
# 5021  Bulk imported. Editorial Notes: This page seem...    Transcribed  ...
#
#                                           Document Body Signature Post Script  \
# 1877  This is the twentieth anniversary year of the ...       NaN         NaN
# 2280  [The following are reference materials for Jul...       NaN         NaN
# 2450  [1970]\nBrothers and sisters, African people, ...       NaN         NaN
# 2451  Julian Bond\nOne supposes that almost every Am...       NaN         NaN
# 2887  Mr. C. H. Aderhold 121 Chestnut Street, SW Atl...       NaN         NaN
# 3718  Atlant\nCall Mrs Gerado Eubanks (ask Dr. H.M. ...       NaN         NaN
# 3792  John J. TramaCo-chairman(215) 692-2680\nDonald...       NaN         NaN
# 3855  [Image]: inner circle: Three pillars supportin...       NaN         NaN
# 3908  JULIAN BOND - Tentative Schedule\nWednesday, O...       NaN         NaN
# 4089  Clark Call Center for Study of Southern Public...       NaN         NaN
# 4225  "The representatives of the Christian church, ...       NaN         NaN
# 5021  32.  Motion picture footage of COPO workers:\n...       NaN         NaN
#
#      Document Extra Marginalia  \
# 1877            NaN        NaN
# 2280            NaN        NaN
# 2450            NaN        NaN
# 2451            NaN        NaN
# 2887            NaN        NaN
# 3718            NaN        NaN
# 3792            NaN        NaN
# 3855            NaN        NaN
# 3908            NaN        NaN
# 4089            NaN        NaN
# 4225            NaN        NaN
# 5021            NaN        NaN
#
#                                               Enclosure  \
# 1877                                                NaN
# 2280                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2887                                                NaN
# 3718                                                NaN
# 3792                                                NaN
# 3855                                                NaN
# 3908                                                NaN
# 4089                                                NaN
# 4225  From Julian Bond to Allard Lowenstein, 3 June ...
# 5021                                                NaN
#
#                                                Footnote  \
# 1877  The Sixties: Years of Hope—Days of Rage, by To...
# 2280  * Member of the New York Bar. Former General C...
# 2450                                                NaN
# 2451                                                NaN
# 2887                                                NaN
# 3718                                                NaN
# 3792                                                NaN
# 3855                                                NaN
# 3908                                                NaN
# 4089                                                NaN
# 4225                                                NaN
# 5021                                                NaN
#
#                                                 General  \
# 1877                                                NaN
# 2280                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2887  From Julian Bond to 136th House District const...
# 3718                                                NaN
# 3792                                                NaN
# 3855                                                NaN
# 3908                                                NaN
# 4089                                                NaN
# 4225                                                NaN
# 5021                                                NaN
#
#                                        Image Identifier  \
# 1877                                                NaN
# 2280  3242561, 3242562, 3242563, 3242564, 3242565, 3...
# 2450                                                NaN
# 2451                                                NaN
# 2887                                                NaN
# 3718                                                NaN
# 3792                                                NaN
# 3855                                                NaN
# 3908                                                NaN
# 4089                                                NaN
# 4225                                                NaN
# 5021                                                NaN
#
#                                                Response
# 1877                                                NaN
# 2280                                                NaN
# 2450                                                NaN
# 2451                                                NaN
# 2887                                                NaN
# 3718  To Julian Bond from Katherine Camp, 9 Sept 196...
# 3792                                                NaN
# 3855                                                NaN
# 3908                                                NaN
# 4089                                                NaN
# 4225                                                NaN
# 5021                                                NaN
#
# [12 rows x 27 columns]

# %%
# identified mistake I made in proofreading
# fixing it here so I don't have to export the doc catalog again
speeches.loc[2363, 'Workflow Stage'] = 'Proof read'

# %%
state_abbrev_to_name = {
    "AL": "Alabama", "AK": "Alaska", "AZ": "Arizona", "AR": "Arkansas",
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DE": "Delaware",
    "FL": "Florida", "GA": "Georgia", "HI": "Hawaii", "ID": "Idaho",
    "IL": "Illinois", "IN": "Indiana", "IA": "Iowa", "KS": "Kansas",
    "KY": "Kentucky", "LA": "Louisiana", "ME": "Maine", "MD": "Maryland",
    "MA": "Massachusetts", "MI": "Michigan", "MN": "Minnesota", "MS": "Mississippi",
    "MO": "Missouri", "MT": "Montana", "NE": "Nebraska", "NV": "Nevada",
    "NH": "New Hampshire", "NJ": "New Jersey", "NM": "New Mexico", "NY": "New York",
    "NC": "North Carolina", "ND": "North Dakota", "OH": "Ohio", "OK": "Oklahoma",
    "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island", "SC": "South Carolina",
    "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas", "UT": "Utah",
    "VT": "Vermont", "VA": "Virginia", "WA": "Washington", "WV": "West Virginia",
    "WI": "Wisconsin", "WY": "Wyoming", "D.C.": "District of Columbia", "DC": "District of Columbia"
}

state_name_to_abbrev = {v: k for k, v in state_abbrev_to_name.items()}

uscities['state_abbrev'] = uscities['state_name'].map(state_name_to_abbrev)

# Step 3: Generate all combinations
location_variants = set()

for _, row in uscities.iterrows():
    city = row['city']
    state = row['state_name']
    abbrev = row['state_abbrev']
    
    # location_variants.add(city)
    location_variants.add(f"{city}, {state}")
    location_variants.add(f"{city}, {abbrev}")

# Step 4: Escape and build regex pattern
escaped_locations = [re.escape(loc) for loc in location_variants]
pattern = r'\b(?:' + '|'.join(escaped_locations) + r')\b'

# Step 5: Test text
title = "Top Tech Events in San Francisco, Austin, and Miami, FL"

# Find matches
matches = re.findall(pattern, title, flags=re.IGNORECASE)
print(matches)
# Out:
# ['Miami, FL']

# %%
uscities.drop(['zips', 'id'], axis=1, inplace=True)

# %%
uscities['City'] = uscities['city'] + ', ' + uscities['state_name']

# Extract the city name using str.extract()
speeches['city'] = speeches['title'].str.extract(f'({pattern})', expand=False)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_16836\1639426336.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   speeches['city'] = speeches['title'].str.extract(f'({pattern})', expand=False)

# %%
sum(speeches.city.value_counts())
# Out:
# 108

# %%
regex_cities = speeches[speeches.city.notna()]

def replace_state_abbreviations(text):
    # Compile a regex pattern that matches all two-letter state abbreviations as whole words
    pattern = r'\b(' + '|'.join(state_abbrev_to_name.keys()) + r')\b'
    return re.sub(pattern, lambda m: state_abbrev_to_name[m.group()], text)
    
regex_cities.city = regex_cities.city.apply(replace_state_abbreviations)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_16836\71271229.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   regex_cities.city = regex_cities.city.apply(replace_state_abbreviations)

# %%
regex_cities.city.value_counts()
# Out:
# city
# Atlanta, Georgia              34
# New Orleans, Louisiana         6
# Los Angeles, California        4
# Jackson, Mississippi           4
# Houston, Texas                 4
# Birmingham, Alabama            3
# Cleveland, Ohio                3
# Charlotte, North Carolina      3
# St. Louis, Missouri            2
# Kansas City, Missouri          2
# New York, New York             2
# Sacramento, California         2
# Chicago, Illinois              2
# Minneapolis, Minnesota         2
# Pittsburgh, Pennsylvania       2
# Seattle, Washington            2
# Philadelphia, Pennsylvania     2
# Montgomery, Alabama            2
# Baltimore, Maryland            2
# Des Moines, Iowa               2
# Sanford, Florida               2
# Wichita, Kansas                1
# San Juan, Puerto Rico          1
# Fort Collins, Colorado         1
# Greensboro, North Carolina     1
# Topeka, Kansas                 1
# Arlington, Texas               1
# Macon, Georgia                 1
# Honolulu, Hawaii               1
# Gary, Indiana                  1
# Cedar Rapids, Iowa             1
# Ruleville, Mississippi         1
# Louisville, Kentucky           1
# Charlottesville, Virginia      1
# San Francisco, California      1
# Nashville, Tennessee           1
# Roanoke, Virginia              1
# Las Vegas, Nevada              1
# Atlantic City, New Jersey      1
# Miami, Florida                 1
# Sedona, Arizona                1
# Norfolk, Virginia              1
# Name: count, dtype: int64

# %%
speeches_no_regex = speeches[~speeches['ID'].isin(regex_cities['ID'])]

# %%
len(speeches)
# Out:
# 487

# %%
len(speeches_no_regex), len(regex_cities)
# Out:
# (379, 108)

# %% [markdown]
# ## Part 2: NLP
#
# Uses NLP to attempt to target other relevant locations

# %%
nlp = spacy.load('en_core_web_sm')

possible_locations = []

for idx, row in speeches_no_regex.iterrows():
    text = row['title']
    doc = nlp(text)
    locations = [ent.text for ent in doc.ents if ent.label_ in ["GPE", "LOC"]]
    possible_locations.append(locations)

# %%
speeches_no_regex['possible_cities'] = possible_locations
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_16836\1952855365.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   speeches_no_regex['possible_cities'] = possible_locations

# %%
speeches_possible = speeches_no_regex[speeches_no_regex.possible_cities.apply(len) > 0]
len(speeches_possible)
# Out:
# 79

# %%
for idx, row in speeches_possible.iterrows():
    print(idx, row['title'], row['possible_cities'])
# Out:
# 339 (Draft) Speech Introductory Remarks on Zimbabwe, 6 Dec 1973 ['Zimbabwe']
# 340 Enclosure: Speech Introductory Remarks on Zimbabwe, 6 Dec 1973 ['Zimbabwe']
# 1873 Speech on the health of the United States education system, 1973 February 2 ['the United States']
# 1875 DUPLICATE DO NOT PUBLISH: "Civil Rights and Wrongs" Planned Parenthood National Atlantic Region Spring Conference, Washington, D.C., May 20, 1989 ['Washington', 'D.C.']
# 1881 Ephemera/Research for Speech at Press Conference in Washington concerning the Vietnam War and the Bach Mai Hospital Emergency Fund, 1973 January 2 (2 of 2) ['Washington']
# 1882 Speech at Press Conference in Washington concerning the Vietnam War and the Bach Mai Hospital Emergency Fund, 1973 January 2 (1 of 2) ['Washington']
# 1898 Commencement Address at Federal City College, Washington, D.C., 1973 June 17 ['Washington', 'D.C.']
# 1915 Speech concerning South Africa [Probably 1978] ['South Africa']
# 1923 Duplicate of ID120: Speech concerning South Africa, 1973 ['South Africa']
# 1932 Remarks prepared for the Southern Conference of Black Mayors, Grambling, Lousiana, 1975 March 7 (3 of 3) ['Lousiana']
# 1934 Remarks prepared for the Southern Conference of Black Mayors, Grambling, Lousiana, 1975 March 7 (2 of 3) ['Lousiana']
# 1935 Remarks prepared for the Southern Conference of Black Mayors, Grambling, Lousiana, 1975 March 7 (1 of 3) ['Lousiana']
# 1944 Speech given at Villanova University, Pennsylvania, concerning race and class, 1975 April 9 (2 of 2) ['Pennsylvania']
# 1945 Speech given at Villanova University, Pennsylvania, concerning race and class, 1975 April 9 (1 of 2) ['Pennsylvania']
# 1951 Duplicate of ID86: Speech at Press Conference in Washington, January 2 1973 ['Washington']
# 1969 Remarks Prepared for P.U.S.H. Convention, Philadelphia, 1975 (2 of 2) ['Philadelphia']
# 1970 Remarks Prepared for P.U.S.H. Convention, Philadelphia, 1975 (1 of 2) ['Philadelphia']
# 1975 Speech concerning the conditions of black America, 1975 (1 of 2) ['America']
# 1978 Tribute to Maynard Jackson, Jr., Atlanta's first Black mayor (A Roast), 1975 (4 of 4) ['Jr.', 'Atlanta']
# 1979 Tribute to Maynard Jackson, Jr., Atlanta's first black mayor (A Roast), 1975 (3 of 4) ['Jr.', 'Atlanta']
# 1980 Tribute to Maynard Jackson, Jr., Atlanta's first black mayor (A Roast), 1975 (2 of 4) ['Jr.', 'Atlanta']
# 1981 Tribute to Maynard Jackson, Jr., Atlanta's first black mayor (A Roast), 1975 (1 of 4) ['Jr.', 'Atlanta']
# 1987 Speech concerning black America: its progress and its failures, 1976 January ['America']
# 1989 Speech concerning Black people in New York City and their condition on eve of the Bicentennial, [1975] ['New York City']
# 1991 Speech concerning Black politics and influence in the South, 1975 ['South']
# 1995 Speech concerning the 200th Birthday of the United States and black gains, 1975 (2 of 2) ['the United States']
# 1996 Speech concerning the 200th Birthday of the United States and black gains, 1975 (1 of 2) ['the United States']
# 2003 Speech concerning Angola and the tragedy of United States foreign policy in Africa, Spring 1976 ['Angola', 'United States', 'Africa']
# 2008 Speech concerning the conditions of black America, 1975 (2 of 2) ['America']
# 2049 Speech concerning the struggle of black women in America, 1976 ['America']
# 2062 Statement by Julian Bond concerning the nomination of Atlanta lawyer Griffin Bell for Attorney General by Jimmy Carter, 1977 March ['Atlanta']
# 2070 Speech concerning black families, Hampton Institute, Virginia, 1981 March 26 ['Virginia']
# 2098 DuBois' "Credo," 1904 attached to Speech concerning black people and traditional difficulties delivered to the Racial Harmony Council, 1972 ['Credo']
# 2136 Speech about W. E. B. DuBois and Black Leadership, ca. 1986 ['Black Leadership']
# 2139 Speech concerning the relationship between the United States and South Africa, 1985 ['the United States', 'South Africa']
# 2140 Speech concerning Central America and Nicaragua, 1985 ['Central America', 'Nicaragua']
# 2141 Speech concerning Georgia's education system, 1985 ['Georgia']
# 2150 Speech- "Civil Rights and Wrongs" Planned Parenthood National Atlantic Region Spring Conference, Washington, D.C., 1989 May 20 ['Washington', 'D.C.']
# 2162 Speech concerning a review of race relations in the United States, Jan - Sept 1988 ['the United States']
# 2183 Speech prepared for Planned Parenthood of Metropolitan Washington Annual Luncheon, Washington, D.C., 1990 May 24 ['Luncheon', 'Washington', 'D.C.']
# 2190 Paper- "Some Questions for Examining Pennsylvania's Black History" delivered at the [15th Annual Black History in Pennsylvania Conference], [1992] ['Pennsylvania']
# 2217 5 Versions (with 7 ephemera) of Speech on conditions of Southern Black People as compared with 1619, October 1969 ['Southern Black People']
# 2228 Commencement Address at Wilberforce College, Ohio, 1971 August ['Ohio']
# 2235 Speech concerning the Civil Rights Movement and the media, delivered at the Martin Luther King Jr. Conference, University of Newcastle, Newcastle upon Tyne, 1998 May 7 - 10 ['Newcastle', 'Tyne']
# 2242 Addresses of Richard Hatcher and Julian Bond to the Steering Committee Meeting of the National Urban Coalition, Washington, D.C., 1969 December 10 ['Washington', 'D.C.']
# 2252 Commencement Address at Tuskegee University, Alabama, 1971 (Draft, Doc 2 of 2) ['Alabama']
# 2253 Commencement Address at Tuskegee University, Alabama, 1971 (Doc 1 of 2) ['Alabama']
# 2255 Speech concerning what is wrong in the United States, before the National Urban Coalition?, 1971 October (Draft, Doc 2 of 2) ['the United States']
# 2256 Speech concerning what is wrong in the United States, before the National Urban Coalition?, 1971 October (Doc 1 of 2) ['the United States']
# 2264 Speech concerning the United States' move toward destruction, Sept - Oct 1968 ["the United States'"]
# 2272 Address at the Dedication of W.E.B. Du Bois Memorial Park, Great Barrington, Massachusetts, 1969 October 18 ['Massachusetts']
# 2277 Printed Version of Commencement Address at St. George's University, Grenada, 2000 May 12 (Doc 2 of 2) ['Grenada']
# 2278 Commencement Address at St. George's University, Grenada, 2000 May 12 (Doc 1 of 2), with a 1927 Crisis article written by Bond's grandfather ['Grenada']
# 2280 Reference Materials for Speech concerning the celebration of the anniversary of Brown v Board of Education and discussing the closing of the Prince Edward County schools, delivered at Prince Edward County, Virginia, 1999 ['Edward County', 'Prince Edward County', 'Virginia']
# 2281 Speech concerning the celebration of the anniversary of Brown v Board of Education and discussing the closing of the Prince Edward County schools, delivered at Prince Edward County, Virginia, 1999 ['Edward County', 'Prince Edward County', 'Virginia']
# 2293 Speech titled NYC Anti-war Rally, 2003 February 15 ['NYC Anti-war']
# 2300 Speech concerning slaves and their legacy delivered at Monticello, Albemarle County, Virginia, 2001 October 6 ['Virginia']
# 2301 Speech concerning the National Housing Act of 1949 and the continued need for fair housing delivered at the Ethel Lawrence Homes Dedication, Mount Laurel, New Jersey, 2001 September 15 ['Mount Laurel', 'New Jersey']
# 2311 Speech- "The Broken Promise of 'Brown v Board of Education' delivered in Virginia, 2004 ['Virginia']
# 2312 Speech delivered to the 2004 NAACP Convention, Philadelphia Convention Center, Pennsylvania, 2004 July 11 ['Pennsylvania']
# 2313 Draft Speech delivered to the 2004 NAACP Convention, Philadelphia Convention Center, Pennsylvania, 2004 July 11 ['Pennsylvania']
# 2320 Speech concerning James Bond for Berea College Founder's Day, Berea College, Kentucky, 2003 October 10 ['Kentucky']
# 2333 Printed Version of Speech accepting the award at the 2005 Human Rights Campaign Dinner, Washington, D.C., 2005 October 1 ['Washington', 'D.C.']
# 2336 Speech delivered before the Florida State branch of the NAACP [Miami], ca. 2003 ['Florida State', 'Miami']
# 2347 (Draft, Fragment) Speech concerning new faces in Washington conditions for poor black people, no date, ca. Summer-Fall 1969? ['Washington']
# 2351 Speech concerning the Legal Defense Fund, the legal arm of the movement, no date, ca. Dec 7 1976 in California ['California']
# 2353 Speech concerning hunger and malnutrition in the United States, no date, June 1972 ['the United States']
# 2358 Speech concerning the United States as a Colonial Society, 1970 ['the United States']
# 2363 Speech concerning Black Voters and Officials delivered to the Voter Education Project, Inc., Capahosic, Virginia, 1970 July 24 (Doc 3 of 4) ['Virginia']
# 2367 Draft: Address at the Dedication of W.E.B. Du Bois Memorial Park, Great Barrington, Massachusetts, 1969 October 18, with ephemera ['Massachusetts']
# 2369 Speech File Material: The Politics of the Outsider, Remarks of Lerone Bennett, Jr. at Conference of Negro Elected Officials, 30 Sept 1967, Chicago ['Chicago']
# 2374 Speech on Atlanta and the "New South ", likely by Neal Peirce, 1974, given in Atlanta ['Atlanta', 'Atlanta']
# 2385 Speech concerning the Atlanta Inquirer and the black people of Atlanta, ca. 1970 ['Atlanta']
# 2388 Speech File Material: Packet of Quotes Used in Speeches, J. S. Rock, H. M. Turner, L. Douglass, DuBois, no date ['DuBois']
# 2440 Speech concerning Black Voters and Officials delivered to the Voter Education Project, Inc., Capahosic, Virginia, 1970 July 24 (Doc 2 of 4) ['Virginia']
# 2441 Speech concerning Black Voters and Officials delivered to the Voter Education Project, Inc., Capahosic, Virginia, 1970 July 24 (Doc 1 of 4) ['Virginia']
# 3855 From Julian Bond to Georgia Secretary of State, 8 Oct 1968, Requisition for stationary ['Georgia']
# 3908 Julian Bond's Tentative Schedule, 30 Oct 1968 ['Tentative Schedule']
# 6131 Speech concerning Black Voters and Officials delivered to the Voter Education Project, Inc., Capahosic, Virginia, 1970 July 24 (Doc 4 of 4) ['Virginia']

# %%
# export to excel and manually update - too many

speeches_possible.to_excel('speeches_possible.xlsx')

# %%
speeches_no_regex = pd.read_excel('speeches_possible.xlsx')

# %%
speeches_no_regex.drop(['possible_cities', 'Unnamed: 0'], axis = 1, inplace = True)

# %%
speeches_no_regex = speeches_no_regex[speeches_no_regex.city.notna()]
len(speeches_no_regex)
# Out:
# 45

# %%
speeches_no_regex.city = speeches_no_regex.city.apply(replace_state_abbreviations)

# %%
speeches_no_regex.city.value_counts()
# Out:
# city
# Washington, District of Columbia       8
# Atlanta, Georgia                       6
# Capahosic, Virginia                    4
# Philadelphia, Pennsylvania             4
# Grambling, Louisiana                   3
# Villanova, Pennsylvania                2
# Tuskegee, Alabama                      2
# Great Barrington, Massachusetts        2
# Grenada                                2
# Prince Edward County, Virginia         2
# Lincoln University, Pennsylvania       1
# New York, New York                     1
# Wilberforce, Ohio                      1
# Newcastle-upon-Tyne, United Kingdom    1
# Hampton, Virginia                      1
# Charlottesville, Virginia              1
# Mount Laurel, New Jersey               1
# Berea, Kentucky                        1
# Miami, Florida                         1
# Chicago, Illinois                      1
# Name: count, dtype: int64

# %% [markdown]
# ## Part 3: Merge
#
# Merge and export the two datasets. Will split by year and convert to mapped tile layer using ArcGIS Online Notebooks.

# %%
regex_cities = regex_cities.reset_index().drop('index', axis = 1)

# %%
all_located_speeches = pd.concat([regex_cities, speeches_no_regex])

# %%
city_data = uscities[['City', 'lat', 'lng']]
city_data.columns = ['city', 'lat', 'lng']
city_data.index = city_data.city
city_data = city_data.drop('city', axis = 1)

# %%
# we will clean up the meat of it later

all_located_speeches = all_located_speeches.join(city_data, how = 'left', on = 'city')

# %%
sum(all_located_speeches.lat.isna())
# Out:
# 12

# %%
all_located_speeches[all_located_speeches.lat.isna()]
# Out:
#       ID               Box                                              title  \
# 43   427   Box 9 Folder 24  Speech concerning the Civil Rights Movement an...
# 50   458   Box 1 Folder 25  Address at the Dedication of W.E.B. Du Bois Me...
# 51   502   Box 10 Folder 8  Printed Version of Commencement Address at St....
# 52   501   Box 10 Folder 8  Commencement Address at St. George's Universit...
# 53   498   Box 10 Folder 5  Reference Materials for Speech concerning the ...
# 54   497   Box 10 Folder 5  Speech concerning the celebration of the anniv...
# 57   514  Box 10 Folder 16  Speech concerning the National Housing Act of ...
# 68   589   Box 2 Folder 13  Speech concerning Black Voters and Officials d...
# 69   579   Box 1 Folder 25  Draft: Address at the Dedication of W.E.B. Du ...
# 74   588   Box 2 Folder 13  Speech concerning Black Voters and Officials d...
# 75   587   Box 2 Folder 13  Speech concerning Black Voters and Officials d...
# 78  4375   Box 15 Folder 1  Speech concerning Black Voters and Officials d...
#
#                                         Document Date  Document Length  \
# 43  Thu, 05/07/1998 - 12:00\n - Sun, 05/10/1998 - ...             23.0
# 50                            Sat, 10/18/1969 - 12:00              6.0
# 51                            Fri, 05/12/2000 - 12:00             12.0
# 52                            Fri, 05/12/2000 - 12:00             12.0
# 53  Fri, 01/01/1999 - 12:00\n - Fri, 12/31/1999 - ...            260.0
# 54  Fri, 01/01/1999 - 12:00\n - Fri, 12/31/1999 - ...             14.0
# 57                            Sat, 09/15/2001 - 12:00              7.0
# 68                            Fri, 07/24/1970 - 12:00              6.0
# 69                            Sat, 10/18/1969 - 12:00             17.0
# 74                            Fri, 07/24/1970 - 12:00              6.0
# 75                            Fri, 07/24/1970 - 12:00              4.0
# 78                            Fri, 07/24/1970 - 12:00              6.0
#
#                 Manuscript Type                       Collection  \
# 43           Handwritten, Typed  Papers of Julian Bond 1897-2006
# 50           Handwritten, Typed  Papers of Julian Bond 1897-2006
# 51                      Printed  Papers of Julian Bond 1897-2006
# 52           Handwritten, Typed  Papers of Julian Bond 1897-2006
# 53                      Printed  Papers of Julian Bond 1897-2006
# 54           Handwritten, Typed  Papers of Julian Bond 1897-2006
# 57                        Typed  Papers of Julian Bond 1897-2006
# 68  Handwritten, Typed, Version  Papers of Julian Bond 1897-2006
# 69    Draft, Handwritten, Typed  Papers of Julian Bond 1897-2006
# 74  Handwritten, Typed, Version  Papers of Julian Bond 1897-2006
# 75    Draft, Handwritten, Typed  Papers of Julian Bond 1897-2006
# 78                  Copy, Typed  Papers of Julian Bond 1897-2006
#
#                                                Source  \
# 43  Special Collections, University of Virginia Li...
# 50  Special Collections, University of Virginia Li...
# 51  Special Collections, University of Virginia Li...
# 52  Special Collections, University of Virginia Li...
# 53  Special Collections, University of Virginia Li...
# 54  Special Collections, University of Virginia Li...
# 57  Special Collections, University of Virginia Li...
# 68  Special Collections, University of Virginia Li...
# 69  Special Collections, University of Virginia Li...
# 74  Special Collections, University of Virginia Li...
# 75  Special Collections, University of Virginia Li...
# 78  Special Collections, University of Virginia Li...
#
#                                        Internal Notes Workflow Stage  ...  \
# 43  This is the only document in the folder.\nImag...   Early Access  ...
# 50  Scanning Note: There are several items in this...   Early Access  ...
# 51  Scanning Notes: There are two items in this fo...   Early Access  ...
# 52  Scanning Notes: There are two items in this fo...   Early Access  ...
# 53  Scanning Notes: There are two records associat...    Transcribed  ...
# 54  Scanning Notes: There are two records associat...   Early Access  ...
# 57  Scanning Notes: There is one item in this fold...   Early Access  ...
# 68  Scanning Note: There are three items in this f...     Proof read  ...
# 69  Scanning Notes: There are two items in this fo...   Early Access  ...
# 74  Scanning Notes: There are three items in this ...     Proof read  ...
# 75  Scanning Note: There are three items in this f...     Proof read  ...
# 78                                     Bulk imported.      Cataloged  ...
#
#    Document Extra                                         Marginalia  \
# 43            NaN                                                NaN
# 50            NaN  [Handwritten marginalia on page 1, seemingly u...
# 51            NaN                                                NaN
# 52            NaN                                                NaN
# 53            NaN                                                NaN
# 54            NaN                                                NaN
# 57            NaN                                                NaN
# 68            NaN                                                NaN
# 69            NaN                                                NaN
# 74            NaN                                                NaN
# 75            NaN                                                NaN
# 78            NaN                                                NaN
#
#    Enclosure                                           Footnote  \
# 43       NaN  1. Quoted in the New York Times, March 18, 199...
# 50       NaN                                                NaN
# 51       NaN                                                NaN
# 52       NaN  1. "Appeal to the United Nations Found Meeting...
# 53       NaN  * Member of the New York Bar. Former General C...
# 54       NaN  1. Green v. County School Board, 391 U.S. 430,...
# 57       NaN  i See, e.g., Huntington Branch, NAACP v. Hunti...
# 68       NaN                                                NaN
# 69       NaN                                                NaN
# 74       NaN                                                NaN
# 75       NaN                                                NaN
# 78       NaN                                                NaN
#
#                                               General  \
# 43                                                NaN
# 50                                                NaN
# 51  Commencement Address at St. George's Universit...
# 52                                                NaN
# 53                                                NaN
# 54  Reference Materials for Speech concerning the ...
# 57                                                NaN
# 68  Speech concerning Black Voters and Officials d...
# 69                                                NaN
# 74  Speech concerning Black Voters and Officials d...
# 75                                                NaN
# 78                                                NaN
#
#                                      Image Identifier Response  \
# 43  3240466, 3240467, 3240468, 3240469, 3240470, 3...      NaN
# 50  3201887, 3201888, 3201889, 3201890, 3201891, 3...      NaN
# 51  3242462, 3242463, 3242464, 3242465, 3242466, 3...      NaN
# 52  3242474, 3242475, 3242476, 3242477, 3242478, 3...      NaN
# 53  3242561, 3242562, 3242563, 3242564, 3242565, 3...      NaN
# 54  3242821, 3242822, 3242823, 3242824, 3242825, 3...      NaN
# 57  3242290, 3242291, 3242292, 3242293, 3242294, 3...      NaN
# 68  3202577, 3202578, 3202579, 3202580, 3202581, 3...      NaN
# 69  3201870, 3201871, 3201872, 3201873, 3201874, 3...      NaN
# 74                                                NaN      NaN
# 75                                                NaN      NaN
# 78                                                NaN      NaN
#
#                                    city lat lng
# 43  Newcastle-upon-Tyne, United Kingdom NaN NaN
# 50      Great Barrington, Massachusetts NaN NaN
# 51                              Grenada NaN NaN
# 52                              Grenada NaN NaN
# 53       Prince Edward County, Virginia NaN NaN
# 54       Prince Edward County, Virginia NaN NaN
# 57             Mount Laurel, New Jersey NaN NaN
# 68                  Capahosic, Virginia NaN NaN
# 69      Great Barrington, Massachusetts NaN NaN
# 74                  Capahosic, Virginia NaN NaN
# 75                  Capahosic, Virginia NaN NaN
# 78                  Capahosic, Virginia NaN NaN
#
# [12 rows x 30 columns]

# %% [markdown]
# It is acceptable to me, for now, to include these locations without latitude and longitude data. But I cannot because of Drupal limitations. Will have to manually enter the other locations.

# %%
# year extraction

all_located_speeches['date_mod'] = all_located_speeches.apply(lambda row: row['Document Date'].split('-')[0].strip(' '), axis=1)
all_located_speeches['year'] = all_located_speeches.apply(lambda row: parser.parse(row['date_mod']).year, axis=1)

# %%
all_located_speeches['year'].value_counts()
# Out:
# year
# 1975    21
# 1977    17
# 1972    11
# 1976    10
# 1973     9
# 1971     9
# 1970     9
# 1981     5
# 1979     5
# 1998     5
# 1980     4
# 2001     4
# 1999     4
# 1989     4
# 1969     4
# 1988     3
# 2003     3
# 2000     3
# 1978     3
# 1991     2
# 1983     2
# 1990     2
# 2004     2
# 1965     1
# 1993     1
# 1987     1
# 1982     1
# 1995     1
# 1996     1
# 1994     1
# 2002     1
# 1992     1
# 2005     1
# 1967     1
# 1974     1
# Name: count, dtype: int64

# %%
sum(all_located_speeches.year.value_counts())
# Out:
# 153

# %%
len(all_located_speeches)
# Out:
# 153

# %%
all_located_speeches.columns
# Out:
# Index(['ID', 'Box', 'title', 'Document Date', 'Document Length',
#        'Manuscript Type', 'Collection', 'Source', 'Internal Notes',
#        'Workflow Stage', 'Object Type', 'Author', 'Keywords', 'Head',
#        'Document Top', 'Dateline', 'Salutation', 'Document Body', 'Signature',
#        'Post Script', 'Document Extra', 'Marginalia', 'Enclosure', 'Footnote',
#        'General', 'Image Identifier', 'Response', 'city', 'lat', 'lng',
#        'date_mod', 'year'],
#       dtype='object')

# %%
export = all_located_speeches[['ID', 'title', 'Manuscript Type', 'Workflow Stage', 
                               'Keywords', 'city', 'lat', 'lng', 'year']]

# %%
export.head()
# Out:
#    ID                                              title  \
# 0  80  Speech made before the Hungry Club [Forum, Atl...
# 1  97  Testimony before the Commission on Delegate Se...
# 2  96  Testimony before the Commission on Delegate Se...
# 3  95  Testimony before the Commission on Delegate Se...
# 4  90  Speech at the National Urban League Meeting, K...
#
#                Manuscript Type Workflow Stage Keywords                   city  \
# 0                          NaN   Early Access      NaN       Atlanta, Georgia
# 1                          NaN   Early Access      NaN       Atlanta, Georgia
# 2                          NaN   Early Access      NaN       Atlanta, Georgia
# 3                          NaN   Early Access      NaN       Atlanta, Georgia
# 4  Typed, Handwritten, Version   Early Access      NaN  Kansas City, Missouri
#
#        lat      lng  year
# 0  33.7628 -84.4220  1972
# 1  33.7628 -84.4220  1973
# 2  33.7628 -84.4220  1973
# 3  33.7628 -84.4220  1973
# 4  39.1238 -94.5541  1973

# %%
# let's add links

export['hyperlink'] = export.ID.apply(lambda x: f'https://bondpapersproject.org/document/{x}')
export
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_16836\3421138827.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   export['hyperlink'] = export.ID.apply(lambda x: f'https://bondpapersproject.org/document/{x}')
#       ID                                              title  \
# 0     80  Speech made before the Hungry Club [Forum, Atl...
# 1     97  Testimony before the Commission on Delegate Se...
# 2     96  Testimony before the Commission on Delegate Se...
# 3     95  Testimony before the Commission on Delegate Se...
# 4     90  Speech at the National Urban League Meeting, K...
# ..   ...                                                ...
# 71   622  Speech on Atlanta and the "New South ", likely...
# 72   611  Speech concerning the Atlanta Inquirer and the...
# 74   588  Speech concerning Black Voters and Officials d...
# 75   587  Speech concerning Black Voters and Officials d...
# 78  4375  Speech concerning Black Voters and Officials d...
#
#                 Manuscript Type Workflow Stage              Keywords  \
# 0                           NaN   Early Access                   NaN
# 1                           NaN   Early Access                   NaN
# 2                           NaN   Early Access                   NaN
# 3                           NaN   Early Access                   NaN
# 4   Typed, Handwritten, Version   Early Access                   NaN
# ..                          ...            ...                   ...
# 71     Copy, Handwritten, Typed   Early Access  Economics, Education
# 72           Handwritten, Typed     Proof read             Economics
# 74  Handwritten, Typed, Version     Proof read    Disenfranchisement
# 75    Draft, Handwritten, Typed     Proof read    Disenfranchisement
# 78                  Copy, Typed      Cataloged                   NaN
#
#                      city      lat      lng  year  \
# 0        Atlanta, Georgia  33.7628 -84.4220  1972
# 1        Atlanta, Georgia  33.7628 -84.4220  1973
# 2        Atlanta, Georgia  33.7628 -84.4220  1973
# 3        Atlanta, Georgia  33.7628 -84.4220  1973
# 4   Kansas City, Missouri  39.1238 -94.5541  1973
# ..                    ...      ...      ...   ...
# 71       Atlanta, Georgia  33.7628 -84.4220  1974
# 72       Atlanta, Georgia  33.7628 -84.4220  1970
# 74    Capahosic, Virginia      NaN      NaN  1970
# 75    Capahosic, Virginia      NaN      NaN  1970
# 78    Capahosic, Virginia      NaN      NaN  1970
#
#                                       hyperlink
# 0     https://bondpapersproject.org/document/80
# 1     https://bondpapersproject.org/document/97
# 2     https://bondpapersproject.org/document/96
# 3     https://bondpapersproject.org/document/95
# 4     https://bondpapersproject.org/document/90
# ..                                          ...
# 71   https://bondpapersproject.org/document/622
# 72   https://bondpapersproject.org/document/611
# 74   https://bondpapersproject.org/document/588
# 75   https://bondpapersproject.org/document/587
# 78  https://bondpapersproject.org/document/4375
#
# [153 rows x 10 columns]

# %%
# let's also make a public/private identifier

def is_public(workflow_status):
    if workflow_status == 'Early Access':
        return 'Yes'
    else:
        return 'No'

export['Published'] = export['Workflow Stage'].apply(is_public)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_16836\4021859472.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   export['Published'] = export['Workflow Stage'].apply(is_public)

# %%
export
# Out:
#       ID                                              title  \
# 0     80  Speech made before the Hungry Club [Forum, Atl...
# 1     97  Testimony before the Commission on Delegate Se...
# 2     96  Testimony before the Commission on Delegate Se...
# 3     95  Testimony before the Commission on Delegate Se...
# 4     90  Speech at the National Urban League Meeting, K...
# ..   ...                                                ...
# 71   622  Speech on Atlanta and the "New South ", likely...
# 72   611  Speech concerning the Atlanta Inquirer and the...
# 74   588  Speech concerning Black Voters and Officials d...
# 75   587  Speech concerning Black Voters and Officials d...
# 78  4375  Speech concerning Black Voters and Officials d...
#
#                 Manuscript Type Workflow Stage              Keywords  \
# 0                           NaN   Early Access                   NaN
# 1                           NaN   Early Access                   NaN
# 2                           NaN   Early Access                   NaN
# 3                           NaN   Early Access                   NaN
# 4   Typed, Handwritten, Version   Early Access                   NaN
# ..                          ...            ...                   ...
# 71     Copy, Handwritten, Typed   Early Access  Economics, Education
# 72           Handwritten, Typed     Proof read             Economics
# 74  Handwritten, Typed, Version     Proof read    Disenfranchisement
# 75    Draft, Handwritten, Typed     Proof read    Disenfranchisement
# 78                  Copy, Typed      Cataloged                   NaN
#
#                      city      lat      lng  year  \
# 0        Atlanta, Georgia  33.7628 -84.4220  1972
# 1        Atlanta, Georgia  33.7628 -84.4220  1973
# 2        Atlanta, Georgia  33.7628 -84.4220  1973
# 3        Atlanta, Georgia  33.7628 -84.4220  1973
# 4   Kansas City, Missouri  39.1238 -94.5541  1973
# ..                    ...      ...      ...   ...
# 71       Atlanta, Georgia  33.7628 -84.4220  1974
# 72       Atlanta, Georgia  33.7628 -84.4220  1970
# 74    Capahosic, Virginia      NaN      NaN  1970
# 75    Capahosic, Virginia      NaN      NaN  1970
# 78    Capahosic, Virginia      NaN      NaN  1970
#
#                                       hyperlink Published
# 0     https://bondpapersproject.org/document/80       Yes
# 1     https://bondpapersproject.org/document/97       Yes
# 2     https://bondpapersproject.org/document/96       Yes
# 3     https://bondpapersproject.org/document/95       Yes
# 4     https://bondpapersproject.org/document/90       Yes
# ..                                          ...       ...
# 71   https://bondpapersproject.org/document/622       Yes
# 72   https://bondpapersproject.org/document/611        No
# 74   https://bondpapersproject.org/document/588        No
# 75   https://bondpapersproject.org/document/587        No
# 78  https://bondpapersproject.org/document/4375        No
#
# [153 rows x 11 columns]

# %%
export.to_csv('tagged_speeches_toArcGIS_20250818.csv')

# %% [markdown]
# ## Future work
#
# Several components:
#
# 1. Exporting a locations table and attempting a locations feed import (highest priority)
# 2. Completing the Storymap (high priority)
# 3. Analyzing locations spoken of more generally, looking at more than just titles
# 4. Extending location search to Series II, which will require analyzing document top, head, dateline, etc.

# %%
# 1. Export locations table

locations = all_located_speeches[['ID', 'city', 'lat', 'lng']]

# %% [markdown]
# **Needs:**
#
# * Wikidata QID link
# * Wikidata record
# * Title (place name)
# * latitude
# * longitude
#
# Descriptions ought to be added manually, for significant places (i.e., Atlanta). Unclear if multiple places can be associated with one document (i.e., Paschal's Motor Hotel, Atlanta)

# %%
locations = locations.groupby('city').agg(lat = ('lat', 'first'), lng = ('lng', 'first'), docs = ('ID', 'unique')).reset_index()

# %%
def get_wikidata_id(place_name, lang="en"):
    url = "https://www.wikidata.org/w/api.php"
    headers = {
        'User-Agent': 'Bond Papers Location Scraper (cwp5xyj@virginia.edu)'
    }
    params = {
        "action": "wbsearchentities",
        "format": "json",
        "language": lang,
        "search": place_name
    }

    try:
        response = requests.get(url, params=params, headers=headers, timeout=10)
        response.raise_for_status()
        data = response.json()
        if data.get("search"):
            first_hit = data["search"][0]
            qid = first_hit["id"]
            return f"https://www.wikidata.org/wiki/{qid}"
    except Exception as e:
        print(f"Error for {place_name}: {e}")
    return None

# %%
locations['WikiData'] = locations['city'].apply(get_wikidata_id)

# %%
locations
# Out:
#                                    city      lat       lng  \
# 0                      Arlington, Texas  32.6998  -97.1250
# 1                      Atlanta, Georgia  33.7628  -84.4220
# 2             Atlantic City, New Jersey  39.3797  -74.4527
# 3                   Baltimore, Maryland  39.3051  -76.6144
# 4                       Berea, Kentucky  37.5904  -84.2898
# 5                   Birmingham, Alabama  33.5279  -86.7971
# 6                   Capahosic, Virginia      NaN       NaN
# 7                    Cedar Rapids, Iowa  41.9662  -91.6783
# 8             Charlotte, North Carolina  35.2083  -80.8303
# 9             Charlottesville, Virginia  38.0375  -78.4855
# 10                    Chicago, Illinois  41.8375  -87.6866
# 11                      Cleveland, Ohio  41.4764  -81.6805
# 12                     Des Moines, Iowa  41.5725  -93.6105
# 13               Fort Collins, Colorado  40.5477 -105.0656
# 14                        Gary, Indiana  41.5905  -87.3473
# 15                 Grambling, Louisiana  32.5275  -92.7124
# 16      Great Barrington, Massachusetts      NaN       NaN
# 17           Greensboro, North Carolina  36.0956  -79.8271
# 18                              Grenada      NaN       NaN
# 19                    Hampton, Virginia  37.0551  -76.3630
# 20                     Honolulu, Hawaii  21.3294 -157.8460
# 21                       Houston, Texas  29.7860  -95.3885
# 22                 Jackson, Mississippi  32.3157  -90.2125
# 23                Kansas City, Missouri  39.1238  -94.5541
# 24                    Las Vegas, Nevada  36.2333 -115.2654
# 25     Lincoln University, Pennsylvania  39.8064  -75.9279
# 26              Los Angeles, California  34.1141 -118.4068
# 27                 Louisville, Kentucky  38.1663  -85.6485
# 28                       Macon, Georgia  32.8065  -83.6974
# 29                       Miami, Florida  25.7840  -80.2101
# 30               Minneapolis, Minnesota  44.9635  -93.2678
# 31                  Montgomery, Alabama  32.3482  -86.2668
# 32             Mount Laurel, New Jersey      NaN       NaN
# 33                 Nashville, Tennessee  36.1715  -86.7842
# 34               New Orleans, Louisiana  30.0687  -89.9288
# 35                   New York, New York  40.6943  -73.9249
# 36  Newcastle-upon-Tyne, United Kingdom      NaN       NaN
# 37                    Norfolk, Virginia  36.8945  -76.2590
# 38           Philadelphia, Pennsylvania  40.0077  -75.1339
# 39             Pittsburgh, Pennsylvania  40.4397  -79.9763
# 40       Prince Edward County, Virginia      NaN       NaN
# 41                    Roanoke, Virginia  37.2785  -79.9581
# 42               Ruleville, Mississippi  33.7245  -90.5500
# 43               Sacramento, California  38.5677 -121.4685
# 44            San Francisco, California  37.7558 -122.4449
# 45                San Juan, Puerto Rico  18.3985  -66.0610
# 46                     Sanford, Florida  28.7891  -81.2757
# 47                  Seattle, Washington  47.6211 -122.3244
# 48                      Sedona, Arizona  34.8581 -111.7941
# 49                  St. Louis, Missouri  38.6359  -90.2451
# 50                       Topeka, Kansas  39.0346  -95.6955
# 51                    Tuskegee, Alabama  32.4409  -85.7131
# 52              Villanova, Pennsylvania  40.0405  -75.3410
# 53     Washington, District of Columbia  38.9047  -77.0163
# 54                      Wichita, Kansas  37.6895  -97.3443
# 55                    Wilberforce, Ohio  39.7151  -83.8847
#
#                                                  docs  \
# 0                                               [336]
# 1   [80, 97, 96, 95, 153, 152, 243, 242, 256, 255,...
# 2                                               [470]
# 3                                          [442, 505]
# 4                                               [529]
# 5                                     [214, 213, 401]
# 6                               [589, 588, 587, 4375]
# 7                                               [236]
# 8                                     [312, 311, 313]
# 9                                          [384, 515]
# 10                                    [118, 668, 627]
# 11                                    [159, 158, 157]
# 12                                         [363, 362]
# 13                                              [286]
# 14                                              [238]
# 15                                    [148, 146, 145]
# 16                                         [458, 579]
# 17                                              [237]
# 18                                         [502, 501]
# 19                                              [283]
# 20                                              [289]
# 21                               [299, 298, 297, 521]
# 22                               [161, 160, 660, 659]
# 23                                           [90, 89]
# 24                                              [431]
# 25                                              [399]
# 26                               [166, 287, 329, 496]
# 27                                              [387]
# 28                                              [302]
# 29                                         [528, 544]
# 30                                         [284, 369]
# 31                                         [290, 377]
# 32                                              [514]
# 33                                              [418]
# 34                     [342, 410, 513, 663, 662, 661]
# 35                                    [386, 494, 198]
# 36                                              [427]
# 37                                              [570]
# 38                     [374, 376, 175, 174, 537, 536]
# 39                                         [271, 270]
# 40                                         [498, 497]
# 41                                              [424]
# 42                                              [258]
# 43                                         [167, 343]
# 44                                              [407]
# 45                                              [281]
# 46                                         [613, 612]
# 47                                         [337, 361]
# 48                                              [517]
# 49                                         [128, 127]
# 50                                              [239]
# 51                                         [444, 443]
# 52                                         [151, 150]
# 53               [11, 87, 86, 93, 373, 383, 454, 547]
# 54                                              [241]
# 55                                              [435]
#
#                                   WikiData
# 0     https://www.wikidata.org/wiki/Q17943
# 1     https://www.wikidata.org/wiki/Q23556
# 2    https://www.wikidata.org/wiki/Q139564
# 3      https://www.wikidata.org/wiki/Q5092
# 4   https://www.wikidata.org/wiki/Q3180809
# 5     https://www.wikidata.org/wiki/Q79867
# 6   https://www.wikidata.org/wiki/Q5034499
# 7    https://www.wikidata.org/wiki/Q486439
# 8     https://www.wikidata.org/wiki/Q16565
# 9    https://www.wikidata.org/wiki/Q123766
# 10     https://www.wikidata.org/wiki/Q1297
# 11    https://www.wikidata.org/wiki/Q37320
# 12    https://www.wikidata.org/wiki/Q39709
# 13   https://www.wikidata.org/wiki/Q490732
# 14   https://www.wikidata.org/wiki/Q184116
# 15  https://www.wikidata.org/wiki/Q2299854
# 16  https://www.wikidata.org/wiki/Q1144518
# 17    https://www.wikidata.org/wiki/Q49238
# 18      https://www.wikidata.org/wiki/Q769
# 19   https://www.wikidata.org/wiki/Q342043
# 20    https://www.wikidata.org/wiki/Q18094
# 21    https://www.wikidata.org/wiki/Q16555
# 22    https://www.wikidata.org/wiki/Q28198
# 23    https://www.wikidata.org/wiki/Q41819
# 24    https://www.wikidata.org/wiki/Q23768
# 25                                    None
# 26       https://www.wikidata.org/wiki/Q65
# 27    https://www.wikidata.org/wiki/Q43668
# 28   https://www.wikidata.org/wiki/Q219656
# 29     https://www.wikidata.org/wiki/Q8652
# 30    https://www.wikidata.org/wiki/Q36091
# 31    https://www.wikidata.org/wiki/Q29364
# 32  https://www.wikidata.org/wiki/Q1072657
# 33    https://www.wikidata.org/wiki/Q23197
# 34    https://www.wikidata.org/wiki/Q34404
# 35       https://www.wikidata.org/wiki/Q60
# 36                                    None
# 37    https://www.wikidata.org/wiki/Q49231
# 38     https://www.wikidata.org/wiki/Q1345
# 39     https://www.wikidata.org/wiki/Q1342
# 40   https://www.wikidata.org/wiki/Q505884
# 41   https://www.wikidata.org/wiki/Q501796
# 42   https://www.wikidata.org/wiki/Q112733
# 43    https://www.wikidata.org/wiki/Q18013
# 44       https://www.wikidata.org/wiki/Q62
# 45    https://www.wikidata.org/wiki/Q41211
# 46   https://www.wikidata.org/wiki/Q786770
# 47     https://www.wikidata.org/wiki/Q5083
# 48    https://www.wikidata.org/wiki/Q80041
# 49    https://www.wikidata.org/wiki/Q38022
# 50    https://www.wikidata.org/wiki/Q41057
# 51    https://www.wikidata.org/wiki/Q79718
# 52  https://www.wikidata.org/wiki/Q7930873
# 53       https://www.wikidata.org/wiki/Q61
# 54    https://www.wikidata.org/wiki/Q49266
# 55  https://www.wikidata.org/wiki/Q1866955

# %%
# manual lookup for the missings will be fine

lincoln_u = 'https://www.wikidata.org/wiki/Q4570781'
newcastle = 'https://www.wikidata.org/wiki/Q1425428'

# %%
locations.iloc[25, 4] = lincoln_u
locations.iloc[25, 4]
# Out:
# 'https://www.wikidata.org/wiki/Q4570781'

# %%
locations.iloc[36, 4] = newcastle
locations.iloc[36, 4]
# Out:
# 'https://www.wikidata.org/wiki/Q1425428'

# %%
locations['wikidata_text'] = 'Wikidata Record'
locations.head()
# Out:
#                         city      lat      lng  \
# 0           Arlington, Texas  32.6998 -97.1250
# 1           Atlanta, Georgia  33.7628 -84.4220
# 2  Atlantic City, New Jersey  39.3797 -74.4527
# 3        Baltimore, Maryland  39.3051 -76.6144
# 4            Berea, Kentucky  37.5904 -84.2898
#
#                                                 docs  \
# 0                                              [336]
# 1  [80, 97, 96, 95, 153, 152, 243, 242, 256, 255,...
# 2                                              [470]
# 3                                         [442, 505]
# 4                                              [529]
#
#                                  WikiData    wikidata_text
# 0    https://www.wikidata.org/wiki/Q17943  Wikidata Record
# 1    https://www.wikidata.org/wiki/Q23556  Wikidata Record
# 2   https://www.wikidata.org/wiki/Q139564  Wikidata Record
# 3     https://www.wikidata.org/wiki/Q5092  Wikidata Record
# 4  https://www.wikidata.org/wiki/Q3180809  Wikidata Record

# %%
locations['docs'] = locations['docs'].apply(lambda x: f'<p>Bulk imported.</p> <p>This location has been connected to the following IDs: {', '.join(map(str, x))}.</p>')

# %%
locations.head()
# Out:
#                         city      lat      lng  \
# 0           Arlington, Texas  32.6998 -97.1250
# 1           Atlanta, Georgia  33.7628 -84.4220
# 2  Atlantic City, New Jersey  39.3797 -74.4527
# 3        Baltimore, Maryland  39.3051 -76.6144
# 4            Berea, Kentucky  37.5904 -84.2898
#
#                                                 docs  \
# 0  <p>Bulk imported.</p> <p>This location has bee...
# 1  <p>Bulk imported.</p> <p>This location has bee...
# 2  <p>Bulk imported.</p> <p>This location has bee...
# 3  <p>Bulk imported.</p> <p>This location has bee...
# 4  <p>Bulk imported.</p> <p>This location has bee...
#
#                                  WikiData    wikidata_text
# 0    https://www.wikidata.org/wiki/Q17943  Wikidata Record
# 1    https://www.wikidata.org/wiki/Q23556  Wikidata Record
# 2   https://www.wikidata.org/wiki/Q139564  Wikidata Record
# 3     https://www.wikidata.org/wiki/Q5092  Wikidata Record
# 4  https://www.wikidata.org/wiki/Q3180809  Wikidata Record

# %%
locations = locations.rename({'city':'title', 'docs':'internal_notes', 'WikiData':'wikidata'}, axis = 1)

# %%
locations.to_csv('places_feed.csv', index = False)
